# %%
import sys
sys.path.append('C:/Users/Elevate/Desktop/AI Projects/PowerBI-LLM')
from src.json_operator.json_update import *

# %%
example_arguments = {
  "dashboard_summary": "This dashboard provides insights into sales performance, including revenue trends, top-performing products, and regional sales distribution.",
  "pages": [
    {
      "page_name": "Revenue Overview",
      "page_summary": "This page displays overall revenue trends, including month-to-month growth, top sales categories, and year-over-year comparisons.",
      "visuals": [
        {
          "kpi_name": "Total Revenue",
          "kpi_definition": "The total revenue generated by all sales during the selected period."
        },
        {
          "kpi_name": "Revenue Growth Rate",
          "kpi_definition": "The percentage increase or decrease in revenue compared to the previous period."
        }
      ]
    },
    {
      "page_name": "Product Performance",
      "page_summary": "This page focuses on the performance of individual products, showcasing the best-sellers and their sales metrics.",
      "visuals": [
        {
          "kpi_name": "Top-Selling Product",
          "kpi_definition": "The product that has generated the highest revenue during the selected period."
        },
        {
          "kpi_name": "Units Sold",
          "kpi_definition": "The total number of units sold for each product during the selected period."
        }
      ]
    },
    {
      "page_name": "Regional Sales",
      "page_summary": "This page provides a breakdown of sales by region, highlighting regional performance and comparing different territories.",
      "visuals": [
        {
          "kpi_name": "Regional Revenue",
          "kpi_definition": "The total revenue generated in each region."
        },
        {
          "kpi_name": "Regional Sales Growth",
          "kpi_definition": "The percentage change in sales from one region to another during the selected period."
        }
      ]
    }
  ]
}

# %%
dashboard_summary = example_arguments['dashboard_summary']
pages = example_arguments['pages']

# %%
result = add_read_me(dashboard_summary, pages)

# %%
result["sections"][0]
# Out:
# {'config': '{}',
#  'displayName': 'Glossary',
#  'displayOption': 1,
#  'filters': '[]',
#  'height': 1600.0,
#  'name': '88cbaa1e34d414c234a5',
#  'visualContainers': [{'config': '{"name": "677ff640e2128e7c8715", "layouts": [{"id": 0, "position": {"x": 0, "y": 0, "z": 0, "width": 1280, "height": 64}}], "singleVisual": {"visualType": "textbox", "drillFilterOtherVisuals": true, "objects": {"general": [{"properties": {"paragraphs": [{"textRuns": [{"value": " DASHBOARD SUMMARY", "textStyle": {"fontWeight": "bold", "fontSize": "20pt", "color": "#ffffff"}}], "horizontalTextAlignment": "center"}]}}]}, "vcObjects": {"background": [{"properties": {"color": {"solid": {"color": {"expr": {"Literal": {"Value": "\'#252423\'"}}}}}}}]}}}',
#    'filters': '[]',
#    'height': 64.0,
#    'width': 1280.0,
#    'x': 0.0,
#    'y': 0.0,
#    'z': 0.0},
# ...
