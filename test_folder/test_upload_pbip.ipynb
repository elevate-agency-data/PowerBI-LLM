# %%
import zipfile
import os
import json

# Function to handle the PBIP folder and extract report.json
def extract_report_and_model(zip_file):
    # Get the base name of the uploaded zip file, excluding the extension
    inner_folder_name = os.path.splitext(zip_file.name)[0] 
    # Extract the zip file
    extract_path = '\mnt\data\pbip_extracted'
    with zipfile.ZipFile(zip_file, 'r') as zip_ref:
        zip_ref.extractall(extract_path)
    
    inner_folder_path = os.path.join(extract_path, inner_folder_name)
    # Print the contents of the inner folder
    inner_folder_contents = os.listdir(inner_folder_path)
    report_folder_path = None
    model_bim_path = None
    
    # Look for the folder that ends with '.Report' or '.SemanticModel'
    for folder in inner_folder_contents:
        full_folder_path = os.path.join(inner_folder_path, folder)
        if folder.endswith('.Report') and os.path.isdir(full_folder_path):
            report_folder_path = full_folder_path
        elif folder.endswith('.SemanticModel') and os.path.isdir(full_folder_path):
            model_folder_path = full_folder_path
            print(model_folder_path)

    # Extract report.json
    if report_folder_path:
        report_json_path = os.path.join(report_folder_path, 'report.json')
        print(report_json_path)
        with open(report_json_path, 'r', encoding='utf-8') as file:
            report_json_content = json.load(file)
    else:
        report_json_content = None

    model_bim_content = None

    # Extract model.bim
    if model_folder_path:
        model_bim_path = os.path.join(model_folder_path, 'model.bim')
        print("model bim path is: ", model_bim_path)
        # if os.path.exists(model_bim_path):
        #     print("model bim path exists")
        with open(model_bim_path, 'r', encoding='utf-8') as file:
            model_bim_content = json.load(file)
    else:
        model_bim_content = None

    return report_json_content, model_bim_content, inner_folder_path, report_json_path, model_bim_path
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# <>:10: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18348\1238016480.py:10: SyntaxWarning: invalid escape sequence '\m'
#   extract_path = '\mnt\data\pbip_extracted'

# %%
# Example usage
zip_file_path = 'inchanel global.zip' 
zip_file = open(zip_file_path, 'rb')  # This line opens the zip file
report_json, model_bim, folder_path, report_path, model_path = extract_report_and_model(zip_file)
# Out:
# \mnt\data\pbip_extracted\inchanel global\inchanel global.SemanticModel
# \mnt\data\pbip_extracted\inchanel global\inchanel global.Report\report.json
# model bim path is:  \mnt\data\pbip_extracted\inchanel global\inchanel global.SemanticModel\model.bim

# %%
# report_json

# %%
report_json['sections'][6].keys()
# Out:
# dict_keys(['config', 'displayName', 'displayOption', 'filters', 'height', 'name', 'ordinal', 'visualContainers', 'width'])

# %%
visuals = []
for i in range(len(report_json['sections'][6]['visualContainers'])):
    config_data = report_json['sections'][6]['visualContainers'][i].get("config", {})
    config_data = json.loads(config_data)
    visual_type_to_be_excluded = ['actionButton', 'image', 'shape', 'textbox', '']
    if config_data.get("singleVisual", {}).get("visualType", "") not in visual_type_to_be_excluded:
        visuals.append(config_data.get("singleVisual", {}).get("visualType", ""))
        # print(i, config_data.get("singleVisual", {}).get("visualType", ""))

# %%
len(visuals)
distinct_visuals = set(visuals)
# distinct_visuals
# visuals

# %%
test_visual_config = report_json['sections'][6]['visualContainers'][9]['config']
test_visual_config = json.loads(test_visual_config)

# %%
print(test_visual_config.keys())
# test_visual_config
print("the attributes of a single visual are:", test_visual_config.get("singleVisual", {}).keys())
# Out:
# dict_keys(['name', 'layouts', 'singleVisual', 'parentGroupName'])
# the attributes of a single visual are: dict_keys(['visualType', 'projections', 'prototypeQuery', 'drillFilterOtherVisuals', 'objects', 'vcObjects'])

# %%
test_visual_config.get("singleVisual", {}).get("prototypeQuery", {})
# Out:
# {'Version': 2,
#  'From': [{'Name': 'd', 'Entity': 'Date', 'Type': 0},
#   {'Name': '_', 'Entity': '_KPI_Customer', 'Type': 0}],
#  'Select': [{'Column': {'Expression': {'SourceRef': {'Source': 'd'}},
#     'Property': 'MonthYear'},
#    'Name': 'Date.MonthYear',
#    'NativeReferenceName': 'MonthYear'},
#   {'Measure': {'Expression': {'SourceRef': {'Source': '_'}},
#     'Property': 'Onboarded'},
#    'Name': '_KPI_Customer.Onboarded',
#    'NativeReferenceName': 'Onboarded'}]}

# %%
test_visual_config.get("singleVisual", {}).get("columnProperties", {})
# Out:
# {}

# %%
test_visual_config.get("vcObjects", {}).get("title", [])
# Out:
# []

# %%
def extract_relevant_elements_dashboard_summary(json_data):
    sections_list = []

    for section in json_data.get("sections", []):
        # only include the pages which are not hidden in the dashboard
        page_config = json.loads(section['config'])
        if page_config.get('visibility') != 1:
            # Store displayName to know the section/page name
            section_summary = {
                "displayName": section.get("displayName", ""),
                "filters": section.get("filters", ""),
                "ordinal": section.get("ordinal", ""),
                "visualContainers": []
            }

            # Process each visual container in the section
            for visual in section.get("visualContainers", []):
                # Parse config if it's a string
                config_data = visual.get("config", {})
                if isinstance(config_data, str):
                    config_data = json.loads(config_data)

                    visual_type_to_be_excluded = ['actionButton', 'image', 'shape', 'textbox', '']
                    if config_data.get("singleVisual", {}).get("visualType", "") not in visual_type_to_be_excluded:
                        # Extract relevant visual properties
                        visual_summary = {
                            "visualType": config_data.get("singleVisual", {}).get("visualType", ""),
                            "projections": config_data.get("singleVisual", {}).get("projections", []),
                            "prototypeQuery": config_data.get("singleVisual", {}).get("prototypeQuery", {}),
                            "title": config_data.get("vcObjects", {}).get("title", []),
                            "filters": visual.get("filters", [])
                        }

                        # Add visual summary if it has useful data
                        if any(visual_summary.values()):
                            section_summary["visualContainers"].append(visual_summary)

            # Add the section's displayName and extracted_data to the list
            sections_list.append({
                "displayName": section.get("displayName", ""),
                "extracted_data": section_summary
            })

    return sections_list

# %%
extracted_report = extract_relevant_elements_dashboard_summary(report_json)

# %%
extracted_report[1]
# Out:
# {'displayName': 'Scope FA',
#  'extracted_data': {'displayName': 'Scope FA',
#   'filters': '[]',
#   'ordinal': 4,
#   'visualContainers': [{'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.total_nb_of_chats'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Total of Chats'},
#        'Name': 'Mesure.total_nb_of_chats',
#        'NativeReferenceName': 'Total of Chats'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Total of Chats'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.Nb Chat sent By FAs'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Nb of Chats sent per FA'},
#        'Name': 'Mesure.Nb Chat sent By FAs',
#        'NativeReferenceName': 'Nb of Chats sent per FA'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Nb of Chats sent per FA'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.FAs Onboarding'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Nb of FAs who onboarded a client'},
#        'Name': 'Mesure.FAs Onboarding',
#        'NativeReferenceName': 'Nb of FAs who onboarded a client'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Nb of FAs who onboarded a client'}}}]},
#     'title': [],
#     'filters': '[{"name":"Filter0a9ca7bcde882ed68dae","expression":{"Measure":{"Expression":{"SourceRef":{"Entity":"_KPI_Customer"}},"Property":"FAs Onboarding Rattachement"}},"type":"Advanced","howCreated":1,"isHiddenInViewMode":false,"ordinal":0},{"name":"Filterd50a572bfd6e4f520061","expression":{"Column":{"Expression":{"SourceRef":{"Entity":"Customer"}},"Property":"CustomerMixSalesPersonPriority"}},"type":"Categorical","howCreated":1,"objects":{"general":[{"properties":{}}]},"ordinal":1}]'},
#    {'visualType': 'slicer',
#     'projections': {'Values': [{'queryRef': 'dim_boutique.Boutique Name',
#        'active': True}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'd', 'Entity': 'dim_boutique', 'Type': 0}],
#      'Select': [{'Column': {'Expression': {'SourceRef': {'Source': 'd'}},
#         'Property': 'Boutique Name'},
#        'Name': 'dim_boutique.Boutique Name',
#        'NativeReferenceName': 'Boutique Name'}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'slicer',
#     'projections': {'Values': [{'queryRef': 'dim_calendar.Date',
#        'active': True}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'd', 'Entity': 'dim_calendar', 'Type': 0}],
#      'Select': [{'Column': {'Expression': {'SourceRef': {'Source': 'd'}},
#         'Property': 'Date'},
#        'Name': 'dim_calendar.Date',
#        'NativeReferenceName': 'Date'}],
#      'OrderBy': [{'Direction': 1,
#        'Expression': {'Column': {'Expression': {'SourceRef': {'Source': 'd'}},
#          'Property': 'Date'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.FAs Chat'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Nb of FAs who sent a Chat'},
#        'Name': 'Mesure.FAs Chat',
#        'NativeReferenceName': 'Nb of FAs who sent a Chat'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Nb of FAs who sent a Chat'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'slicer',
#     'projections': {'Values': [{'queryRef': 'location.InchanelBtq_Status',
#        'active': True}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'l', 'Entity': 'location', 'Type': 0}],
#      'Select': [{'Column': {'Expression': {'SourceRef': {'Source': 'l'}},
#         'Property': 'InchanelBtq_Status'},
#        'Name': 'location.InchanelBtq_Status',
#        'NativeReferenceName': 'InchanelBtq_Status'}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'slicer',
#     'projections': {'Values': [{'queryRef': 'dim_boutique.Boutique Name',
#        'active': True}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'd', 'Entity': 'dim_boutique', 'Type': 0}],
#      'Select': [{'Column': {'Expression': {'SourceRef': {'Source': 'd'}},
#         'Property': 'Boutique Name'},
#        'Name': 'dim_boutique.Boutique Name',
#        'NativeReferenceName': 'Boutique Name'}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.nb Suggestion Board By FA'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Nb of SB sent per FA'},
#        'Name': 'Mesure.nb Suggestion Board By FA',
#        'NativeReferenceName': 'Nb of SB sent per FA'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Nb of SB sent per FA'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'slicer',
#     'projections': {'Values': [{'queryRef': 'location.InchanelBtq_Status',
#        'active': True}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'l', 'Entity': 'location', 'Type': 0}],
#      'Select': [{'Column': {'Expression': {'SourceRef': {'Source': 'l'}},
#         'Property': 'InchanelBtq_Status'},
#        'Name': 'location.InchanelBtq_Status',
#        'NativeReferenceName': 'InchanelBtq_Status'}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.Nb of Mirror Sessions by FA'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Nb of Mirror Sessions by FA'},
#        'Name': 'Mesure.Nb of Mirror Sessions by FA',
#        'NativeReferenceName': 'Nb of Mirror Sessions by FA'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Nb of Mirror Sessions by FA'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'slicer',
#     'projections': {'Values': [{'queryRef': 'dim_boutique.Country',
#        'active': True}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'd', 'Entity': 'dim_boutique', 'Type': 0}],
#      'Select': [{'Column': {'Expression': {'SourceRef': {'Source': 'd'}},
#         'Property': 'Country'},
#        'Name': 'dim_boutique.Country',
#        'NativeReferenceName': 'Country'}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.sbe_nb_SuggestionBoard_Sent'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Total of SB sent'},
#        'Name': 'Mesure.sbe_nb_SuggestionBoard_Sent',
#        'NativeReferenceName': 'Total of SB sent'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Total of SB sent'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'slicer',
#     'projections': {'Values': [{'queryRef': 'dim_boutique.Country',
#        'active': True}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'd', 'Entity': 'dim_boutique', 'Type': 0}],
#      'Select': [{'Column': {'Expression': {'SourceRef': {'Source': 'd'}},
#         'Property': 'Country'},
#        'Name': 'dim_boutique.Country',
#        'NativeReferenceName': 'Country'}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.avg_onborded_client_by_FA'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Avg Onboarded Clients per FA'},
#        'Name': 'Mesure.avg_onborded_client_by_FA',
#        'NativeReferenceName': 'Avg Onboarded Clients per FA'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Avg Onboarded Clients per FA'}}}]},
#     'title': [],
#     'filters': '[{"name":"Filtera4cad1c4a428594532f4","expression":{"Measure":{"Expression":{"SourceRef":{"Entity":"_KPI_MirrorDB"}},"Property":"mirdb_nb_Customer"}},"type":"Advanced","howCreated":1,"isHiddenInViewMode":false,"ordinal":0},{"name":"Filter21c808bcc60189ab1518","expression":{"Measure":{"Expression":{"SourceRef":{"Entity":"_KPI_Customer"}},"Property":"Nb Onboarded By FAs"}},"type":"Advanced","howCreated":1,"isHiddenInViewMode":false,"ordinal":1},{"name":"Filter555a22b788efaf09358d","expression":{"Column":{"Expression":{"SourceRef":{"Entity":"Customer"}},"Property":"IsPersonnelChanel"}},"type":"Categorical","howCreated":1,"objects":{},"ordinal":2}]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.FAs suggestion board'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Nb of FAs who sent a SB'},
#        'Name': 'Mesure.FAs suggestion board',
#        'NativeReferenceName': 'Nb of FAs who sent a SB'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Nb of FAs who sent a SB'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.mirdb_nb_FA'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Nb of FAs who did at least one Mirror Session'},
#        'Name': 'Mesure.mirdb_nb_FA',
#        'NativeReferenceName': 'Nb of FAs who did at least one Mirror Session'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Nb of FAs who did at least one Mirror Session'}}}]},
#     'title': [],
#     'filters': '[]'},
#    {'visualType': 'card',
#     'projections': {'Values': [{'queryRef': 'Mesure.mirror_nb_sessions'}]},
#     'prototypeQuery': {'Version': 2,
#      'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}],
#      'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#         'Property': 'Nb of Mirror Sessions'},
#        'Name': 'Mesure.mirror_nb_sessions',
#        'NativeReferenceName': 'mirror_nb_sessions'}],
#      'OrderBy': [{'Direction': 2,
#        'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}},
#          'Property': 'Nb of Mirror Sessions'}}}]},
#     'title': [],
#     'filters': '[{"name":"80b331c2dff9e295441e","expression":{"Measure":{"Expression":{"SourceRef":{"Entity":"Mesure"}},"Property":"Nb of Mirror Sessions"}},"type":"Advanced","howCreated":0,"isHiddenInViewMode":false,"ordinal":0}]'}]}}

# %%
report_json.keys()
# Out:
# dict_keys(['config', 'layoutOptimization', 'resourcePackages', 'sections'])

# %%
report_json['sections'][6].keys()
# Out:
# dict_keys(['config', 'displayName', 'displayOption', 'filters', 'height', 'name', 'ordinal', 'visualContainers', 'width'])

# %%
# Initialize a set to store distinct visual types
distinct_visual_types = set()

for i in range(len(report_json['sections'][6]['visualContainers'])):
    visuel = report_json['sections'][6]['visualContainers'][i]['config']
    parsed_data = json.loads(visuel)  # Parse the JSON string
    visual_type = parsed_data.get("singleVisual", {}).get("visualType")
    
    if visual_type:  # Check if visual_type is not None
        distinct_visual_types.add(visual_type)  # Add to the set

# Print the distinct visual types
print("Distinct Visual Types:", distinct_visual_types)
# Out:
# Distinct Visual Types: {'textbox', 'image', 'clusteredColumnChart', 'donutChart', 'slicer', 'actionButton', 'card', 'shape'}

# %%
visuel_string = report_json['sections'][6]['visualContainers'][5]['config']
parsed_data = json.loads(visuel_string)
parsed_data.keys()
# Out:
# dict_keys(['name', 'layouts', 'singleVisualGroup'])

# %%
visual = parsed_data['singleVisual']
print(visual)

# Remove the 'objects' attribute
if 'objects' in visual.keys():
    print(True)
    del visual['objects']
# Out:
# {'visualType': 'card', 'projections': {'Values': [{'queryRef': 'Mesure.INCHANEL Total Users (Since Start)'}]}, 'prototypeQuery': {'Version': 2, 'From': [{'Name': 'm', 'Entity': 'Mesure', 'Type': 0}], 'Select': [{'Measure': {'Expression': {'SourceRef': {'Source': 'm'}}, 'Property': 'INCHANEL ACTIVE Users'}, 'Name': 'Mesure.INCHANEL Total Users (Since Start)', 'NativeReferenceName': 'Active Clients on the period'}], 'OrderBy': [{'Direction': 2, 'Expression': {'Measure': {'Expression': {'SourceRef': {'Source': 'm'}}, 'Property': 'INCHANEL ACTIVE Users'}}}]}, 'columnProperties': {'Mesure.INCHANEL Total Users (Since Start)': {'displayName': 'Active Clients on the period'}}, 'drillFilterOtherVisuals': True, 'hasDefaultSort': True, 'objects': {'labels': [{'properties': {'color': {'solid': {'color': {'expr': {'ThemeDataColor': {'ColorId': 1, 'Percent': 0}}}}}, 'fontSize': {'expr': {'Literal': {'Value': '25D'}}}, 'bold': {'expr': {'Literal': {'Value': 'true'}}}}}], 'categoryLabels': [{'properties': {'fontSize': {'expr': {'Literal': {'Value': '13D'}}}}}]}, 'vcObjects': {'title': [{'properties': {'titleWrap': {'expr': {'Literal': {'Value': 'true'}}}}}], 'background': [{'properties': {'show': {'expr': {'Literal': {'Value': 'false'}}}, 'transparency': {'expr': {'Literal': {'Value': '0D'}}}}}]}}
# True

# %%
visual.keys()
# Out:
# dict_keys(['visualType', 'projections', 'prototypeQuery', 'columnProperties', 'drillFilterOtherVisuals', 'hasDefaultSort', 'vcObjects'])

# %%
# Extract the visualType
visual_type = parsed_data.get("singleVisual", {}).get("visualType")

print("Visual Type:", visual_type)
# Out:
# Visual Type: image

# %%
# with open('data.json', 'w') as json_file:
#     json.dump(model_bim, json_file, indent=4)

# %% [markdown]
# ### Dataset

# %%
model_bim
# Out:
# {'compatibilityLevel': 1567,
#  'model': {'annotations': [{'name': 'PBI_QueryOrder',
#     'value': '["fact_wishlist","dim_calendar","dim_boutique","dim_client","Mesure","fact_mirror","fact_suggestion_board","fact_message","server_id","database_id","storage_id"]'},
#    {'name': '__PBI_TimeIntelligenceEnabled', 'value': '1'},
#    {'name': 'PBIDesktopVersion', 'value': '2.138.782.0 (24.11)'},
#    {'name': 'PBI_ProTooling', 'value': '["DaxQueryView_Desktop","DevMode"]'}],
#   'culture': 'fr-FR',
#   'cultures': [{'name': 'fr-FR',
#     'linguisticMetadata': {'content': {'Entities': {'dim_boutique': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique'}},
#         'State': 'Generated',
#         'Terms': [{'dim boutique': {'State': 'Generated'}},
#          {'dim_boutique': {'State': 'Generated',
#            'Type': 'Noun',
#            'Weight': 0.99}},
#          {'boutique': {'State': 'Generated', 'Weight': 0.97}}]},
#        'dim_boutique.UTC_closing_hour_summer': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'UTC closing hour (summer)'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'UTC closing hour (summer)': {'State': 'Generated'}},
#          {'time': {'State': 'Generated', 'Weight': 0.7}},
#          {'UTC closing hour': {'State': 'Generated', 'Weight': 0.75}}]},
#        'dim_boutique.UTC_closing_hour_winter': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'UTC closing hour (winter)'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'UTC closing hour (winter)': {'State': 'Generated'}},
#          {'time': {'State': 'Generated', 'Weight': 0.7}},
#          {'UTC closing hour': {'State': 'Generated', 'Weight': 0.75}}]},
#        'dim_boutique.UTC_opening_hour_summer': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'UTC opening hour (summer)'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'UTC opening hour (summer)': {'State': 'Generated'}},
#          {'time': {'State': 'Generated', 'Weight': 0.7}},
#          {'UTC opening hour': {'State': 'Generated', 'Weight': 0.75}}]},
#        'dim_boutique.UTC_opening_hour_winter': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'UTC opening hour (winter)'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'UTC opening hour (winter)': {'State': 'Generated'}},
#          {'time': {'State': 'Generated', 'Weight': 0.7}},
#          {'UTC opening hour': {'State': 'Generated', 'Weight': 0.75}}]},
#        'dim_boutique.boutique_code': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Boutique Code'}},
#         'NameType': 'Identifier',
#         'State': 'Generated',
#         'Terms': [{'boutique code': {'State': 'Generated'}},
#          {'code': {'State': 'Generated', 'Weight': 0.97}},
#          {'boutique id': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'boutique key': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}}]},
#        'dim_boutique.boutique_group_code': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Boutique Group Code'}},
#         'State': 'Generated',
#         'Terms': [{'boutique group code': {'State': 'Generated'}},
#          {'group code': {'State': 'Generated', 'Weight': 0.97}},
#          {'boutique group id': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'group id': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'boutique group key': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}},
#          {'group key': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'boutique category code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.609}},
#          {'boutique organization code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.609}},
#          {'category code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}},
#          {'organization code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}},
#          {'boutique bracket code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.591}},
#          {'boutique class code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.591}}]},
#        'dim_boutique.boutique_name': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Boutique Name'}},
#         'NameType': 'Name',
#         'State': 'Generated',
#         'Terms': [{'boutique name': {'State': 'Generated'}},
#          {'name': {'State': 'Generated', 'Weight': 0.97}},
#          {'boutique': {'State': 'Generated', 'Weight': 0.97}},
#          {'boutique nickname': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'boutique title': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'boutique label': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'boutique tag': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}}]},
#        'dim_boutique.boutique_status': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Boutique Status'}},
#         'State': 'Generated',
#         'Terms': [{'boutique status': {'State': 'Generated'}},
#          {'status': {'State': 'Generated', 'Weight': 0.97}},
#          {'boutique category': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'boutique importance': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'boutique prestige': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'boutique prominence': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'category': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}},
#          {'importance': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}},
#          {'prestige': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}},
#          {'prominence': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}},
#          {'boutique condition': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'boutique class': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}}]},
#        'dim_boutique.boutique_status_code': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Boutique Status Code'}},
#         'State': 'Generated',
#         'Terms': [{'boutique status code': {'State': 'Generated'}},
#          {'status code': {'State': 'Generated', 'Weight': 0.97}},
#          {'boutique status id': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'status id': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'boutique status key': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}},
#          {'status key': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'boutique category code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.609}},
#          {'boutique importance code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.609}},
#          {'boutique prestige code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.609}},
#          {'boutique prominence code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.609}},
#          {'category code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}},
#          {'importance code': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}}]},
#        'dim_boutique.closing_hour_local': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Closing hour (local)'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'closing hour (local)': {'State': 'Generated'}},
#          {'time': {'State': 'Generated', 'Weight': 0.7}},
#          {'closing hour': {'State': 'Generated', 'Weight': 0.75}}]},
#        'dim_boutique.country': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Country'}},
#         'State': 'Generated',
#         'Terms': [{'country': {'State': 'Generated'}},
#          {'nation': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}},
#          {'location': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}}]},
#        'dim_boutique.digital_launch_date': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Digital Launch date'}},
#         'State': 'Generated',
#         'Terms': [{'digital launch date': {'State': 'Generated'}},
#          {'launch date': {'State': 'Generated', 'Weight': 0.97}},
#          {'digital launch moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'launch moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'digital launch period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}},
#          {'launch period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}}]},
#        'dim_boutique.inchanel_launching_date': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Inchanel Launching Date'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'inchanel launching date': {'State': 'Generated'}},
#          {'date': {'State': 'Generated', 'Weight': 0.7}},
#          {'inchanel launching moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'inchanel launching period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}}]},
#        'dim_boutique.inchanel_launching_date.variation.hiérarchie_de_date': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'Hierarchy': 'Hiérarchie de dates',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Inchanel Launching Date'}},
#         'State': 'Generated',
#         'Terms': [{'hiérarchie de date': {'State': 'Generated'}},
#          {'hiérarchie de moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'hiérarchie de period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}}]},
#        'dim_boutique.inchanel_launching_date.variation.hiérarchie_de_date.année': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Année',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Inchanel Launching Date'}},
#         'State': 'Generated',
#         'Terms': [{'année': {'State': 'Generated'}},
#          {'inchanel launching date année': {'State': 'Generated'}},
#          {'inchanel launching moment année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.617}},
#          {'inchanel launching period année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.599}}]},
#        'dim_boutique.inchanel_launching_date.variation.hiérarchie_de_date.jour': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Jour',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Inchanel Launching Date'}},
#         'State': 'Generated',
#         'Terms': [{'jour': {'State': 'Generated'}},
#          {'inchanel launching date jour': {'State': 'Generated'}},
#          {'inchanel launching moment jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.617}},
#          {'inchanel launching period jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.599}}]},
#        'dim_boutique.inchanel_launching_date.variation.hiérarchie_de_date.mois': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Mois',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Inchanel Launching Date'}},
#         'State': 'Generated',
#         'Terms': [{'mois': {'State': 'Generated'}},
#          {'inchanel launching date mois': {'State': 'Generated'}},
#          {'inchanel launching moment mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.617}},
#          {'inchanel launching period mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.599}}]},
#        'dim_boutique.inchanel_launching_date.variation.hiérarchie_de_date.trimestre': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Trimestre',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Inchanel Launching Date'}},
#         'State': 'Generated',
#         'Terms': [{'trimestre': {'State': 'Generated'}},
#          {'inchanel launching date trimestre': {'State': 'Generated'}},
#          {'inchanel launching moment trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.617}},
#          {'inchanel launching period trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.599}}]},
#        'dim_boutique.market': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Market'}},
#         'State': 'Generated',
#         'Terms': [{'market': {'State': 'Generated'}},
#          {'marketplace': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.491}},
#          {'souk': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.491}},
#          {'bazaar': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.491}},
#          {'shop': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'arcade': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'fair': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}}]},
#        'dim_boutique.mirror_launch_date': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Mirror Launch date'}},
#         'State': 'Generated',
#         'Terms': [{'mirror launch date': {'State': 'Generated'}},
#          {'launch date': {'State': 'Generated', 'Weight': 0.97}},
#          {'mirror launch moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'launch moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'mirror launch period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}},
#          {'launch period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}}]},
#        'dim_boutique.opening_hour_local': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Opening hour (local)'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'opening hour (local)': {'State': 'Generated'}},
#          {'time': {'State': 'Generated', 'Weight': 0.7}},
#          {'opening hour': {'State': 'Generated', 'Weight': 0.75}}]},
#        'dim_boutique.region': {'Definition': {'Binding': {'ConceptualEntity': 'dim_boutique',
#           'ConceptualProperty': 'Region'}},
#         'State': 'Generated',
#         'Terms': [{'region': {'State': 'Generated'}},
#          {'location': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.818}},
#          {'province': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}},
#          {'area': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.714}},
#          {'district': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.714}},
#          {'section': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.714}},
#          {'zone': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.714}},
#          {'continent': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.714}}]},
#        'dim_calendar': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar'}},
#         'State': 'Generated',
#         'Terms': [{'dim calendar': {'State': 'Generated'}},
#          {'dim_calendar': {'State': 'Generated',
#            'Type': 'Noun',
#            'Weight': 0.99}},
#          {'calendar': {'State': 'Generated', 'Weight': 0.97}},
#          {'dim almanac': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.5}},
#          {'dim datebook': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.5}},
#          {'dim agenda': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.5}},
#          {'dim logbook': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.5}},
#          {'dim diary': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.5}},
#          {'almanac': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.491}},
#          {'datebook': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.491}},
#          {'agenda': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.491}},
#          {'logbook': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.491}},
#          {'diary': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.491}}]},
#        'dim_calendar.date': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'Date'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'date': {'State': 'Generated'}},
#          {'moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}},
#          {'period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.714}}]},
#        'dim_calendar.date.variation.hiérarchie_de_date': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Date'}},
#         'State': 'Generated',
#         'Terms': [{'hiérarchie de date': {'State': 'Generated'}},
#          {'hiérarchie de moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'hiérarchie de period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}}]},
#        'dim_calendar.date.variation.hiérarchie_de_date.année': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Année',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Date'}},
#         'State': 'Generated',
#         'Terms': [{'année': {'State': 'Generated'}},
#          {'date année': {'State': 'Generated'}},
#          {'moment année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}},
#          {'period année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.582}}]},
#        'dim_calendar.date.variation.hiérarchie_de_date.jour': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Jour',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Date'}},
#         'State': 'Generated',
#         'Terms': [{'jour': {'State': 'Generated'}},
#          {'date jour': {'State': 'Generated'}},
#          {'moment jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}},
#          {'period jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.582}}]},
#        'dim_calendar.date.variation.hiérarchie_de_date.mois': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Mois',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Date'}},
#         'State': 'Generated',
#         'Terms': [{'mois': {'State': 'Generated'}},
#          {'date mois': {'State': 'Generated'}},
#          {'moment mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}},
#          {'period mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.582}}]},
#        'dim_calendar.date.variation.hiérarchie_de_date.trimestre': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Trimestre',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Date'}},
#         'State': 'Generated',
#         'Terms': [{'trimestre': {'State': 'Generated'}},
#          {'date trimestre': {'State': 'Generated'}},
#          {'moment trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}},
#          {'period trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.582}}]},
#        'dim_calendar.date_ID': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'Date ID'}},
#         'State': 'Generated',
#         'Terms': [{'date ID': {'State': 'Generated'}},
#          {'date identification': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'date identity': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'date identifier': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'date credential': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'moment id': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.6}},
#          {'period id': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.582}}]},
#        'dim_calendar.end_of_the_month': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'End of the Month'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'end of the month': {'State': 'Generated'}},
#          {'completion of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.771}},
#          {'conclusion of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.771}},
#          {'expiration of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.771}},
#          {'close of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'finish of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'last of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'stop of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'closing of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'ending of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'end of the mth': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.617}}]},
#        'dim_calendar.end_of_the_month.variation.hiérarchie_de_date': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'VariationSet': 'Variation',
#           'VariationSource': 'End of the Month'}},
#         'State': 'Generated',
#         'Terms': [{'hiérarchie de date': {'State': 'Generated'}},
#          {'hiérarchie de moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'hiérarchie de period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}}]},
#        'dim_calendar.end_of_the_month.variation.hiérarchie_de_date.année': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Année',
#           'VariationSet': 'Variation',
#           'VariationSource': 'End of the Month'}},
#         'State': 'Generated',
#         'Terms': [{'année': {'State': 'Generated'}},
#          {'end of the month année': {'State': 'Generated'}},
#          {'completion of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'conclusion of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'expiration of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'close of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'finish of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'last of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'stop of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'closing of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'ending of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'end of the mth année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.624}}]},
#        'dim_calendar.end_of_the_month.variation.hiérarchie_de_date.jour': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Jour',
#           'VariationSet': 'Variation',
#           'VariationSource': 'End of the Month'}},
#         'State': 'Generated',
#         'Terms': [{'jour': {'State': 'Generated'}},
#          {'end of the month jour': {'State': 'Generated'}},
#          {'completion of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'conclusion of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'expiration of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'close of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'finish of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'last of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'stop of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'closing of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'ending of the month jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'end of the mth jour': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.624}}]},
#        'dim_calendar.end_of_the_month.variation.hiérarchie_de_date.mois': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Mois',
#           'VariationSet': 'Variation',
#           'VariationSource': 'End of the Month'}},
#         'State': 'Generated',
#         'Terms': [{'mois': {'State': 'Generated'}},
#          {'end of the month mois': {'State': 'Generated'}},
#          {'completion of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'conclusion of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'expiration of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'close of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'finish of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'last of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'stop of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'closing of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'ending of the month mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'end of the mth mois': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.624}}]},
#        'dim_calendar.end_of_the_month.variation.hiérarchie_de_date.trimestre': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Trimestre',
#           'VariationSet': 'Variation',
#           'VariationSource': 'End of the Month'}},
#         'State': 'Generated',
#         'Terms': [{'trimestre': {'State': 'Generated'}},
#          {'end of the month trimestre': {'State': 'Generated'}},
#          {'completion of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'conclusion of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'expiration of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.78}},
#          {'close of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'finish of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'last of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'stop of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'closing of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'ending of the month trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.757}},
#          {'end of the mth trimestre': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.624}}]},
#        'dim_calendar.month': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'Month'}},
#         'State': 'Generated',
#         'Terms': [{'month': {'State': 'Generated'}},
#          {'mth': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.736}}]},
#        'dim_calendar.month_year_name': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'Month_year_name'}},
#         'State': 'Generated',
#         'Terms': [{'month year name': {'State': 'Generated'}},
#          {'Month_year_name': {'State': 'Generated',
#            'Type': 'Noun',
#            'Weight': 0.99}},
#          {'month year': {'State': 'Generated', 'Weight': 0.97}},
#          {'year name': {'State': 'Generated', 'Weight': 0.97}},
#          {'month yr': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.75}},
#          {'month year nickname': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}},
#          {'month year title': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}},
#          {'month year label': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}},
#          {'month year tag': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}},
#          {'year nickname': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'year title': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'year label': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'year tag': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.727}},
#          {'mth year name': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.609}}]},
#        'dim_calendar.name_of_the_month': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'Name of the month'}},
#         'State': 'Generated',
#         'Terms': [{'name of the month': {'State': 'Generated'}},
#          {'nickname of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'title of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'label of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'tag of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.748}},
#          {'name of the mth': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.617}}]},
#        'dim_calendar.primary_key': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'PrimaryKey'}},
#         'State': 'Generated',
#         'Terms': [{'primary key': {'State': 'Generated'}},
#          {'PrimaryKey': {'State': 'Generated',
#            'Type': 'Noun',
#            'Weight': 0.99}},
#          {'key': {'State': 'Generated', 'Weight': 0.97}},
#          {'main': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'basic': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'fundamental': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'central': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'major': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'keynote': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'essential': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.476}},
#          {'primary solution': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.475}},
#          {'primary explanation': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.475}},
#          {'primary basis': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.475}}]},
#        'dim_calendar.quanter': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'Quanter'}},
#         'State': 'Generated',
#         'Terms': [{'quanter': {'State': 'Generated'}}]},
#        'dim_calendar.start_of_the_month': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'ConceptualProperty': 'Start of the Month'}},
#         'SemanticType': 'Time',
#         'State': 'Generated',
#         'Terms': [{'start of the month': {'State': 'Generated'}},
#          {'start of the mth': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.617}},
#          {'twitch of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.499}},
#          {'jump of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.499}},
#          {'jerk of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.499}},
#          {'flinch of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.499}},
#          {'jolt of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.499}},
#          {'shock of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.474}},
#          {'fright of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.474}},
#          {'surprise of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.474}},
#          {'turn of the month': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.474}}]},
#        'dim_calendar.start_of_the_month.variation.hiérarchie_de_date': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Start of the Month'}},
#         'State': 'Generated',
#         'Terms': [{'hiérarchie de date': {'State': 'Generated'}},
#          {'hiérarchie de moment': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.762}},
#          {'hiérarchie de period': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.739}}]},
#        'dim_calendar.start_of_the_month.variation.hiérarchie_de_date.année': {'Definition': {'Binding': {'ConceptualEntity': 'dim_calendar',
#           'Hierarchy': 'Hiérarchie de dates',
#           'HierarchyLevel': 'Année',
#           'VariationSet': 'Variation',
#           'VariationSource': 'Start of the Month'}},
#         'State': 'Generated',
#         'Terms': [{'année': {'State': 'Generated'}},
#          {'start of the month année': {'State': 'Generated'}},
#          {'start of the mth année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.624}},
#          {'twitch of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.504}},
#          {'jump of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.504}},
#          {'jerk of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.504}},
#          {'flinch of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.504}},
#          {'jolt of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.504}},
#          {'shock of the month année': {'Source': {'Agent': 'Thesaurus'},
#            'State': 'Suggested',
#            'Type': 'Noun',
#            'Weight': 0.479}},
#          {'fright of the month année': {'Source': {'Agent': 'Thesaurus'},
# ...
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Year'}],
#       'dataCategory': 'Years',
#       'dataType': 'int64',
#       'expression': 'YEAR([Date])',
#       'isHidden': True,
#       'lineageTag': 'e2ce4443-32ee-4850-8de1-71ba410a733e',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'NoMois',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'MonthNumber'}],
#       'dataCategory': 'MonthOfYear',
#       'dataType': 'int64',
#       'expression': 'MONTH([Date])',
#       'isHidden': True,
#       'lineageTag': '9afd518b-670c-45b7-b633-d73edc7f10ff',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Mois',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Month'}],
#       'dataCategory': 'Months',
#       'dataType': 'string',
#       'expression': 'FORMAT([Date], "MMMM")',
#       'isHidden': True,
#       'lineageTag': 'e5bc5964-d14c-4d1d-b10f-89f3fcd53372',
#       'sortByColumn': 'NoMois',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'NoTrimestre',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'QuarterNumber'}],
#       'dataCategory': 'QuarterOfYear',
#       'dataType': 'int64',
#       'expression': 'INT(([NoMois] + 2) / 3)',
#       'isHidden': True,
#       'lineageTag': '6a7f77e7-aa0e-4192-b827-ddfa40e101b0',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Trimestre',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Quarter'}],
#       'dataCategory': 'Quarters',
#       'dataType': 'string',
#       'expression': '"Trim " & [NoTrimestre]',
#       'isHidden': True,
#       'lineageTag': '90c615b6-a99c-4063-8312-ded188c0eff4',
#       'sortByColumn': 'NoTrimestre',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Jour',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Day'}],
#       'dataCategory': 'DayOfMonth',
#       'dataType': 'int64',
#       'expression': 'DAY([Date])',
#       'isHidden': True,
#       'lineageTag': 'e1c57694-dd61-4e9a-8b61-542b8d57b63b',
#       'summarizeBy': 'none',
#       'type': 'calculated'}],
#     'hierarchies': [{'name': 'Hiérarchie de dates',
#       'annotations': [{'name': 'TemplateId', 'value': 'DateHierarchy'}],
#       'levels': [{'name': 'Année',
#         'column': 'Année',
#         'lineageTag': '27c827f3-c618-46dd-aad1-bc58e0e4a776',
#         'ordinal': 0},
#        {'name': 'Trimestre',
#         'column': 'Trimestre',
#         'lineageTag': '01c9bb73-6f98-49bb-a04a-d89fbd78467c',
#         'ordinal': 1},
#        {'name': 'Mois',
#         'column': 'Mois',
#         'lineageTag': 'cf3802af-9b28-4430-8845-05809cbb511d',
#         'ordinal': 2},
#        {'name': 'Jour',
#         'column': 'Jour',
#         'lineageTag': 'c51a37eb-064e-4089-b1b9-039dc1fe1604',
#         'ordinal': 3}],
#       'lineageTag': '84215edc-17c6-4dcb-8abd-8026f4cd16ff'}],
#     'isHidden': True,
#     'lineageTag': '2c269409-520b-4dae-8a81-4272dbfd3afa',
#     'partitions': [{'name': 'LocalDateTable_b6d04e11-7818-41c0-8252-5404c06b34b3',
#       'mode': 'import',
#       'source': {'expression': "Calendar(Date(Year(MIN('fact_mirror'[dtm_lastupdate])), 1, 1), Date(Year(MAX('fact_mirror'[dtm_lastupdate])), 12, 31))",
#        'type': 'calculated'}}],
#     'showAsVariationsOnly': True},
#    {'name': 'LocalDateTable_b7b7c7a9-0a88-4ce3-8981-443a5a749dea',
#     'annotations': [{'name': '__PBI_LocalDateTable', 'value': 'true'}],
#     'columns': [{'name': 'Date',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'}],
#       'dataCategory': 'PaddedDateTableDates',
#       'dataType': 'dateTime',
#       'isHidden': True,
#       'isNameInferred': True,
#       'lineageTag': 'f0b923ee-8a7e-48a3-9619-539a948f91e0',
#       'sourceColumn': '[Date]',
#       'summarizeBy': 'none',
#       'type': 'calculatedTableColumn'},
#      {'name': 'Année',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Year'}],
#       'dataCategory': 'Years',
#       'dataType': 'int64',
#       'expression': 'YEAR([Date])',
#       'isHidden': True,
#       'lineageTag': 'c41298c9-1f96-4916-ad86-a228c750dd4c',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'NoMois',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'MonthNumber'}],
#       'dataCategory': 'MonthOfYear',
#       'dataType': 'int64',
#       'expression': 'MONTH([Date])',
#       'isHidden': True,
#       'lineageTag': 'b55d1999-5901-4801-ab70-2247d57b1055',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Mois',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Month'}],
#       'dataCategory': 'Months',
#       'dataType': 'string',
#       'expression': 'FORMAT([Date], "MMMM")',
#       'isHidden': True,
#       'lineageTag': '47e46db2-8102-43ff-8222-56abb101b7f3',
#       'sortByColumn': 'NoMois',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'NoTrimestre',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'QuarterNumber'}],
#       'dataCategory': 'QuarterOfYear',
#       'dataType': 'int64',
#       'expression': 'INT(([NoMois] + 2) / 3)',
#       'isHidden': True,
#       'lineageTag': '42a1b3d2-8848-42ab-9d86-36521ad14029',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Trimestre',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Quarter'}],
#       'dataCategory': 'Quarters',
#       'dataType': 'string',
#       'expression': '"Trim " & [NoTrimestre]',
#       'isHidden': True,
#       'lineageTag': '3e65296b-cbb3-42a6-9a01-d1a138ca9d4a',
#       'sortByColumn': 'NoTrimestre',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Jour',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Day'}],
#       'dataCategory': 'DayOfMonth',
#       'dataType': 'int64',
#       'expression': 'DAY([Date])',
#       'isHidden': True,
#       'lineageTag': '93ab9a78-834d-4b44-b4f6-3c70d3444621',
#       'summarizeBy': 'none',
#       'type': 'calculated'}],
#     'hierarchies': [{'name': 'Hiérarchie de dates',
#       'annotations': [{'name': 'TemplateId', 'value': 'DateHierarchy'}],
#       'levels': [{'name': 'Année',
#         'column': 'Année',
#         'lineageTag': '54ac0628-2d46-4cb5-a4fc-70eeda08b4ea',
#         'ordinal': 0},
#        {'name': 'Trimestre',
#         'column': 'Trimestre',
#         'lineageTag': '74fda4b7-e00f-4c0c-8ed1-d51b46b2811f',
#         'ordinal': 1},
#        {'name': 'Mois',
#         'column': 'Mois',
#         'lineageTag': '6cd34242-de79-4bde-a31e-b6fb0e07c129',
#         'ordinal': 2},
#        {'name': 'Jour',
#         'column': 'Jour',
#         'lineageTag': '91dc5afb-0caf-4da6-b7a1-44abf330969e',
#         'ordinal': 3}],
#       'lineageTag': '45c5bd69-8c5f-4c14-a5ce-8e6ffed78c83'}],
#     'isHidden': True,
#     'lineageTag': 'b13c93a2-9714-4b68-afd6-0a160bd4c761',
#     'partitions': [{'name': 'LocalDateTable_b7b7c7a9-0a88-4ce3-8981-443a5a749dea',
#       'mode': 'import',
#       'source': {'expression': "Calendar(Date(Year(MIN('fact_mirror'[experience_starting_time])), 1, 1), Date(Year(MAX('fact_mirror'[experience_starting_time])), 12, 31))",
#        'type': 'calculated'}}],
#     'showAsVariationsOnly': True},
#    {'name': 'LocalDateTable_77ee9777-3f8a-4f4a-91db-c0373d5b761f',
#     'annotations': [{'name': '__PBI_LocalDateTable', 'value': 'true'}],
#     'columns': [{'name': 'Date',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'}],
#       'dataCategory': 'PaddedDateTableDates',
#       'dataType': 'dateTime',
#       'isHidden': True,
#       'isNameInferred': True,
#       'lineageTag': '419adbd5-5050-4454-8feb-ce1d57a08d2c',
#       'sourceColumn': '[Date]',
#       'summarizeBy': 'none',
#       'type': 'calculatedTableColumn'},
#      {'name': 'Année',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Year'}],
#       'dataCategory': 'Years',
#       'dataType': 'int64',
#       'expression': 'YEAR([Date])',
#       'isHidden': True,
#       'lineageTag': '260e7eb2-877c-4c5c-a4a7-cc43482174b4',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'NoMois',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'MonthNumber'}],
#       'dataCategory': 'MonthOfYear',
#       'dataType': 'int64',
#       'expression': 'MONTH([Date])',
#       'isHidden': True,
#       'lineageTag': '5ba82e9f-2dd2-4790-b78c-d29d8eac17ca',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Mois',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Month'}],
#       'dataCategory': 'Months',
#       'dataType': 'string',
#       'expression': 'FORMAT([Date], "MMMM")',
#       'isHidden': True,
#       'lineageTag': '664ae2aa-82ea-4443-9f02-185f83e43bce',
#       'sortByColumn': 'NoMois',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'NoTrimestre',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'QuarterNumber'}],
#       'dataCategory': 'QuarterOfYear',
#       'dataType': 'int64',
#       'expression': 'INT(([NoMois] + 2) / 3)',
#       'isHidden': True,
#       'lineageTag': '39755172-1cd6-4458-8289-2f0d388ce584',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Trimestre',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Quarter'}],
#       'dataCategory': 'Quarters',
#       'dataType': 'string',
#       'expression': '"Trim " & [NoTrimestre]',
#       'isHidden': True,
#       'lineageTag': '3032b1c1-e49d-4392-91bb-497787038953',
#       'sortByColumn': 'NoTrimestre',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Jour',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Day'}],
#       'dataCategory': 'DayOfMonth',
#       'dataType': 'int64',
#       'expression': 'DAY([Date])',
#       'isHidden': True,
#       'lineageTag': 'ddfc311f-ebed-4aba-8da4-2a6edcf69d95',
#       'summarizeBy': 'none',
#       'type': 'calculated'}],
#     'hierarchies': [{'name': 'Hiérarchie de dates',
#       'annotations': [{'name': 'TemplateId', 'value': 'DateHierarchy'}],
#       'levels': [{'name': 'Année',
#         'column': 'Année',
#         'lineageTag': 'e66b61c0-5798-4fde-b992-09147355b0d0',
#         'ordinal': 0},
#        {'name': 'Trimestre',
#         'column': 'Trimestre',
#         'lineageTag': '01a66341-50f3-4c79-945b-4f30509ed67c',
#         'ordinal': 1},
#        {'name': 'Mois',
#         'column': 'Mois',
#         'lineageTag': '2e25c170-a4c9-44d4-b69e-96909a3efdd5',
#         'ordinal': 2},
#        {'name': 'Jour',
#         'column': 'Jour',
#         'lineageTag': 'a3070ef7-cc26-451a-882b-831f21e1089a',
#         'ordinal': 3}],
#       'lineageTag': '0a32802a-67c2-4b7a-b30a-26b7c2d02c76'}],
#     'isHidden': True,
#     'lineageTag': 'e93d7927-bf2b-4582-83f4-b08659688114',
#     'partitions': [{'name': 'LocalDateTable_77ee9777-3f8a-4f4a-91db-c0373d5b761f',
#       'mode': 'import',
#       'source': {'expression': "Calendar(Date(Year(MIN('fact_mirror'[experience_ending_date])), 1, 1), Date(Year(MAX('fact_mirror'[experience_ending_date])), 12, 31))",
#        'type': 'calculated'}}],
#     'showAsVariationsOnly': True},
#    {'name': 'LocalDateTable_e91d7dbb-0364-4129-bd81-abaa8064afc2',
#     'annotations': [{'name': '__PBI_LocalDateTable', 'value': 'true'}],
#     'columns': [{'name': 'Date',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'}],
#       'dataCategory': 'PaddedDateTableDates',
#       'dataType': 'dateTime',
#       'isHidden': True,
#       'isNameInferred': True,
#       'lineageTag': '2c18d110-9629-4deb-8a73-5316040821f4',
#       'sourceColumn': '[Date]',
#       'summarizeBy': 'none',
#       'type': 'calculatedTableColumn'},
#      {'name': 'Année',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Year'}],
#       'dataCategory': 'Years',
#       'dataType': 'int64',
#       'expression': 'YEAR([Date])',
#       'isHidden': True,
#       'lineageTag': 'b6c892d0-dcff-480f-89dd-a2a1be959872',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'NoMois',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'MonthNumber'}],
#       'dataCategory': 'MonthOfYear',
#       'dataType': 'int64',
#       'expression': 'MONTH([Date])',
#       'isHidden': True,
#       'lineageTag': '48cacace-177a-433c-9467-1cb2386e0529',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Mois',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Month'}],
#       'dataCategory': 'Months',
#       'dataType': 'string',
#       'expression': 'FORMAT([Date], "MMMM")',
#       'isHidden': True,
#       'lineageTag': '3e529c08-c3ae-4520-8584-717b4512ace4',
#       'sortByColumn': 'NoMois',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'NoTrimestre',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'QuarterNumber'}],
#       'dataCategory': 'QuarterOfYear',
#       'dataType': 'int64',
#       'expression': 'INT(([NoMois] + 2) / 3)',
#       'isHidden': True,
#       'lineageTag': '45ecf62d-c2f2-4587-89b7-78620c0438e6',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Trimestre',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Quarter'}],
#       'dataCategory': 'Quarters',
#       'dataType': 'string',
#       'expression': '"Trim " & [NoTrimestre]',
#       'isHidden': True,
#       'lineageTag': '7501f531-d38e-489f-abe5-2722254cd155',
#       'sortByColumn': 'NoTrimestre',
#       'summarizeBy': 'none',
#       'type': 'calculated'},
#      {'name': 'Jour',
#       'annotations': [{'name': 'SummarizationSetBy', 'value': 'User'},
#        {'name': 'TemplateId', 'value': 'Day'}],
#       'dataCategory': 'DayOfMonth',
#       'dataType': 'int64',
#       'expression': 'DAY([Date])',
#       'isHidden': True,
#       'lineageTag': 'e28dd675-2b9d-44dd-a257-02a77814c5be',
#       'summarizeBy': 'none',
#       'type': 'calculated'}],
#     'hierarchies': [{'name': 'Hiérarchie de dates',
#       'annotations': [{'name': 'TemplateId', 'value': 'DateHierarchy'}],
#       'levels': [{'name': 'Année',
#         'column': 'Année',
#         'lineageTag': '2198fa10-8a8c-408b-97b6-77756ed60629',
#         'ordinal': 0},
#        {'name': 'Trimestre',
#         'column': 'Trimestre',
#         'lineageTag': 'ab07b79f-19ac-47e6-bfcd-54252ba16f33',
#         'ordinal': 1},
#        {'name': 'Mois',
#         'column': 'Mois',
#         'lineageTag': '7a9d0065-923c-4290-a8e7-f0c6d9134b25',
#         'ordinal': 2},
#        {'name': 'Jour',
#         'column': 'Jour',
#         'lineageTag': '59bb79b6-4865-46e0-8a70-53fd5eb88d5f',
#         'ordinal': 3}],
#       'lineageTag': '9acb090d-c2b8-4348-97a7-bc21a020c432'}],
#     'isHidden': True,
#     'lineageTag': 'e47aa26c-ee4b-4b88-8a0d-467765c9037d',
#     'partitions': [{'name': 'LocalDateTable_e91d7dbb-0364-4129-bd81-abaa8064afc2',
#       'mode': 'import',
#       'source': {'expression': "Calendar(Date(Year(MIN('fact_mirror'[experience_ending_time])), 1, 1), Date(Year(MAX('fact_mirror'[experience_ending_time])), 12, 31))",
#        'type': 'calculated'}}],
#     'showAsVariationsOnly': True}]}}

# %%
model_bim['model'].keys()
# Out:
# dict_keys(['annotations', 'culture', 'cultures', 'dataAccessOptions', 'defaultPowerBIDataSourceVersion', 'expressions', 'queryGroups', 'relationships', 'sourceQueryCulture', 'tables'])

# %%
model_bim['model']['expressions']
# Out:
# [{'name': 'server_id',
#   'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#    {'name': 'PBI_ResultType', 'value': 'Text'}],
#   'description': 'Azure server name',
#   'expression': '"asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#   'kind': 'm',
#   'lineageTag': 'acf363bb-3a3b-4c63-8ce9-64df713220f6',
#   'queryGroup': 'parameters'},
#  {'name': 'database_id',
#   'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#    {'name': 'PBI_ResultType', 'value': 'Text'}],
#   'expression': '"dhfsh-gold" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#   'kind': 'm',
#   'lineageTag': 'a29a4a2c-53d5-46aa-a171-21ed366054bd',
#   'queryGroup': 'parameters'},
#  {'name': 'storage_id',
#   'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#    {'name': 'PBI_ResultType', 'value': 'Text'}],
#   'description': 'Azure blob storage id',
#   'expression': '"sastddthglbfsh1rawweuuat" meta [IsParameterQuery=true, Type="Any", IsParameterQueryRequired=true]',
#   'kind': 'm',
#   'lineageTag': 'cb07b717-ca14-4a97-9812-d5f687ce77b9',
#   'queryGroup': 'parameters'}]

# %%
model_bim['model']['relationships']
# Out:
# [{'name': 'f14ab861-6de1-4ee5-83f7-0d54e5b5938c',
#   'fromColumn': 'Date',
#   'fromTable': 'dim_calendar',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_822da7e9-510e-4037-be69-095aaa0a2010'},
#  {'name': 'c9107009-412b-4574-980c-7ed8c5a62a86',
#   'fromColumn': 'Start of the Month',
#   'fromTable': 'dim_calendar',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_4de7692d-409c-4065-9503-d0b84e2f7489'},
#  {'name': '3b1de498-ce49-4932-8bda-832bd1565be8',
#   'fromColumn': 'End of the Month',
#   'fromTable': 'dim_calendar',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_9a1422c1-22fb-462c-9059-dcf138aec3e7'},
#  {'name': '24216199-4312-4a98-852f-b1a9e44c6405',
#   'fromColumn': 'Start of the Week',
#   'fromTable': 'dim_calendar',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_fdf3cfa6-ac4f-4279-80cf-cd75cf0f5ed8'},
#  {'name': '674c4005-e1ae-4490-9c9e-d75173bc9f7c',
#   'fromColumn': 'dtm_experiencestarting',
#   'fromTable': 'fact_mirror',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_b967f1b3-99af-4a56-a8c8-5115a090d2e8'},
#  {'name': '1d2a6e8d-ff99-4087-bcb3-a41a20a3404a',
#   'fromColumn': 'dtm_experienceending',
#   'fromTable': 'fact_mirror',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_abff6ddb-74f8-4e28-98b7-1cb2763daf96'},
#  {'name': 'cf1574a2-f761-4d82-943b-e6b91c69e89b',
#   'fromColumn': 'Inchanel Launching Date',
#   'fromTable': 'dim_boutique',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_de807e5e-d6db-488d-ac38-bb0d956e632e'},
#  {'name': '9353ca34-cd7b-280f-5433-931a87419fb1',
#   'fromColumn': 'lab_updatestatus',
#   'fromTable': 'fact_wishlist',
#   'toColumn': 'Date',
#   'toTable': 'dim_calendar'},
#  {'name': 'c87e5af8-63ac-02d2-942c-a67860be8d51',
#   'fromColumn': 'dtm_createdat',
#   'fromTable': 'fact_message',
#   'toColumn': 'Date',
#   'toTable': 'dim_calendar'},
#  {'name': 'b745ebb9-8178-d650-33f2-73e9b5f23ee1',
#   'fromColumn': 'dtm_dateofonboarding',
#   'fromTable': 'dim_client',
#   'toColumn': 'Date',
#   'toTable': 'dim_calendar'},
#  {'name': '1c542d6c-d576-4003-b820-2d7dc763db54',
#   'fromColumn': 'dtm_lastupdate',
#   'fromTable': 'fact_mirror',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_b6d04e11-7818-41c0-8252-5404c06b34b3'},
#  {'name': 'ce1c1e6c-247f-789d-b6bd-f533d7f8cf7b',
#   'fromColumn': 'experience_starting_date',
#   'fromTable': 'fact_mirror',
#   'toColumn': 'Date',
#   'toTable': 'dim_calendar'},
#  {'name': '5edf97e5-2dfa-4184-9346-5f07102b71fd',
#   'fromColumn': 'experience_starting_time',
#   'fromTable': 'fact_mirror',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_b7b7c7a9-0a88-4ce3-8981-443a5a749dea'},
#  {'name': '6bbf3867-3ff9-4ffc-9ed5-4d221b7defc8',
#   'fromColumn': 'experience_ending_date',
#   'fromTable': 'fact_mirror',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_77ee9777-3f8a-4f4a-91db-c0373d5b761f'},
#  {'name': 'dee10df1-8da8-47e0-99ee-2edbad3f2f19',
#   'fromColumn': 'experience_ending_time',
#   'fromTable': 'fact_mirror',
#   'joinOnDateBehavior': 'datePartOnly',
#   'toColumn': 'Date',
#   'toTable': 'LocalDateTable_e91d7dbb-0364-4129-bd81-abaa8064afc2'},
#  {'name': 'f9da5c3e-35c2-7acd-6803-7cf5aed38a20',
#   'fromColumn': 'dtm_publication',
#   'fromTable': 'fact_suggestion_board',
#   'toColumn': 'Date',
#   'toTable': 'dim_calendar'},
#  {'name': '872aa289-7fa2-4272-7bb4-5180a1b03676',
#   'fromColumn': 'fky_boutique',
#   'fromTable': 'fact_mirror',
#   'toColumn': 'Boutique Code',
#   'toTable': 'dim_boutique'},
#  {'name': '9bcb9828-f1dd-3ca0-f8b1-3af228795bdc',
#   'fromColumn': 'fky_boutique',
#   'fromTable': 'dim_client',
#   'toColumn': 'Boutique Code',
#   'toTable': 'dim_boutique'}]

# %%
# Define the keywords to exclude
excluded_keywords = ["LocalDateTable", "DateTableTemplate"]

included_table = []
for i in range(len(model_bim['model']['tables'])):
    # Check if the name does not contain any excluded keyword
    if not any(keyword in model_bim['model']['tables'][i]['name'] for keyword in excluded_keywords):
        included_table.append(model_bim['model']['tables'][i])
        # Print the name of the included table
        print(model_bim['model']['tables'][i]['name'])
# Out:
# fact_wishlist
# dim_calendar
# Mesure
# fact_mirror
# fact_suggestion_board
# fact_message
# dim_client
# dim_boutique

# %%
len(included_table)
# Out:
# 8

# %%
model_bim['model']['tables'][8]['partitions']
# Out:
# [{'name': 'fact_mirror',
#   'mode': 'import',
#   'queryGroup': 'fact',
#   'source': {'expression': ['let',
#     '    Source = Sql.Database(',
#     '        "asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net", ',
#     '        database_id, ',
#     '        [Query = "SELECT *',
#     '                  FROM OPENROWSET(',
#     '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_mirror/\',',
#     "                        FORMAT = 'DELTA'",
#     '                    ) AS [result]"',
#     '        ]',
#     '    )',
#     'in',
#     '    Source'],
#    'type': 'm'}}]

# %%
model_bim['model']['tables'][7].keys()
# Out:
# dict_keys(['name', 'annotations', 'lineageTag', 'measures', 'partitions'])

# %%
model = model_bim['model']

# Define the keywords to exclude
excluded_keywords = ["LocalDateTable", "DateTableTemplate"]
all_measures =[]
# Filter tables to exclude ones containing the excluded keywords
for table in model.get("tables", []):
    if not any(keyword in table['name'] for keyword in excluded_keywords):
        print(table['name'])
        print(table['partitions'])
# Out:
# fact_wishlist
# [{'name': 'fact_wishlist', 'mode': 'import', 'queryGroup': 'fact', 'source': {'expression': ['let', '    Source = Sql.Database(', '        server_id, ', '        database_id, ', '        [Query = "SELECT *', '                  FROM OPENROWSET(', '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_wishlist/\',', "                        FORMAT = 'DELTA'", '                    ) AS [result]"', '        ]', '    ),', '    #"Modify Date Column Format" = Table.TransformColumnTypes(Source,{{"lab_updatestatus", type date}}),', '    #"Lignes filtrées" = Table.SelectRows(#"Modify Date Column Format", each true)', 'in', '    #"Lignes filtrées"'], 'type': 'm'}}]
# dim_calendar
# [{'name': 'dim_calendar', 'mode': 'import', 'queryGroup': 'dimension', 'source': {'expression': ['let', '    Source = let', '    Source = let', '    Source = "",', '    StartDate = #date(2019, 1, 1),', '    EndDate = #date(2029, 1, 1),', '    Duration = Duration.Days(EndDate - StartDate),', '    DefineInterval = List.Dates(StartDate, Duration, #duration(1, 0, 0, 0)),', '    ConvertToTable = Table.FromList(DefineInterval, Splitter.SplitByNothing(), null, null, ExtraValues.Error),', '    RenameColumns = Table.RenameColumns(ConvertToTable, {{"Column1", "Date"}}),', '    ModifyType = Table.TransformColumnTypes(RenameColumns, {{"Date", type date}}),', '    AddDateID = Table.AddColumn(ModifyType, "Date ID", each Date.ToText([Date], "YYYYMMDD")),', '    ReorderColumns = Table.ReorderColumns(AddDateID, {"Date ID", "Date"}),', '    AddYearColumn = Table.AddColumn(ReorderColumns, "Année", each Date.Year([Date]), Int64.Type),', '    ModifyYearType = Table.TransformColumnTypes(AddYearColumn, {{"Année", type text}}),', '    AddMonthColumn = Table.AddColumn(ModifyYearType, "Mois", each Date.Month([Date]), Int64.Type),', '    AddQuarterColumn = Table.AddColumn(AddMonthColumn, "Trimestre", each Date.QuarterOfYear([Date]), Int64.Type),', '    AddStartOfMonth = Table.AddColumn(AddQuarterColumn, "Début de mois", each Date.StartOfMonth([Date]), type date),', '    AddEndOfMonth = Table.AddColumn(AddStartOfMonth, "Fin du mois", each Date.EndOfMonth([Date]), type date),', '    AddNameOfMonth = Table.AddColumn(AddEndOfMonth, "Nom du mois", each Date.MonthName([Date]), type text),', '    AddMonthYearName = Table.AddColumn(AddNameOfMonth, "Month_year_name", each [Nom du mois] & " " & [Année]),', '    AddStartOfWeek = Table.AddColumn(AddMonthYearName, "Début de semaine", each Date.StartOfWeek([Date]), type date),', '    AddIndexColumn = Table.AddIndexColumn(AddStartOfWeek, "PrimaryKey", 1, 1, Int64.Type),', '    RenameFinalColumns = Table.RenameColumns(AddIndexColumn, {{"Année", "Year"}, {"Mois", "Month"}, {"Trimestre", "Quanter"}, {"Début de mois", "Start of the Month"}, {"Nom du mois", "Name of the month"}, {"Fin du mois", "End of the Month"}, {"Début de semaine", "Start of the Week"}})', 'in', '    RenameFinalColumns', 'in', '    Source', 'in', '    Source'], 'type': 'm'}}]
# Mesure
# [{'name': 'Mesure', 'mode': 'import', 'source': {'expression': ['let', '    Source = Table.FromRows(Json.Document(Binary.Decompress(Binary.FromText("i44FAA==", BinaryEncoding.Base64), Compression.Deflate)), let _t = ((type nullable text) meta [Serialized.Text = true]) in type table [temp = _t]),', '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"temp", type text}}),', '    #"Colonnes supprimées" = Table.RemoveColumns(#"Type modifié",{"temp"})', 'in', '    #"Colonnes supprimées"'], 'type': 'm'}}]
# fact_mirror
# [{'name': 'fact_mirror', 'mode': 'import', 'queryGroup': 'fact', 'source': {'expression': ['let', '    Source = Sql.Database(', '        "asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net", ', '        database_id, ', '        [Query = "SELECT *', '                  FROM OPENROWSET(', '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_mirror/\',', "                        FORMAT = 'DELTA'", '                    ) AS [result]"', '        ]', '    )', 'in', '    Source'], 'type': 'm'}}]
# fact_suggestion_board
# [{'name': 'fact_suggestion_board', 'mode': 'import', 'queryGroup': 'fact', 'source': {'expression': ['let', '    Source = Sql.Database(', '        server_id, ', '        database_id, ', '        [Query = "SELECT *', '                  FROM OPENROWSET(', '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_suggestion_board/\',', "                        FORMAT = 'DELTA'", '                    ) AS [result]"', '        ]', '    ),', '    #"Modify Date Column Format" = Table.TransformColumnTypes(Source,{{"dtm_publication", type date}})', 'in', '    #"Modify Date Column Format"'], 'type': 'm'}}]
# fact_message
# [{'name': 'fact_message', 'mode': 'import', 'queryGroup': 'fact', 'source': {'expression': ['let', '    Source = Sql.Database(', '        server_id, ', '        database_id, ', '        [Query = "SELECT *', '                  FROM OPENROWSET(', '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_message/\',', "                        FORMAT = 'DELTA'", '                    ) AS [result]"', '        ]', '    ),', '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"dtm_createdat", type date}})', 'in', '    #"Type modifié"'], 'type': 'm'}}]
# dim_client
# [{'name': 'dim_client', 'mode': 'import', 'queryGroup': 'dimension', 'source': {'expression': ['let', '    Source = Sql.Database(', '        server_id, ', '        database_id, ', '        [Query = "SELECT *', '                  FROM OPENROWSET(', '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/dimension/dim_client/\',', "                        FORMAT = 'DELTA'", '                    ) AS [result]"', '        ]', '    ),', '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"dtm_dateofonboarding", type date}})', 'in', '    #"Type modifié"'], 'type': 'm'}}]
# dim_boutique
# [{'name': 'dim_boutique', 'mode': 'import', 'queryGroup': 'dimension', 'source': {'expression': ['let', '    // Load files from SharePoint folder', '    Source = SharePoint.Files("https://lpl.sharepoint.com/sites/PERFORMANCETEAM", [ApiVersion = 15]),', '', '    // Filter to the specific folder path', '    FilteredRows = Table.SelectRows(Source, each [Folder Path] = "https://lpl.sharepoint.com/sites/PERFORMANCETEAM/Documents partages/Dashboard/DATA & MONITORING/INCHANEL/COUCHE GOLD/DIM BOUTIQUE/"),', '', '    // Select the specific file', '    BoutiqueReferenceFile = FilteredRows{[Name = "Référentiel boutiques InChanel.xlsx", Folder Path = "https://lpl.sharepoint.com/sites/PERFORMANCETEAM/Documents partages/Dashboard/DATA & MONITORING/INCHANEL/COUCHE GOLD/DIM BOUTIQUE/"]}[Content],', '', '    // Load the Excel file', '    ImportedExcel = Excel.Workbook(BoutiqueReferenceFile),', '', '    // Get the data from the specific sheet', '    BoutiqueSheet = ImportedExcel{[Item = "REFERENTIEL BOUTIQUES INCHANEL", Kind = "Sheet"]}[Data],', '', '    // Filter non-null rows from the source', '    FilteredSourceRows = Table.SelectRows(BoutiqueSheet, each [Column6] <> null),', '', '    // Promote headers', '    PromotedHeaders = Table.PromoteHeaders(FilteredSourceRows, [PromoteAllScalars = true]),', '', '    // Change column types', '    ChangedColumnTypes = Table.TransformColumnTypes(', '        PromotedHeaders,', '        {', '            {"Region", type text}, ', '            {"Market", type text}, ', '            {"Country", type text}, ', '            {"Boutique Name", type text}, ', '            {"Boutique Group Code", type any}, ', '            {"Boutique STAR Code", type text}, ', '            {"Inchanel Launching Date", type date}, ', '            {"Boutique Status", type text}, ', '            {"Boutique Status Code", Int64.Type}, ', '            {"Mirror Launch date", type any}, ', '            {"Digital Launch date", type text}, ', '            {"Opening hour (local)", type time}, ', '            {"Closing hour (local)", type time}, ', '            {"UTC opening hour (summer)", type time}, ', '            {"UTC closing hour (summer)", type time}, ', '            {"UTC opening hour (winter)", type time},', '            {"UTC closing hour (winter)", type time},', '            {"Code boutique mirror ", type text}', '        }', '    ),', '', '    // Filter rows where "Code boutique mirror" is not null', '    FilteredMirrorCodeRows = Table.SelectRows(ChangedColumnTypes, each [#"Code boutique mirror "] <> null),', '', '    // Remove "Boutique STAR Code" column', '    RemovedBoutiqueStarCode = Table.RemoveColumns(FilteredMirrorCodeRows, {"Boutique STAR Code"}),', '', '    // Remove duplicates based on "Code boutique mirror"', '    DistinctMirrorCode = Table.Distinct(RemovedBoutiqueStarCode, {"Code boutique mirror "}),', '', '    // Rename "Code boutique mirror" to "Boutique STAR Code"', '    RenamedColumns = Table.RenameColumns(DistinctMirrorCode, {{"Code boutique mirror ", "Boutique STAR Code"}}),', '', '    // Combine the original table and the updated table', '    CombinedTable = Table.Combine({ChangedColumnTypes, RenamedColumns}),', '', '    // Remove the redundant "Code boutique mirror" column', '    FinalResult = Table.RemoveColumns(CombinedTable, {"Code boutique mirror "}),', '    RenameColumn = Table.RenameColumns(FinalResult,{{"Boutique STAR Code", "Boutique Code"}})', 'in', '    RenameColumn'], 'type': 'm'}}]

# %%
model = model_bim['model']

# Define the keywords to exclude
excluded_keywords = ["LocalDateTable", "DateTableTemplate"]
all_measures =[]
# Filter tables to exclude ones containing the excluded keywords
for table in model.get("tables", []):
    if not any(keyword in table['name'] for keyword in excluded_keywords):
        if "measures" in table.keys():
            print("the table {} contains measures".format(table['name']))
            for measure in table['measures']:
                all_measures.append(measure)

all_measures
# Out:
# the table Mesure contains measures
# [{'name': 'Nb of Clients who used the Wishlist',
#   'displayFolder': 'wishlist',
#   'expression': ['', 'DISTINCTCOUNT(fact_wishlist[fky_client])', ''],
#   'formatString': '0',
#   'lineageTag': 'b04888e0-5770-4b38-be96-d2fc9d2b53c2'},
#  {'name': 'Wishlist usage frequency per client',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'wishlist',
#   'expression': ['',
#    'VAR distinct_days = ',
#    "DISTINCTCOUNT( 'fact_wishlist'[lab_updatestatus] )",
#    '',
#    'VAR t =',
#    '    SUMMARIZE(',
#    '        fact_wishlist,',
#    '        fact_wishlist[fky_client],',
#    '        "val", distinct_days',
#    '    )',
#    '',
#    'RETURN',
#    '    AVERAGEX(',
#    '        t,',
#    '        [val]',
#    '    )',
#    ''],
#   'lineageTag': '1117dc79-4a80-4df0-b02f-7ffd4be90d35'},
#  {'name': 'Nb of Mirror Sessions',
#   'displayFolder': 'mirror',
#   'expression': ['',
#    'CALCULATE(',
#    '    COUNTROWS(fact_mirror),',
#    '    FILTER(',
#    '        fact_mirror,',
#    '        fact_mirror[is_session_starting_time_validated] = TRUE() ',
#    '        && fact_mirror[experience_Duration_valid] = TRUE()',
#    '        && fact_mirror[lab_sessiontype] = "external"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': 'b1ca63bf-2377-4040-9aca-d5053bfea38f'},
#  {'name': 'Share of Mirror Sessions attached to a client',
#   'displayFolder': 'mirror',
#   'expression': ['',
#    'DIVIDE(',
#    '    CALCULATE(',
#    '        [Nb of Mirror Sessions]',
#    '        , fact_mirror[connection_mode] = "Client"',
#    '    )',
#    '    , [Nb of Mirror Sessions]',
#    ')'],
#   'formatString': '0%;-0%;0%',
#   'lineageTag': '3c56b624-7aeb-4c41-9e99-6e684abf9012'},
#  {'name': 'Nb of clients attached to Mirror Sessions',
#   'displayFolder': 'mirror',
#   'expression': ['',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(fact_mirror[fky_client]),',
#    '    FILTER(',
#    '        fact_mirror,',
#    '        fact_mirror[is_session_starting_time_validated] = TRUE()',
#    '        && fact_mirror[experience_Duration_valid] = TRUE()',
#    '        && fact_mirror[lab_sessiontype] = "external"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '9b413f73-7290-479e-8e65-fa5172d88cf2'},
#  {'name': 'Nb of Clients who opened a Chat',
#   'displayFolder': 'message',
#   'expression': 'CALCULATE(DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), FILTER(\'fact_fashion_app\', \'fact_fashion_app\'[lab_UserType] = "INCHANEL" && \'fact_fashion_app\'[lab_MetricType] = "USERS" && \'fact_fashion_app\'[lab_chatFA] > 0 && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"))',
#   'formatString': '0',
#   'lineageTag': '2cd21672-72fe-46dd-9a49-6290d81bf1f2'},
#  {'name': 'Nb of Clients who replied in a Chat',
#   'displayFolder': 'message',
#   'expression': 'DISTINCTCOUNT(fact_message[fky_chanel_member]) ',
#   'formatString': '0',
#   'lineageTag': '3db09d91-80d8-469a-85c2-f9cc7f39a378'},
#  {'name': 'Chat usage frequency per client',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'message',
#   'expression': ['',
#    'VAR t =',
#    '    SUMMARIZE(',
#    "        'fact_message',",
#    "        'fact_message'[fky_chanel_member],",
#    '        "val", DISTINCTCOUNT(\'fact_message\'[dtm_createdat])',
#    '    )',
#    'RETURN',
#    '    AVERAGEX(',
#    '        t,',
#    '        [val]',
#    '    )',
#    ''],
#   'lineageTag': '3dcc5cdf-2504-4383-b29e-4cd3fe611614'},
#  {'name': 'Nb of Clients who received a SB',
#   'displayFolder': 'suggestion board',
#   'expression': "DISTINCTCOUNT( 'fact_suggestion_board'[fky_client])",
#   'formatString': '0',
#   'lineageTag': '490eed12-fddf-454c-9494-e57e6f4bd4ea'},
#  {'name': 'Nb of Clients who opened a SB',
#   'displayFolder': 'suggestion board',
#   'expression': ['',
#    'CALCULATE(',
#    "    DISTINCTCOUNT('fact_fashion_app'[fky_client])",
#    '    , FILTER(',
#    "        'fact_fashion_app'",
#    '        , \'fact_fashion_app\'[lab_UserType] = "INCHANEL" ',
#    '        && \'fact_fashion_app\'[lab_MetricType] = "USERS" ',
#    "        && 'fact_fashion_app'[lab_suggestionboardviews] > 0 ",
#    '        && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': 'f6ca8184-5764-4e52-af0d-4e0e11142ba6'},
#  {'name': 'Nb of SB sent per client',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'suggestion board',
#   'expression': ['',
#    '',
#    'VAR sbe_nb_SuggestionBoard_Sent_eu = ',
#    'calculate(',
#    '    COUNTROWS(fact_suggestion_board)',
#    '    , filter(',
#    '        fact_suggestion_board',
#    '        , fact_suggestion_board[lab_status] = "SENT" ',
#    '    )',
#    ')',
#    '',
#    'RETURN DIVIDE(',
#    '    sbe_nb_SuggestionBoard_Sent_eu',
#    '    , [Nb of Clients who received a SB]',
#    ')'],
#   'lineageTag': '331945d3-9ba7-41de-ba6a-142ed757a3bd'},
#  {'name': 'Whitelisted Clients',
#   'displayFolder': 'client',
#   'expression': ['',
#    'CALCULATE(',
#    "    COUNTROWS('dim_client'),",
#    '    dim_client[is_whitelisted] = "yes"',
#    ')'],
#   'formatString': '0',
#   'lineageTag': 'c1bc4709-a113-4cfb-8931-aff15d9b0dfd'},
#  {'name': 'Nb of Onboarded Clients',
#   'displayFolder': 'client',
#   'expression': ['',
#    'CALCULATE(',
#    "    COUNTROWS('dim_client'),",
#    '    dim_client[is_onboarded] = TRUE()',
#    ')'],
#   'formatString': '0',
#   'lineageTag': 'a1ee563a-1839-48c4-88b8-714681361154'},
#  {'name': 'INCHANEL ACTIVE Users',
#   'displayFolder': 'client',
#   'expression': ['',
#    'CALCULATE(',
#    "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#    '    \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#    '    \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#    '    \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '488fb56e-ace9-4943-9cc6-a2c11f4ff028'},
#  {'name': 'INCHANEL Active User 6 Months (Since Start)',
#   'displayFolder': 'client',
#   'expression': ['',
#    'VAR MinDateFilter = MAX(dim_calendar[Date]) - 180  // date of 6 months ago',
#    '',
#    'RETURN',
#    'CALCULATE(',
#    "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#    "    FILTER(ALL('dim_calendar'), dim_calendar[Date] >= MinDateFilter),",
#    '    KEEPFILTERS(',
#    '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#    '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#    '        \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#    '    )',
#    ')'],
#   'lineageTag': '977dd977-2c5b-4a9e-a122-2583530dbd2d'},
#  {'name': 'Monthly Repeated Users',
#   'displayFolder': 'client',
#   'expression': ['',
#    'VAR min_date = min(dim_calendar[Date])',
#    'VAR max_date = max(dim_calendar[Date])',
#    'VAR MinDateFilter = max_date - 180  ',
#    'VAR avg_frequency = (max_date - min_date) / DISTINCTCOUNT(fact_fashion_app[dtm_fashionapp])',
#    '',
#    'RETURN',
#    'CALCULATE(',
#    "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#    '    FILTER(',
#    "        'fact_fashion_app',",
#    '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#    '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#    '        \'fact_fashion_app\'[lab_scope] = "GLOBAL" &&',
#    '         avg_frequency <= 28',
#    '    ),',
#    '    FILTER(',
#    "        ALL('dim_calendar'),",
#    '        dim_calendar[Date] >= MinDateFilter',
#    '    )',
#    ')',
#    ''],
#   'formatString': '0',
#   'lineageTag': '1b114ac1-f91c-4ce4-8d66-bf714560f7e4'},
#  {'name': 'Nb of FAs who onboarded a client',
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(dim_client[fky_faofonboarding]), // fa of attachment to be added in case of that faofonboarding is blank',
#    '    FILTER(',
#    '        dim_client,',
#    '        dim_client[is_onboarded] = "Other"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '43f7a150-f20e-4c18-97fe-8a5daa48240f'},
#  {'name': 'Avg Onboarded Clients per FA',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    'VAR onboarded_client = ',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(dim_client[pky_client]), ',
#    '    FILTER(',
#    '        dim_client,',
#    '        dim_client[is_onboarded] = "Other"',
#    '    )',
#    ')',
#    '',
#    'RETURN DIVIDE(onboarded_client, [Nb of FAs who onboarded a client])'],
#   'lineageTag': 'f1644c1f-f34d-406d-a190-3b47f06b0bd7'},
#  {'name': 'Nb of FAs who sent a SB',
#   'displayFolder': 'scope FA',
#   'expression': 'DISTINCTCOUNT(fact_suggestion_board[fky_fa])',
#   'formatString': '0',
#   'lineageTag': '23a4aaae-e5ec-495a-81fe-34dd2babad61'},
#  {'name': 'Total of SB sent',
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(fact_suggestion_board[pky_suggestion_board])',
#    '    , FILTER(',
#    '        fact_suggestion_board',
#    '        , fact_suggestion_board[lab_status] = "SENT"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '028e4af9-39cc-47fe-b114-629283df51b8'},
#  {'name': 'Nb of SB sent per FA',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'scope FA',
#   'expression': '[Total of SB sent] / [Nb of FAs who sent a SB] ',
#   'lineageTag': 'e9e0c141-91e3-4f13-871a-a7fcfc23b679'},
#  {'name': 'Nb of FAs who sent a Chat',
#   'displayFolder': 'scope FA',
#   'expression': 'DISTINCTCOUNT(fact_message[fky_fa])',
#   'lineageTag': 'c84dec07-2aad-4189-a033-b7b4f78fe1b3'},
#  {'name': 'Total of Chats',
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    '',
#    'CALCULATE(',
#    '    COUNT(fact_message[pky_message])',
#    '    , FILTER(',
#    '        fact_message',
#    '        ,NOT(ISBLANK(fact_message[fky_fa]))',
#    '    )',
#    ')'],
#   'lineageTag': '4324aca1-1c81-4e8e-9ba9-0da12c791f46'},
#  {'name': 'Nb of Chats sent per FA',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    'DIVIDE(',
#    '    [Total of Chats]',
#    '    , [Nb of FAs who sent a Chat]',
#    ')'],
#   'lineageTag': 'bb7437d2-5949-4c95-a0ed-1d915599fcbc'},
#  {'name': 'Nb of FAs who did at least one Mirror Session',
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    '',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(fact_mirror[fky_fa]),',
#    '    FILTER(fact_mirror,',
#    '    fact_mirror[experience_Duration_valid] = True',
#    '            )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '3e8b16d6-d9ac-4928-843c-ad516432f32e'},
#  {'name': 'Nb of Mirror Sessions by FA',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'scope FA',
#   'expression': '[Nb of Mirror Sessions] / [Nb of FAs who did at least one Mirror Session]',
#   'lineageTag': 'c8bee7b8-2c47-4585-85d4-cf27d36824e3'}]

# %%
model_bim['model']['tables'][8]['partitions']
# Out:
# [{'name': 'fact_mirror',
#   'mode': 'import',
#   'queryGroup': 'fact',
#   'source': {'expression': ['let',
#     '    Source = Sql.Database(',
#     '        "asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net", ',
#     '        database_id, ',
#     '        [Query = "SELECT *',
#     '                  FROM OPENROWSET(',
#     '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_mirror/\',',
#     "                        FORMAT = 'DELTA'",
#     '                    ) AS [result]"',
#     '        ]',
#     '    )',
#     'in',
#     '    Source'],
#    'type': 'm'}}]

# %%
def extract_relevant_elements_dashboard_summary(json_dataset):
    model = json_dataset.get('model', {})
    # Initialize the extracted dataset
    extracted_json_dataset = {       
        "tables": {
            "expressions": model.get("expressions", []),
            "table_partitions": []
        },
        "measures": []
    }

    # Define the keywords to exclude
    excluded_keywords = ["LocalDateTable", "DateTableTemplate"]

    # Filter tables to exclude ones containing the excluded keywords
    for table in model.get("tables", []):
        if not any(keyword in table.get('name', '') for keyword in excluded_keywords):
            # Add table partitions if they exist
            partitions = table.get('partitions', [])
            if partitions:
                extracted_json_dataset["tables"]["table_partitions"].extend(partitions)

            # Add measures if they exist
            if "measures" in table:
                print(f"The table '{table['name']}' contains measures.")
                extracted_json_dataset["measures"].extend(table["measures"])
    
    return extracted_json_dataset

# %%
test_extraction = extract_relevant_elements_dashboard_summary(model_bim)
test_extraction
# Out:
# The table 'Mesure' contains measures.
# {'tables': {'expressions': [{'name': 'server_id',
#     'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#      {'name': 'PBI_ResultType', 'value': 'Text'}],
#     'description': 'Azure server name',
#     'expression': '"asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#     'kind': 'm',
#     'lineageTag': 'acf363bb-3a3b-4c63-8ce9-64df713220f6',
#     'queryGroup': 'parameters'},
#    {'name': 'database_id',
#     'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#      {'name': 'PBI_ResultType', 'value': 'Text'}],
#     'expression': '"dhfsh-gold" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#     'kind': 'm',
#     'lineageTag': 'a29a4a2c-53d5-46aa-a171-21ed366054bd',
#     'queryGroup': 'parameters'},
#    {'name': 'storage_id',
#     'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#      {'name': 'PBI_ResultType', 'value': 'Text'}],
#     'description': 'Azure blob storage id',
#     'expression': '"sastddthglbfsh1rawweuuat" meta [IsParameterQuery=true, Type="Any", IsParameterQueryRequired=true]',
#     'kind': 'm',
#     'lineageTag': 'cb07b717-ca14-4a97-9812-d5f687ce77b9',
#     'queryGroup': 'parameters'}],
#   'table_partitions': [{'name': 'fact_wishlist',
#     'mode': 'import',
#     'queryGroup': 'fact',
#     'source': {'expression': ['let',
#       '    Source = Sql.Database(',
#       '        server_id, ',
#       '        database_id, ',
#       '        [Query = "SELECT *',
#       '                  FROM OPENROWSET(',
#       '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_wishlist/\',',
#       "                        FORMAT = 'DELTA'",
#       '                    ) AS [result]"',
#       '        ]',
#       '    ),',
#       '    #"Modify Date Column Format" = Table.TransformColumnTypes(Source,{{"lab_updatestatus", type date}}),',
#       '    #"Lignes filtrées" = Table.SelectRows(#"Modify Date Column Format", each true)',
#       'in',
#       '    #"Lignes filtrées"'],
#      'type': 'm'}},
#    {'name': 'dim_calendar',
#     'mode': 'import',
#     'queryGroup': 'dimension',
#     'source': {'expression': ['let',
#       '    Source = let',
#       '    Source = let',
#       '    Source = "",',
#       '    StartDate = #date(2019, 1, 1),',
#       '    EndDate = #date(2029, 1, 1),',
#       '    Duration = Duration.Days(EndDate - StartDate),',
#       '    DefineInterval = List.Dates(StartDate, Duration, #duration(1, 0, 0, 0)),',
#       '    ConvertToTable = Table.FromList(DefineInterval, Splitter.SplitByNothing(), null, null, ExtraValues.Error),',
#       '    RenameColumns = Table.RenameColumns(ConvertToTable, {{"Column1", "Date"}}),',
#       '    ModifyType = Table.TransformColumnTypes(RenameColumns, {{"Date", type date}}),',
#       '    AddDateID = Table.AddColumn(ModifyType, "Date ID", each Date.ToText([Date], "YYYYMMDD")),',
#       '    ReorderColumns = Table.ReorderColumns(AddDateID, {"Date ID", "Date"}),',
#       '    AddYearColumn = Table.AddColumn(ReorderColumns, "Année", each Date.Year([Date]), Int64.Type),',
#       '    ModifyYearType = Table.TransformColumnTypes(AddYearColumn, {{"Année", type text}}),',
#       '    AddMonthColumn = Table.AddColumn(ModifyYearType, "Mois", each Date.Month([Date]), Int64.Type),',
#       '    AddQuarterColumn = Table.AddColumn(AddMonthColumn, "Trimestre", each Date.QuarterOfYear([Date]), Int64.Type),',
#       '    AddStartOfMonth = Table.AddColumn(AddQuarterColumn, "Début de mois", each Date.StartOfMonth([Date]), type date),',
#       '    AddEndOfMonth = Table.AddColumn(AddStartOfMonth, "Fin du mois", each Date.EndOfMonth([Date]), type date),',
#       '    AddNameOfMonth = Table.AddColumn(AddEndOfMonth, "Nom du mois", each Date.MonthName([Date]), type text),',
#       '    AddMonthYearName = Table.AddColumn(AddNameOfMonth, "Month_year_name", each [Nom du mois] & " " & [Année]),',
#       '    AddStartOfWeek = Table.AddColumn(AddMonthYearName, "Début de semaine", each Date.StartOfWeek([Date]), type date),',
#       '    AddIndexColumn = Table.AddIndexColumn(AddStartOfWeek, "PrimaryKey", 1, 1, Int64.Type),',
#       '    RenameFinalColumns = Table.RenameColumns(AddIndexColumn, {{"Année", "Year"}, {"Mois", "Month"}, {"Trimestre", "Quanter"}, {"Début de mois", "Start of the Month"}, {"Nom du mois", "Name of the month"}, {"Fin du mois", "End of the Month"}, {"Début de semaine", "Start of the Week"}})',
#       'in',
#       '    RenameFinalColumns',
#       'in',
#       '    Source',
#       'in',
#       '    Source'],
#      'type': 'm'}},
#    {'name': 'Mesure',
#     'mode': 'import',
#     'source': {'expression': ['let',
#       '    Source = Table.FromRows(Json.Document(Binary.Decompress(Binary.FromText("i44FAA==", BinaryEncoding.Base64), Compression.Deflate)), let _t = ((type nullable text) meta [Serialized.Text = true]) in type table [temp = _t]),',
#       '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"temp", type text}}),',
#       '    #"Colonnes supprimées" = Table.RemoveColumns(#"Type modifié",{"temp"})',
#       'in',
#       '    #"Colonnes supprimées"'],
#      'type': 'm'}},
#    {'name': 'fact_mirror',
#     'mode': 'import',
#     'queryGroup': 'fact',
#     'source': {'expression': ['let',
#       '    Source = Sql.Database(',
#       '        "asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net", ',
#       '        database_id, ',
#       '        [Query = "SELECT *',
#       '                  FROM OPENROWSET(',
#       '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_mirror/\',',
#       "                        FORMAT = 'DELTA'",
#       '                    ) AS [result]"',
#       '        ]',
#       '    )',
#       'in',
#       '    Source'],
#      'type': 'm'}},
#    {'name': 'fact_suggestion_board',
#     'mode': 'import',
#     'queryGroup': 'fact',
#     'source': {'expression': ['let',
#       '    Source = Sql.Database(',
#       '        server_id, ',
#       '        database_id, ',
#       '        [Query = "SELECT *',
#       '                  FROM OPENROWSET(',
#       '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_suggestion_board/\',',
#       "                        FORMAT = 'DELTA'",
#       '                    ) AS [result]"',
#       '        ]',
#       '    ),',
#       '    #"Modify Date Column Format" = Table.TransformColumnTypes(Source,{{"dtm_publication", type date}})',
#       'in',
#       '    #"Modify Date Column Format"'],
#      'type': 'm'}},
#    {'name': 'fact_message',
#     'mode': 'import',
#     'queryGroup': 'fact',
#     'source': {'expression': ['let',
#       '    Source = Sql.Database(',
#       '        server_id, ',
#       '        database_id, ',
#       '        [Query = "SELECT *',
#       '                  FROM OPENROWSET(',
#       '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_message/\',',
#       "                        FORMAT = 'DELTA'",
#       '                    ) AS [result]"',
#       '        ]',
#       '    ),',
#       '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"dtm_createdat", type date}})',
#       'in',
#       '    #"Type modifié"'],
#      'type': 'm'}},
#    {'name': 'dim_client',
#     'mode': 'import',
#     'queryGroup': 'dimension',
#     'source': {'expression': ['let',
#       '    Source = Sql.Database(',
#       '        server_id, ',
#       '        database_id, ',
#       '        [Query = "SELECT *',
#       '                  FROM OPENROWSET(',
#       '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/dimension/dim_client/\',',
#       "                        FORMAT = 'DELTA'",
#       '                    ) AS [result]"',
#       '        ]',
#       '    ),',
#       '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"dtm_dateofonboarding", type date}})',
#       'in',
#       '    #"Type modifié"'],
#      'type': 'm'}},
#    {'name': 'dim_boutique',
#     'mode': 'import',
#     'queryGroup': 'dimension',
#     'source': {'expression': ['let',
#       '    // Load files from SharePoint folder',
#       '    Source = SharePoint.Files("https://lpl.sharepoint.com/sites/PERFORMANCETEAM", [ApiVersion = 15]),',
#       '',
#       '    // Filter to the specific folder path',
#       '    FilteredRows = Table.SelectRows(Source, each [Folder Path] = "https://lpl.sharepoint.com/sites/PERFORMANCETEAM/Documents partages/Dashboard/DATA & MONITORING/INCHANEL/COUCHE GOLD/DIM BOUTIQUE/"),',
#       '',
#       '    // Select the specific file',
#       '    BoutiqueReferenceFile = FilteredRows{[Name = "Référentiel boutiques InChanel.xlsx", Folder Path = "https://lpl.sharepoint.com/sites/PERFORMANCETEAM/Documents partages/Dashboard/DATA & MONITORING/INCHANEL/COUCHE GOLD/DIM BOUTIQUE/"]}[Content],',
#       '',
#       '    // Load the Excel file',
#       '    ImportedExcel = Excel.Workbook(BoutiqueReferenceFile),',
#       '',
#       '    // Get the data from the specific sheet',
#       '    BoutiqueSheet = ImportedExcel{[Item = "REFERENTIEL BOUTIQUES INCHANEL", Kind = "Sheet"]}[Data],',
#       '',
#       '    // Filter non-null rows from the source',
#       '    FilteredSourceRows = Table.SelectRows(BoutiqueSheet, each [Column6] <> null),',
#       '',
#       '    // Promote headers',
#       '    PromotedHeaders = Table.PromoteHeaders(FilteredSourceRows, [PromoteAllScalars = true]),',
#       '',
#       '    // Change column types',
#       '    ChangedColumnTypes = Table.TransformColumnTypes(',
#       '        PromotedHeaders,',
#       '        {',
#       '            {"Region", type text}, ',
#       '            {"Market", type text}, ',
#       '            {"Country", type text}, ',
#       '            {"Boutique Name", type text}, ',
#       '            {"Boutique Group Code", type any}, ',
#       '            {"Boutique STAR Code", type text}, ',
#       '            {"Inchanel Launching Date", type date}, ',
#       '            {"Boutique Status", type text}, ',
#       '            {"Boutique Status Code", Int64.Type}, ',
#       '            {"Mirror Launch date", type any}, ',
#       '            {"Digital Launch date", type text}, ',
#       '            {"Opening hour (local)", type time}, ',
#       '            {"Closing hour (local)", type time}, ',
#       '            {"UTC opening hour (summer)", type time}, ',
#       '            {"UTC closing hour (summer)", type time}, ',
#       '            {"UTC opening hour (winter)", type time},',
#       '            {"UTC closing hour (winter)", type time},',
#       '            {"Code boutique mirror ", type text}',
#       '        }',
#       '    ),',
#       '',
#       '    // Filter rows where "Code boutique mirror" is not null',
#       '    FilteredMirrorCodeRows = Table.SelectRows(ChangedColumnTypes, each [#"Code boutique mirror "] <> null),',
#       '',
#       '    // Remove "Boutique STAR Code" column',
#       '    RemovedBoutiqueStarCode = Table.RemoveColumns(FilteredMirrorCodeRows, {"Boutique STAR Code"}),',
#       '',
#       '    // Remove duplicates based on "Code boutique mirror"',
#       '    DistinctMirrorCode = Table.Distinct(RemovedBoutiqueStarCode, {"Code boutique mirror "}),',
#       '',
#       '    // Rename "Code boutique mirror" to "Boutique STAR Code"',
#       '    RenamedColumns = Table.RenameColumns(DistinctMirrorCode, {{"Code boutique mirror ", "Boutique STAR Code"}}),',
#       '',
#       '    // Combine the original table and the updated table',
#       '    CombinedTable = Table.Combine({ChangedColumnTypes, RenamedColumns}),',
#       '',
#       '    // Remove the redundant "Code boutique mirror" column',
#       '    FinalResult = Table.RemoveColumns(CombinedTable, {"Code boutique mirror "}),',
#       '    RenameColumn = Table.RenameColumns(FinalResult,{{"Boutique STAR Code", "Boutique Code"}})',
#       'in',
#       '    RenameColumn'],
#      'type': 'm'}}]},
#  'measures': [{'name': 'Nb of Clients who used the Wishlist',
#    'displayFolder': 'wishlist',
#    'expression': ['', 'DISTINCTCOUNT(fact_wishlist[fky_client])', ''],
#    'formatString': '0',
#    'lineageTag': 'b04888e0-5770-4b38-be96-d2fc9d2b53c2'},
#   {'name': 'Wishlist usage frequency per client',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'wishlist',
#    'expression': ['',
#     'VAR distinct_days = ',
#     "DISTINCTCOUNT( 'fact_wishlist'[lab_updatestatus] )",
#     '',
#     'VAR t =',
#     '    SUMMARIZE(',
#     '        fact_wishlist,',
#     '        fact_wishlist[fky_client],',
#     '        "val", distinct_days',
#     '    )',
#     '',
#     'RETURN',
#     '    AVERAGEX(',
#     '        t,',
#     '        [val]',
#     '    )',
#     ''],
#    'lineageTag': '1117dc79-4a80-4df0-b02f-7ffd4be90d35'},
#   {'name': 'Nb of Mirror Sessions',
#    'displayFolder': 'mirror',
#    'expression': ['',
#     'CALCULATE(',
#     '    COUNTROWS(fact_mirror),',
#     '    FILTER(',
#     '        fact_mirror,',
#     '        fact_mirror[is_session_starting_time_validated] = TRUE() ',
#     '        && fact_mirror[experience_Duration_valid] = TRUE()',
#     '        && fact_mirror[lab_sessiontype] = "external"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': 'b1ca63bf-2377-4040-9aca-d5053bfea38f'},
#   {'name': 'Share of Mirror Sessions attached to a client',
#    'displayFolder': 'mirror',
#    'expression': ['',
#     'DIVIDE(',
#     '    CALCULATE(',
#     '        [Nb of Mirror Sessions]',
#     '        , fact_mirror[connection_mode] = "Client"',
#     '    )',
#     '    , [Nb of Mirror Sessions]',
#     ')'],
#    'formatString': '0%;-0%;0%',
#    'lineageTag': '3c56b624-7aeb-4c41-9e99-6e684abf9012'},
#   {'name': 'Nb of clients attached to Mirror Sessions',
#    'displayFolder': 'mirror',
#    'expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_mirror[fky_client]),',
#     '    FILTER(',
#     '        fact_mirror,',
#     '        fact_mirror[is_session_starting_time_validated] = TRUE()',
#     '        && fact_mirror[experience_Duration_valid] = TRUE()',
#     '        && fact_mirror[lab_sessiontype] = "external"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '9b413f73-7290-479e-8e65-fa5172d88cf2'},
#   {'name': 'Nb of Clients who opened a Chat',
#    'displayFolder': 'message',
#    'expression': 'CALCULATE(DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), FILTER(\'fact_fashion_app\', \'fact_fashion_app\'[lab_UserType] = "INCHANEL" && \'fact_fashion_app\'[lab_MetricType] = "USERS" && \'fact_fashion_app\'[lab_chatFA] > 0 && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"))',
#    'formatString': '0',
#    'lineageTag': '2cd21672-72fe-46dd-9a49-6290d81bf1f2'},
#   {'name': 'Nb of Clients who replied in a Chat',
#    'displayFolder': 'message',
#    'expression': 'DISTINCTCOUNT(fact_message[fky_chanel_member]) ',
#    'formatString': '0',
#    'lineageTag': '3db09d91-80d8-469a-85c2-f9cc7f39a378'},
#   {'name': 'Chat usage frequency per client',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'message',
#    'expression': ['',
#     'VAR t =',
#     '    SUMMARIZE(',
#     "        'fact_message',",
#     "        'fact_message'[fky_chanel_member],",
#     '        "val", DISTINCTCOUNT(\'fact_message\'[dtm_createdat])',
#     '    )',
#     'RETURN',
#     '    AVERAGEX(',
#     '        t,',
#     '        [val]',
#     '    )',
#     ''],
#    'lineageTag': '3dcc5cdf-2504-4383-b29e-4cd3fe611614'},
#   {'name': 'Nb of Clients who received a SB',
#    'displayFolder': 'suggestion board',
#    'expression': "DISTINCTCOUNT( 'fact_suggestion_board'[fky_client])",
#    'formatString': '0',
#    'lineageTag': '490eed12-fddf-454c-9494-e57e6f4bd4ea'},
#   {'name': 'Nb of Clients who opened a SB',
#    'displayFolder': 'suggestion board',
#    'expression': ['',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client])",
#     '    , FILTER(',
#     "        'fact_fashion_app'",
#     '        , \'fact_fashion_app\'[lab_UserType] = "INCHANEL" ',
#     '        && \'fact_fashion_app\'[lab_MetricType] = "USERS" ',
#     "        && 'fact_fashion_app'[lab_suggestionboardviews] > 0 ",
#     '        && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': 'f6ca8184-5764-4e52-af0d-4e0e11142ba6'},
#   {'name': 'Nb of SB sent per client',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'suggestion board',
#    'expression': ['',
#     '',
#     'VAR sbe_nb_SuggestionBoard_Sent_eu = ',
#     'calculate(',
#     '    COUNTROWS(fact_suggestion_board)',
#     '    , filter(',
#     '        fact_suggestion_board',
#     '        , fact_suggestion_board[lab_status] = "SENT" ',
#     '    )',
#     ')',
#     '',
#     'RETURN DIVIDE(',
#     '    sbe_nb_SuggestionBoard_Sent_eu',
#     '    , [Nb of Clients who received a SB]',
#     ')'],
#    'lineageTag': '331945d3-9ba7-41de-ba6a-142ed757a3bd'},
#   {'name': 'Whitelisted Clients',
#    'displayFolder': 'client',
#    'expression': ['',
#     'CALCULATE(',
#     "    COUNTROWS('dim_client'),",
#     '    dim_client[is_whitelisted] = "yes"',
#     ')'],
#    'formatString': '0',
#    'lineageTag': 'c1bc4709-a113-4cfb-8931-aff15d9b0dfd'},
#   {'name': 'Nb of Onboarded Clients',
#    'displayFolder': 'client',
#    'expression': ['',
#     'CALCULATE(',
#     "    COUNTROWS('dim_client'),",
#     '    dim_client[is_onboarded] = TRUE()',
#     ')'],
#    'formatString': '0',
#    'lineageTag': 'a1ee563a-1839-48c4-88b8-714681361154'},
#   {'name': 'INCHANEL ACTIVE Users',
#    'displayFolder': 'client',
#    'expression': ['',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     '    \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '    \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '    \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '488fb56e-ace9-4943-9cc6-a2c11f4ff028'},
#   {'name': 'INCHANEL Active User 6 Months (Since Start)',
#    'displayFolder': 'client',
#    'expression': ['',
#     'VAR MinDateFilter = MAX(dim_calendar[Date]) - 180  // date of 6 months ago',
#     '',
#     'RETURN',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     "    FILTER(ALL('dim_calendar'), dim_calendar[Date] >= MinDateFilter),",
#     '    KEEPFILTERS(',
#     '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '        \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#     '    )',
#     ')'],
#    'lineageTag': '977dd977-2c5b-4a9e-a122-2583530dbd2d'},
#   {'name': 'Monthly Repeated Users',
#    'displayFolder': 'client',
#    'expression': ['',
#     'VAR min_date = min(dim_calendar[Date])',
#     'VAR max_date = max(dim_calendar[Date])',
#     'VAR MinDateFilter = max_date - 180  ',
#     'VAR avg_frequency = (max_date - min_date) / DISTINCTCOUNT(fact_fashion_app[dtm_fashionapp])',
#     '',
#     'RETURN',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     '    FILTER(',
#     "        'fact_fashion_app',",
#     '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '        \'fact_fashion_app\'[lab_scope] = "GLOBAL" &&',
#     '         avg_frequency <= 28',
#     '    ),',
#     '    FILTER(',
#     "        ALL('dim_calendar'),",
#     '        dim_calendar[Date] >= MinDateFilter',
#     '    )',
#     ')',
#     ''],
#    'formatString': '0',
#    'lineageTag': '1b114ac1-f91c-4ce4-8d66-bf714560f7e4'},
#   {'name': 'Nb of FAs who onboarded a client',
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(dim_client[fky_faofonboarding]), // fa of attachment to be added in case of that faofonboarding is blank',
#     '    FILTER(',
#     '        dim_client,',
#     '        dim_client[is_onboarded] = "Other"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '43f7a150-f20e-4c18-97fe-8a5daa48240f'},
#   {'name': 'Avg Onboarded Clients per FA',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     'VAR onboarded_client = ',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(dim_client[pky_client]), ',
#     '    FILTER(',
#     '        dim_client,',
#     '        dim_client[is_onboarded] = "Other"',
#     '    )',
#     ')',
#     '',
#     'RETURN DIVIDE(onboarded_client, [Nb of FAs who onboarded a client])'],
#    'lineageTag': 'f1644c1f-f34d-406d-a190-3b47f06b0bd7'},
#   {'name': 'Nb of FAs who sent a SB',
#    'displayFolder': 'scope FA',
#    'expression': 'DISTINCTCOUNT(fact_suggestion_board[fky_fa])',
#    'formatString': '0',
#    'lineageTag': '23a4aaae-e5ec-495a-81fe-34dd2babad61'},
#   {'name': 'Total of SB sent',
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_suggestion_board[pky_suggestion_board])',
#     '    , FILTER(',
#     '        fact_suggestion_board',
#     '        , fact_suggestion_board[lab_status] = "SENT"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '028e4af9-39cc-47fe-b114-629283df51b8'},
#   {'name': 'Nb of SB sent per FA',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'scope FA',
#    'expression': '[Total of SB sent] / [Nb of FAs who sent a SB] ',
#    'lineageTag': 'e9e0c141-91e3-4f13-871a-a7fcfc23b679'},
#   {'name': 'Nb of FAs who sent a Chat',
#    'displayFolder': 'scope FA',
#    'expression': 'DISTINCTCOUNT(fact_message[fky_fa])',
#    'lineageTag': 'c84dec07-2aad-4189-a033-b7b4f78fe1b3'},
#   {'name': 'Total of Chats',
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     '',
#     'CALCULATE(',
#     '    COUNT(fact_message[pky_message])',
#     '    , FILTER(',
#     '        fact_message',
#     '        ,NOT(ISBLANK(fact_message[fky_fa]))',
#     '    )',
#     ')'],
#    'lineageTag': '4324aca1-1c81-4e8e-9ba9-0da12c791f46'},
#   {'name': 'Nb of Chats sent per FA',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     'DIVIDE(',
#     '    [Total of Chats]',
#     '    , [Nb of FAs who sent a Chat]',
#     ')'],
#    'lineageTag': 'bb7437d2-5949-4c95-a0ed-1d915599fcbc'},
#   {'name': 'Nb of FAs who did at least one Mirror Session',
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     '',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_mirror[fky_fa]),',
#     '    FILTER(fact_mirror,',
#     '    fact_mirror[experience_Duration_valid] = True',
#     '            )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '3e8b16d6-d9ac-4928-843c-ad516432f32e'},
#   {'name': 'Nb of Mirror Sessions by FA',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'scope FA',
#    'expression': '[Nb of Mirror Sessions] / [Nb of FAs who did at least one Mirror Session]',
#    'lineageTag': 'c8bee7b8-2c47-4585-85d4-cf27d36824e3'}]}

# %%
data_table = test_extraction['tables']

# %%
data_table
# Out:
# {'expressions': [{'name': 'server_id',
#    'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#     {'name': 'PBI_ResultType', 'value': 'Text'}],
#    'description': 'Azure server name',
#    'expression': '"asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#    'kind': 'm',
#    'lineageTag': 'acf363bb-3a3b-4c63-8ce9-64df713220f6',
#    'queryGroup': 'parameters'},
#   {'name': 'database_id',
#    'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#     {'name': 'PBI_ResultType', 'value': 'Text'}],
#    'expression': '"dhfsh-gold" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#    'kind': 'm',
#    'lineageTag': 'a29a4a2c-53d5-46aa-a171-21ed366054bd',
#    'queryGroup': 'parameters'},
#   {'name': 'storage_id',
#    'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#     {'name': 'PBI_ResultType', 'value': 'Text'}],
#    'description': 'Azure blob storage id',
#    'expression': '"sastddthglbfsh1rawweuuat" meta [IsParameterQuery=true, Type="Any", IsParameterQueryRequired=true]',
#    'kind': 'm',
#    'lineageTag': 'cb07b717-ca14-4a97-9812-d5f687ce77b9',
#    'queryGroup': 'parameters'}],
#  'table_partitions': [{'name': 'fact_wishlist',
#    'mode': 'import',
#    'queryGroup': 'fact',
#    'source': {'expression': ['let',
#      '    Source = Sql.Database(',
#      '        server_id, ',
#      '        database_id, ',
#      '        [Query = "SELECT *',
#      '                  FROM OPENROWSET(',
#      '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_wishlist/\',',
#      "                        FORMAT = 'DELTA'",
#      '                    ) AS [result]"',
#      '        ]',
#      '    ),',
#      '    #"Modify Date Column Format" = Table.TransformColumnTypes(Source,{{"lab_updatestatus", type date}}),',
#      '    #"Lignes filtrées" = Table.SelectRows(#"Modify Date Column Format", each true)',
#      'in',
#      '    #"Lignes filtrées"'],
#     'type': 'm'}},
#   {'name': 'dim_calendar',
#    'mode': 'import',
#    'queryGroup': 'dimension',
#    'source': {'expression': ['let',
#      '    Source = let',
#      '    Source = let',
#      '    Source = "",',
#      '    StartDate = #date(2019, 1, 1),',
#      '    EndDate = #date(2029, 1, 1),',
#      '    Duration = Duration.Days(EndDate - StartDate),',
#      '    DefineInterval = List.Dates(StartDate, Duration, #duration(1, 0, 0, 0)),',
#      '    ConvertToTable = Table.FromList(DefineInterval, Splitter.SplitByNothing(), null, null, ExtraValues.Error),',
#      '    RenameColumns = Table.RenameColumns(ConvertToTable, {{"Column1", "Date"}}),',
#      '    ModifyType = Table.TransformColumnTypes(RenameColumns, {{"Date", type date}}),',
#      '    AddDateID = Table.AddColumn(ModifyType, "Date ID", each Date.ToText([Date], "YYYYMMDD")),',
#      '    ReorderColumns = Table.ReorderColumns(AddDateID, {"Date ID", "Date"}),',
#      '    AddYearColumn = Table.AddColumn(ReorderColumns, "Année", each Date.Year([Date]), Int64.Type),',
#      '    ModifyYearType = Table.TransformColumnTypes(AddYearColumn, {{"Année", type text}}),',
#      '    AddMonthColumn = Table.AddColumn(ModifyYearType, "Mois", each Date.Month([Date]), Int64.Type),',
#      '    AddQuarterColumn = Table.AddColumn(AddMonthColumn, "Trimestre", each Date.QuarterOfYear([Date]), Int64.Type),',
#      '    AddStartOfMonth = Table.AddColumn(AddQuarterColumn, "Début de mois", each Date.StartOfMonth([Date]), type date),',
#      '    AddEndOfMonth = Table.AddColumn(AddStartOfMonth, "Fin du mois", each Date.EndOfMonth([Date]), type date),',
#      '    AddNameOfMonth = Table.AddColumn(AddEndOfMonth, "Nom du mois", each Date.MonthName([Date]), type text),',
#      '    AddMonthYearName = Table.AddColumn(AddNameOfMonth, "Month_year_name", each [Nom du mois] & " " & [Année]),',
#      '    AddStartOfWeek = Table.AddColumn(AddMonthYearName, "Début de semaine", each Date.StartOfWeek([Date]), type date),',
#      '    AddIndexColumn = Table.AddIndexColumn(AddStartOfWeek, "PrimaryKey", 1, 1, Int64.Type),',
#      '    RenameFinalColumns = Table.RenameColumns(AddIndexColumn, {{"Année", "Year"}, {"Mois", "Month"}, {"Trimestre", "Quanter"}, {"Début de mois", "Start of the Month"}, {"Nom du mois", "Name of the month"}, {"Fin du mois", "End of the Month"}, {"Début de semaine", "Start of the Week"}})',
#      'in',
#      '    RenameFinalColumns',
#      'in',
#      '    Source',
#      'in',
#      '    Source'],
#     'type': 'm'}},
#   {'name': 'Mesure',
#    'mode': 'import',
#    'source': {'expression': ['let',
#      '    Source = Table.FromRows(Json.Document(Binary.Decompress(Binary.FromText("i44FAA==", BinaryEncoding.Base64), Compression.Deflate)), let _t = ((type nullable text) meta [Serialized.Text = true]) in type table [temp = _t]),',
#      '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"temp", type text}}),',
#      '    #"Colonnes supprimées" = Table.RemoveColumns(#"Type modifié",{"temp"})',
#      'in',
#      '    #"Colonnes supprimées"'],
#     'type': 'm'}},
#   {'name': 'fact_mirror',
#    'mode': 'import',
#    'queryGroup': 'fact',
#    'source': {'expression': ['let',
#      '    Source = Sql.Database(',
#      '        "asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net", ',
#      '        database_id, ',
#      '        [Query = "SELECT *',
#      '                  FROM OPENROWSET(',
#      '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_mirror/\',',
#      "                        FORMAT = 'DELTA'",
#      '                    ) AS [result]"',
#      '        ]',
#      '    )',
#      'in',
#      '    Source'],
#     'type': 'm'}},
#   {'name': 'fact_suggestion_board',
#    'mode': 'import',
#    'queryGroup': 'fact',
#    'source': {'expression': ['let',
#      '    Source = Sql.Database(',
#      '        server_id, ',
#      '        database_id, ',
#      '        [Query = "SELECT *',
#      '                  FROM OPENROWSET(',
#      '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_suggestion_board/\',',
#      "                        FORMAT = 'DELTA'",
#      '                    ) AS [result]"',
#      '        ]',
#      '    ),',
#      '    #"Modify Date Column Format" = Table.TransformColumnTypes(Source,{{"dtm_publication", type date}})',
#      'in',
#      '    #"Modify Date Column Format"'],
#     'type': 'm'}},
#   {'name': 'fact_message',
#    'mode': 'import',
#    'queryGroup': 'fact',
#    'source': {'expression': ['let',
#      '    Source = Sql.Database(',
#      '        server_id, ',
#      '        database_id, ',
#      '        [Query = "SELECT *',
#      '                  FROM OPENROWSET(',
#      '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_message/\',',
#      "                        FORMAT = 'DELTA'",
#      '                    ) AS [result]"',
#      '        ]',
#      '    ),',
#      '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"dtm_createdat", type date}})',
#      'in',
#      '    #"Type modifié"'],
#     'type': 'm'}},
#   {'name': 'dim_client',
#    'mode': 'import',
#    'queryGroup': 'dimension',
#    'source': {'expression': ['let',
#      '    Source = Sql.Database(',
#      '        server_id, ',
#      '        database_id, ',
#      '        [Query = "SELECT *',
#      '                  FROM OPENROWSET(',
#      '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/dimension/dim_client/\',',
#      "                        FORMAT = 'DELTA'",
#      '                    ) AS [result]"',
#      '        ]',
#      '    ),',
#      '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"dtm_dateofonboarding", type date}})',
#      'in',
#      '    #"Type modifié"'],
#     'type': 'm'}},
#   {'name': 'dim_boutique',
#    'mode': 'import',
#    'queryGroup': 'dimension',
#    'source': {'expression': ['let',
#      '    // Load files from SharePoint folder',
#      '    Source = SharePoint.Files("https://lpl.sharepoint.com/sites/PERFORMANCETEAM", [ApiVersion = 15]),',
#      '',
#      '    // Filter to the specific folder path',
#      '    FilteredRows = Table.SelectRows(Source, each [Folder Path] = "https://lpl.sharepoint.com/sites/PERFORMANCETEAM/Documents partages/Dashboard/DATA & MONITORING/INCHANEL/COUCHE GOLD/DIM BOUTIQUE/"),',
#      '',
#      '    // Select the specific file',
#      '    BoutiqueReferenceFile = FilteredRows{[Name = "Référentiel boutiques InChanel.xlsx", Folder Path = "https://lpl.sharepoint.com/sites/PERFORMANCETEAM/Documents partages/Dashboard/DATA & MONITORING/INCHANEL/COUCHE GOLD/DIM BOUTIQUE/"]}[Content],',
#      '',
#      '    // Load the Excel file',
#      '    ImportedExcel = Excel.Workbook(BoutiqueReferenceFile),',
#      '',
#      '    // Get the data from the specific sheet',
#      '    BoutiqueSheet = ImportedExcel{[Item = "REFERENTIEL BOUTIQUES INCHANEL", Kind = "Sheet"]}[Data],',
#      '',
#      '    // Filter non-null rows from the source',
#      '    FilteredSourceRows = Table.SelectRows(BoutiqueSheet, each [Column6] <> null),',
#      '',
#      '    // Promote headers',
#      '    PromotedHeaders = Table.PromoteHeaders(FilteredSourceRows, [PromoteAllScalars = true]),',
#      '',
#      '    // Change column types',
#      '    ChangedColumnTypes = Table.TransformColumnTypes(',
#      '        PromotedHeaders,',
#      '        {',
#      '            {"Region", type text}, ',
#      '            {"Market", type text}, ',
#      '            {"Country", type text}, ',
#      '            {"Boutique Name", type text}, ',
#      '            {"Boutique Group Code", type any}, ',
#      '            {"Boutique STAR Code", type text}, ',
#      '            {"Inchanel Launching Date", type date}, ',
#      '            {"Boutique Status", type text}, ',
#      '            {"Boutique Status Code", Int64.Type}, ',
#      '            {"Mirror Launch date", type any}, ',
#      '            {"Digital Launch date", type text}, ',
#      '            {"Opening hour (local)", type time}, ',
#      '            {"Closing hour (local)", type time}, ',
#      '            {"UTC opening hour (summer)", type time}, ',
#      '            {"UTC closing hour (summer)", type time}, ',
#      '            {"UTC opening hour (winter)", type time},',
#      '            {"UTC closing hour (winter)", type time},',
#      '            {"Code boutique mirror ", type text}',
#      '        }',
#      '    ),',
#      '',
#      '    // Filter rows where "Code boutique mirror" is not null',
#      '    FilteredMirrorCodeRows = Table.SelectRows(ChangedColumnTypes, each [#"Code boutique mirror "] <> null),',
#      '',
#      '    // Remove "Boutique STAR Code" column',
#      '    RemovedBoutiqueStarCode = Table.RemoveColumns(FilteredMirrorCodeRows, {"Boutique STAR Code"}),',
#      '',
#      '    // Remove duplicates based on "Code boutique mirror"',
#      '    DistinctMirrorCode = Table.Distinct(RemovedBoutiqueStarCode, {"Code boutique mirror "}),',
#      '',
#      '    // Rename "Code boutique mirror" to "Boutique STAR Code"',
#      '    RenamedColumns = Table.RenameColumns(DistinctMirrorCode, {{"Code boutique mirror ", "Boutique STAR Code"}}),',
#      '',
#      '    // Combine the original table and the updated table',
#      '    CombinedTable = Table.Combine({ChangedColumnTypes, RenamedColumns}),',
#      '',
#      '    // Remove the redundant "Code boutique mirror" column',
#      '    FinalResult = Table.RemoveColumns(CombinedTable, {"Code boutique mirror "}),',
#      '    RenameColumn = Table.RenameColumns(FinalResult,{{"Boutique STAR Code", "Boutique Code"}})',
#      'in',
#      '    RenameColumn'],
#     'type': 'm'}}]}

# %%
data = test_extraction['measures']

# %%
def extract_name_and_expression(elements):
    result = []
    for element in elements:
        name = element.get('name')
        # Combine the non-empty parts of the 'expression' list into a single string
        expression = " ".join(part.strip() for part in element.get('expression', []) if part.strip())
        result.append({'name': name, 'expression': expression})
    return result

result = extract_name_and_expression(data)
for item in result:
    print(item)
# Out:
# {'name': 'Nb of Clients who used the Wishlist', 'expression': 'DISTINCTCOUNT(fact_wishlist[fky_client])'}
# {'name': 'Wishlist usage frequency per client', 'expression': 'VAR distinct_days = DISTINCTCOUNT( \'fact_wishlist\'[lab_updatestatus] ) VAR t = SUMMARIZE( fact_wishlist, fact_wishlist[fky_client], "val", distinct_days ) RETURN AVERAGEX( t, [val] )'}
# {'name': 'Nb of Mirror Sessions', 'expression': 'CALCULATE( COUNTROWS(fact_mirror), FILTER( fact_mirror, fact_mirror[is_session_starting_time_validated] = TRUE() && fact_mirror[experience_Duration_valid] = TRUE() && fact_mirror[lab_sessiontype] = "external" ) )'}
# {'name': 'Share of Mirror Sessions attached to a client', 'expression': 'DIVIDE( CALCULATE( [Nb of Mirror Sessions] , fact_mirror[connection_mode] = "Client" ) , [Nb of Mirror Sessions] )'}
# {'name': 'Nb of clients attached to Mirror Sessions', 'expression': 'CALCULATE( DISTINCTCOUNT(fact_mirror[fky_client]), FILTER( fact_mirror, fact_mirror[is_session_starting_time_validated] = TRUE() && fact_mirror[experience_Duration_valid] = TRUE() && fact_mirror[lab_sessiontype] = "external" ) )'}
# {'name': 'Nb of Clients who opened a Chat', 'expression': 'C A L C U L A T E ( D I S T I N C T C O U N T ( \' f a c t _ f a s h i o n _ a p p \' [ f k y _ c l i e n t ] ) , F I L T E R ( \' f a c t _ f a s h i o n _ a p p \' , \' f a c t _ f a s h i o n _ a p p \' [ l a b _ U s e r T y p e ] = " I N C H A N E L " & & \' f a c t _ f a s h i o n _ a p p \' [ l a b _ M e t r i c T y p e ] = " U S E R S " & & \' f a c t _ f a s h i o n _ a p p \' [ l a b _ c h a t F A ] > 0 & & \' f a c t _ f a s h i o n _ a p p \' [ l a b _ S c o p e ] = " G L O B A L " ) )'}
# {'name': 'Nb of Clients who replied in a Chat', 'expression': 'D I S T I N C T C O U N T ( f a c t _ m e s s a g e [ f k y _ c h a n e l _ m e m b e r ] )'}
# {'name': 'Chat usage frequency per client', 'expression': 'VAR t = SUMMARIZE( \'fact_message\', \'fact_message\'[fky_chanel_member], "val", DISTINCTCOUNT(\'fact_message\'[dtm_createdat]) ) RETURN AVERAGEX( t, [val] )'}
# {'name': 'Nb of Clients who received a SB', 'expression': "D I S T I N C T C O U N T ( ' f a c t _ s u g g e s t i o n _ b o a r d ' [ f k y _ c l i e n t ] )"}
# {'name': 'Nb of Clients who opened a SB', 'expression': 'CALCULATE( DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]) , FILTER( \'fact_fashion_app\' , \'fact_fashion_app\'[lab_UserType] = "INCHANEL" && \'fact_fashion_app\'[lab_MetricType] = "USERS" && \'fact_fashion_app\'[lab_suggestionboardviews] > 0 && \'fact_fashion_app\'[lab_Scope] = "GLOBAL" ) )'}
# {'name': 'Nb of SB sent per client', 'expression': 'VAR sbe_nb_SuggestionBoard_Sent_eu = calculate( COUNTROWS(fact_suggestion_board) , filter( fact_suggestion_board , fact_suggestion_board[lab_status] = "SENT" ) ) RETURN DIVIDE( sbe_nb_SuggestionBoard_Sent_eu , [Nb of Clients who received a SB] )'}
# {'name': 'Whitelisted Clients', 'expression': 'CALCULATE( COUNTROWS(\'dim_client\'), dim_client[is_whitelisted] = "yes" )'}
# {'name': 'Nb of Onboarded Clients', 'expression': "CALCULATE( COUNTROWS('dim_client'), dim_client[is_onboarded] = TRUE() )"}
# {'name': 'INCHANEL ACTIVE Users', 'expression': 'CALCULATE( DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), \'fact_fashion_app\'[lab_usertype] = "INCHANEL" && \'fact_fashion_app\'[lab_metrictype] = "USERS" && \'fact_fashion_app\'[lab_scope] = "GLOBAL" )'}
# {'name': 'INCHANEL Active User 6 Months (Since Start)', 'expression': 'VAR MinDateFilter = MAX(dim_calendar[Date]) - 180  // date of 6 months ago RETURN CALCULATE( DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), FILTER(ALL(\'dim_calendar\'), dim_calendar[Date] >= MinDateFilter), KEEPFILTERS( \'fact_fashion_app\'[lab_usertype] = "INCHANEL" && \'fact_fashion_app\'[lab_metrictype] = "USERS" && \'fact_fashion_app\'[lab_scope] = "GLOBAL" ) )'}
# {'name': 'Monthly Repeated Users', 'expression': 'VAR min_date = min(dim_calendar[Date]) VAR max_date = max(dim_calendar[Date]) VAR MinDateFilter = max_date - 180 VAR avg_frequency = (max_date - min_date) / DISTINCTCOUNT(fact_fashion_app[dtm_fashionapp]) RETURN CALCULATE( DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), FILTER( \'fact_fashion_app\', \'fact_fashion_app\'[lab_usertype] = "INCHANEL" && \'fact_fashion_app\'[lab_metrictype] = "USERS" && \'fact_fashion_app\'[lab_scope] = "GLOBAL" && avg_frequency <= 28 ), FILTER( ALL(\'dim_calendar\'), dim_calendar[Date] >= MinDateFilter ) )'}
# {'name': 'Nb of FAs who onboarded a client', 'expression': 'CALCULATE( DISTINCTCOUNT(dim_client[fky_faofonboarding]), // fa of attachment to be added in case of that faofonboarding is blank FILTER( dim_client, dim_client[is_onboarded] = "Other" ) )'}
# {'name': 'Avg Onboarded Clients per FA', 'expression': 'VAR onboarded_client = CALCULATE( DISTINCTCOUNT(dim_client[pky_client]), FILTER( dim_client, dim_client[is_onboarded] = "Other" ) ) RETURN DIVIDE(onboarded_client, [Nb of FAs who onboarded a client])'}
# {'name': 'Nb of FAs who sent a SB', 'expression': 'D I S T I N C T C O U N T ( f a c t _ s u g g e s t i o n _ b o a r d [ f k y _ f a ] )'}
# {'name': 'Total of SB sent', 'expression': 'CALCULATE( DISTINCTCOUNT(fact_suggestion_board[pky_suggestion_board]) , FILTER( fact_suggestion_board , fact_suggestion_board[lab_status] = "SENT" ) )'}
# {'name': 'Nb of SB sent per FA', 'expression': '[ T o t a l o f S B s e n t ] / [ N b o f F A s w h o s e n t a S B ]'}
# {'name': 'Nb of FAs who sent a Chat', 'expression': 'D I S T I N C T C O U N T ( f a c t _ m e s s a g e [ f k y _ f a ] )'}
# {'name': 'Total of Chats', 'expression': 'CALCULATE( COUNT(fact_message[pky_message]) , FILTER( fact_message ,NOT(ISBLANK(fact_message[fky_fa])) ) )'}
# {'name': 'Nb of Chats sent per FA', 'expression': 'DIVIDE( [Total of Chats] , [Nb of FAs who sent a Chat] )'}
# {'name': 'Nb of FAs who did at least one Mirror Session', 'expression': 'CALCULATE( DISTINCTCOUNT(fact_mirror[fky_fa]), FILTER(fact_mirror, fact_mirror[experience_Duration_valid] = True ) )'}
# {'name': 'Nb of Mirror Sessions by FA', 'expression': '[ N b o f M i r r o r S e s s i o n s ] / [ N b o f F A s w h o d i d a t l e a s t o n e M i r r o r S e s s i o n ]'}

# %%
test_extraction.keys()
# Out:
# dict_keys(['expressions', 'tables'])

# %%
model_bim['model']['tables'][7]
# Out:
# {'name': 'Mesure',
#  'annotations': [{'name': 'PBI_ResultType', 'value': 'Table'}],
#  'lineageTag': 'f6b28902-600c-4245-9ec3-14d242fe77ea',
#  'measures': [{'name': 'Nb of Clients who used the Wishlist',
#    'displayFolder': 'wishlist',
#    'expression': ['', 'DISTINCTCOUNT(fact_wishlist[fky_client])', ''],
#    'formatString': '0',
#    'lineageTag': 'b04888e0-5770-4b38-be96-d2fc9d2b53c2'},
#   {'name': 'Wishlist usage frequency per client',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'wishlist',
#    'expression': ['',
#     'VAR distinct_days = ',
#     "DISTINCTCOUNT( 'fact_wishlist'[lab_updatestatus] )",
#     '',
#     'VAR t =',
#     '    SUMMARIZE(',
#     '        fact_wishlist,',
#     '        fact_wishlist[fky_client],',
#     '        "val", distinct_days',
#     '    )',
#     '',
#     'RETURN',
#     '    AVERAGEX(',
#     '        t,',
#     '        [val]',
#     '    )',
#     ''],
#    'lineageTag': '1117dc79-4a80-4df0-b02f-7ffd4be90d35'},
#   {'name': 'Nb of Mirror Sessions',
#    'displayFolder': 'mirror',
#    'expression': ['',
#     'CALCULATE(',
#     '    COUNTROWS(fact_mirror),',
#     '    FILTER(',
#     '        fact_mirror,',
#     '        fact_mirror[is_session_starting_time_validated] = TRUE() ',
#     '        && fact_mirror[experience_Duration_valid] = TRUE()',
#     '        && fact_mirror[lab_sessiontype] = "external"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': 'b1ca63bf-2377-4040-9aca-d5053bfea38f'},
#   {'name': 'Share of Mirror Sessions attached to a client',
#    'displayFolder': 'mirror',
#    'expression': ['',
#     'DIVIDE(',
#     '    CALCULATE(',
#     '        [Nb of Mirror Sessions]',
#     '        , fact_mirror[connection_mode] = "Client"',
#     '    )',
#     '    , [Nb of Mirror Sessions]',
#     ')'],
#    'formatString': '0%;-0%;0%',
#    'lineageTag': '3c56b624-7aeb-4c41-9e99-6e684abf9012'},
#   {'name': 'Nb of clients attached to Mirror Sessions',
#    'displayFolder': 'mirror',
#    'expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_mirror[fky_client]),',
#     '    FILTER(',
#     '        fact_mirror,',
#     '        fact_mirror[is_session_starting_time_validated] = TRUE()',
#     '        && fact_mirror[experience_Duration_valid] = TRUE()',
#     '        && fact_mirror[lab_sessiontype] = "external"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '9b413f73-7290-479e-8e65-fa5172d88cf2'},
#   {'name': 'Nb of Clients who opened a Chat',
#    'displayFolder': 'message',
#    'expression': 'CALCULATE(DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), FILTER(\'fact_fashion_app\', \'fact_fashion_app\'[lab_UserType] = "INCHANEL" && \'fact_fashion_app\'[lab_MetricType] = "USERS" && \'fact_fashion_app\'[lab_chatFA] > 0 && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"))',
#    'formatString': '0',
#    'lineageTag': '2cd21672-72fe-46dd-9a49-6290d81bf1f2'},
#   {'name': 'Nb of Clients who replied in a Chat',
#    'displayFolder': 'message',
#    'expression': 'DISTINCTCOUNT(fact_message[fky_chanel_member]) ',
#    'formatString': '0',
#    'lineageTag': '3db09d91-80d8-469a-85c2-f9cc7f39a378'},
#   {'name': 'Chat usage frequency per client',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'message',
#    'expression': ['',
#     'VAR t =',
#     '    SUMMARIZE(',
#     "        'fact_message',",
#     "        'fact_message'[fky_chanel_member],",
#     '        "val", DISTINCTCOUNT(\'fact_message\'[dtm_createdat])',
#     '    )',
#     'RETURN',
#     '    AVERAGEX(',
#     '        t,',
#     '        [val]',
#     '    )',
#     ''],
#    'lineageTag': '3dcc5cdf-2504-4383-b29e-4cd3fe611614'},
#   {'name': 'Nb of Clients who received a SB',
#    'displayFolder': 'suggestion board',
#    'expression': "DISTINCTCOUNT( 'fact_suggestion_board'[fky_client])",
#    'formatString': '0',
#    'lineageTag': '490eed12-fddf-454c-9494-e57e6f4bd4ea'},
#   {'name': 'Nb of Clients who opened a SB',
#    'displayFolder': 'suggestion board',
#    'expression': ['',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client])",
#     '    , FILTER(',
#     "        'fact_fashion_app'",
#     '        , \'fact_fashion_app\'[lab_UserType] = "INCHANEL" ',
#     '        && \'fact_fashion_app\'[lab_MetricType] = "USERS" ',
#     "        && 'fact_fashion_app'[lab_suggestionboardviews] > 0 ",
#     '        && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': 'f6ca8184-5764-4e52-af0d-4e0e11142ba6'},
#   {'name': 'Nb of SB sent per client',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'suggestion board',
#    'expression': ['',
#     '',
#     'VAR sbe_nb_SuggestionBoard_Sent_eu = ',
#     'calculate(',
#     '    COUNTROWS(fact_suggestion_board)',
#     '    , filter(',
#     '        fact_suggestion_board',
#     '        , fact_suggestion_board[lab_status] = "SENT" ',
#     '    )',
#     ')',
#     '',
#     'RETURN DIVIDE(',
#     '    sbe_nb_SuggestionBoard_Sent_eu',
#     '    , [Nb of Clients who received a SB]',
#     ')'],
#    'lineageTag': '331945d3-9ba7-41de-ba6a-142ed757a3bd'},
#   {'name': 'Whitelisted Clients',
#    'displayFolder': 'client',
#    'expression': ['',
#     'CALCULATE(',
#     "    COUNTROWS('dim_client'),",
#     '    dim_client[is_whitelisted] = "yes"',
#     ')'],
#    'formatString': '0',
#    'lineageTag': 'c1bc4709-a113-4cfb-8931-aff15d9b0dfd'},
#   {'name': 'Nb of Onboarded Clients',
#    'displayFolder': 'client',
#    'expression': ['',
#     'CALCULATE(',
#     "    COUNTROWS('dim_client'),",
#     '    dim_client[is_onboarded] = TRUE()',
#     ')'],
#    'formatString': '0',
#    'lineageTag': 'a1ee563a-1839-48c4-88b8-714681361154'},
#   {'name': 'INCHANEL ACTIVE Users',
#    'displayFolder': 'client',
#    'expression': ['',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     '    \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '    \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '    \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '488fb56e-ace9-4943-9cc6-a2c11f4ff028'},
#   {'name': 'INCHANEL Active User 6 Months (Since Start)',
#    'displayFolder': 'client',
#    'expression': ['',
#     'VAR MinDateFilter = MAX(dim_calendar[Date]) - 180  // date of 6 months ago',
#     '',
#     'RETURN',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     "    FILTER(ALL('dim_calendar'), dim_calendar[Date] >= MinDateFilter),",
#     '    KEEPFILTERS(',
#     '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '        \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#     '    )',
#     ')'],
#    'lineageTag': '977dd977-2c5b-4a9e-a122-2583530dbd2d'},
#   {'name': 'Monthly Repeated Users',
#    'displayFolder': 'client',
#    'expression': ['',
#     'VAR min_date = min(dim_calendar[Date])',
#     'VAR max_date = max(dim_calendar[Date])',
#     'VAR MinDateFilter = max_date - 180  ',
#     'VAR avg_frequency = (max_date - min_date) / DISTINCTCOUNT(fact_fashion_app[dtm_fashionapp])',
#     '',
#     'RETURN',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     '    FILTER(',
#     "        'fact_fashion_app',",
#     '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '        \'fact_fashion_app\'[lab_scope] = "GLOBAL" &&',
#     '         avg_frequency <= 28',
#     '    ),',
#     '    FILTER(',
#     "        ALL('dim_calendar'),",
#     '        dim_calendar[Date] >= MinDateFilter',
#     '    )',
#     ')',
#     ''],
#    'formatString': '0',
#    'lineageTag': '1b114ac1-f91c-4ce4-8d66-bf714560f7e4'},
#   {'name': 'Nb of FAs who onboarded a client',
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(dim_client[fky_faofonboarding]), // fa of attachment to be added in case of that faofonboarding is blank',
#     '    FILTER(',
#     '        dim_client,',
#     '        dim_client[is_onboarded] = "Other"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '43f7a150-f20e-4c18-97fe-8a5daa48240f'},
#   {'name': 'Avg Onboarded Clients per FA',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     'VAR onboarded_client = ',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(dim_client[pky_client]), ',
#     '    FILTER(',
#     '        dim_client,',
#     '        dim_client[is_onboarded] = "Other"',
#     '    )',
#     ')',
#     '',
#     'RETURN DIVIDE(onboarded_client, [Nb of FAs who onboarded a client])'],
#    'lineageTag': 'f1644c1f-f34d-406d-a190-3b47f06b0bd7'},
#   {'name': 'Nb of FAs who sent a SB',
#    'displayFolder': 'scope FA',
#    'expression': 'DISTINCTCOUNT(fact_suggestion_board[fky_fa])',
#    'formatString': '0',
#    'lineageTag': '23a4aaae-e5ec-495a-81fe-34dd2babad61'},
#   {'name': 'Total of SB sent',
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_suggestion_board[pky_suggestion_board])',
#     '    , FILTER(',
#     '        fact_suggestion_board',
#     '        , fact_suggestion_board[lab_status] = "SENT"',
#     '    )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '028e4af9-39cc-47fe-b114-629283df51b8'},
#   {'name': 'Nb of SB sent per FA',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'scope FA',
#    'expression': '[Total of SB sent] / [Nb of FAs who sent a SB] ',
#    'lineageTag': 'e9e0c141-91e3-4f13-871a-a7fcfc23b679'},
#   {'name': 'Nb of FAs who sent a Chat',
#    'displayFolder': 'scope FA',
#    'expression': 'DISTINCTCOUNT(fact_message[fky_fa])',
#    'lineageTag': 'c84dec07-2aad-4189-a033-b7b4f78fe1b3'},
#   {'name': 'Total of Chats',
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     '',
#     'CALCULATE(',
#     '    COUNT(fact_message[pky_message])',
#     '    , FILTER(',
#     '        fact_message',
#     '        ,NOT(ISBLANK(fact_message[fky_fa]))',
#     '    )',
#     ')'],
#    'lineageTag': '4324aca1-1c81-4e8e-9ba9-0da12c791f46'},
#   {'name': 'Nb of Chats sent per FA',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     'DIVIDE(',
#     '    [Total of Chats]',
#     '    , [Nb of FAs who sent a Chat]',
#     ')'],
#    'lineageTag': 'bb7437d2-5949-4c95-a0ed-1d915599fcbc'},
#   {'name': 'Nb of FAs who did at least one Mirror Session',
#    'displayFolder': 'scope FA',
#    'expression': ['',
#     '',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_mirror[fky_fa]),',
#     '    FILTER(fact_mirror,',
#     '    fact_mirror[experience_Duration_valid] = True',
#     '            )',
#     ')'],
#    'formatString': '0',
#    'lineageTag': '3e8b16d6-d9ac-4928-843c-ad516432f32e'},
#   {'name': 'Nb of Mirror Sessions by FA',
#    'annotations': [{'name': 'PBI_FormatHint',
#      'value': '{"isGeneralNumber":true}'}],
#    'displayFolder': 'scope FA',
#    'expression': '[Nb of Mirror Sessions] / [Nb of FAs who did at least one Mirror Session]',
#    'lineageTag': 'c8bee7b8-2c47-4585-85d4-cf27d36824e3'}],
#  'partitions': [{'name': 'Mesure',
#    'mode': 'import',
#    'source': {'expression': ['let',
#      '    Source = Table.FromRows(Json.Document(Binary.Decompress(Binary.FromText("i44FAA==", BinaryEncoding.Base64), Compression.Deflate)), let _t = ((type nullable text) meta [Serialized.Text = true]) in type table [temp = _t]),',
#      '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"temp", type text}}),',
#      '    #"Colonnes supprimées" = Table.RemoveColumns(#"Type modifié",{"temp"})',
#      'in',
#      '    #"Colonnes supprimées"'],
#     'type': 'm'}}]}

# %%
model_bim['model']['tables'][7]['measures']
# Out:
# [{'name': 'Nb of Clients who used the Wishlist',
#   'displayFolder': 'wishlist',
#   'expression': ['', 'DISTINCTCOUNT(fact_wishlist[fky_client])', ''],
#   'formatString': '0',
#   'lineageTag': 'b04888e0-5770-4b38-be96-d2fc9d2b53c2'},
#  {'name': 'Wishlist usage frequency per client',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'wishlist',
#   'expression': ['',
#    'VAR distinct_days = ',
#    "DISTINCTCOUNT( 'fact_wishlist'[lab_updatestatus] )",
#    '',
#    'VAR t =',
#    '    SUMMARIZE(',
#    '        fact_wishlist,',
#    '        fact_wishlist[fky_client],',
#    '        "val", distinct_days',
#    '    )',
#    '',
#    'RETURN',
#    '    AVERAGEX(',
#    '        t,',
#    '        [val]',
#    '    )',
#    ''],
#   'lineageTag': '1117dc79-4a80-4df0-b02f-7ffd4be90d35'},
#  {'name': 'Nb of Mirror Sessions',
#   'displayFolder': 'mirror',
#   'expression': ['',
#    'CALCULATE(',
#    '    COUNTROWS(fact_mirror),',
#    '    FILTER(',
#    '        fact_mirror,',
#    '        fact_mirror[is_session_starting_time_validated] = TRUE() ',
#    '        && fact_mirror[experience_Duration_valid] = TRUE()',
#    '        && fact_mirror[lab_sessiontype] = "external"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': 'b1ca63bf-2377-4040-9aca-d5053bfea38f'},
#  {'name': 'Share of Mirror Sessions attached to a client',
#   'displayFolder': 'mirror',
#   'expression': ['',
#    'DIVIDE(',
#    '    CALCULATE(',
#    '        [Nb of Mirror Sessions]',
#    '        , fact_mirror[connection_mode] = "Client"',
#    '    )',
#    '    , [Nb of Mirror Sessions]',
#    ')'],
#   'formatString': '0%;-0%;0%',
#   'lineageTag': '3c56b624-7aeb-4c41-9e99-6e684abf9012'},
#  {'name': 'Nb of clients attached to Mirror Sessions',
#   'displayFolder': 'mirror',
#   'expression': ['',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(fact_mirror[fky_client]),',
#    '    FILTER(',
#    '        fact_mirror,',
#    '        fact_mirror[is_session_starting_time_validated] = TRUE()',
#    '        && fact_mirror[experience_Duration_valid] = TRUE()',
#    '        && fact_mirror[lab_sessiontype] = "external"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '9b413f73-7290-479e-8e65-fa5172d88cf2'},
#  {'name': 'Nb of Clients who opened a Chat',
#   'displayFolder': 'message',
#   'expression': 'CALCULATE(DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), FILTER(\'fact_fashion_app\', \'fact_fashion_app\'[lab_UserType] = "INCHANEL" && \'fact_fashion_app\'[lab_MetricType] = "USERS" && \'fact_fashion_app\'[lab_chatFA] > 0 && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"))',
#   'formatString': '0',
#   'lineageTag': '2cd21672-72fe-46dd-9a49-6290d81bf1f2'},
#  {'name': 'Nb of Clients who replied in a Chat',
#   'displayFolder': 'message',
#   'expression': 'DISTINCTCOUNT(fact_message[fky_chanel_member]) ',
#   'formatString': '0',
#   'lineageTag': '3db09d91-80d8-469a-85c2-f9cc7f39a378'},
#  {'name': 'Chat usage frequency per client',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'message',
#   'expression': ['',
#    'VAR t =',
#    '    SUMMARIZE(',
#    "        'fact_message',",
#    "        'fact_message'[fky_chanel_member],",
#    '        "val", DISTINCTCOUNT(\'fact_message\'[dtm_createdat])',
#    '    )',
#    'RETURN',
#    '    AVERAGEX(',
#    '        t,',
#    '        [val]',
#    '    )',
#    ''],
#   'lineageTag': '3dcc5cdf-2504-4383-b29e-4cd3fe611614'},
#  {'name': 'Nb of Clients who received a SB',
#   'displayFolder': 'suggestion board',
#   'expression': "DISTINCTCOUNT( 'fact_suggestion_board'[fky_client])",
#   'formatString': '0',
#   'lineageTag': '490eed12-fddf-454c-9494-e57e6f4bd4ea'},
#  {'name': 'Nb of Clients who opened a SB',
#   'displayFolder': 'suggestion board',
#   'expression': ['',
#    'CALCULATE(',
#    "    DISTINCTCOUNT('fact_fashion_app'[fky_client])",
#    '    , FILTER(',
#    "        'fact_fashion_app'",
#    '        , \'fact_fashion_app\'[lab_UserType] = "INCHANEL" ',
#    '        && \'fact_fashion_app\'[lab_MetricType] = "USERS" ',
#    "        && 'fact_fashion_app'[lab_suggestionboardviews] > 0 ",
#    '        && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': 'f6ca8184-5764-4e52-af0d-4e0e11142ba6'},
#  {'name': 'Nb of SB sent per client',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'suggestion board',
#   'expression': ['',
#    '',
#    'VAR sbe_nb_SuggestionBoard_Sent_eu = ',
#    'calculate(',
#    '    COUNTROWS(fact_suggestion_board)',
#    '    , filter(',
#    '        fact_suggestion_board',
#    '        , fact_suggestion_board[lab_status] = "SENT" ',
#    '    )',
#    ')',
#    '',
#    'RETURN DIVIDE(',
#    '    sbe_nb_SuggestionBoard_Sent_eu',
#    '    , [Nb of Clients who received a SB]',
#    ')'],
#   'lineageTag': '331945d3-9ba7-41de-ba6a-142ed757a3bd'},
#  {'name': 'Whitelisted Clients',
#   'displayFolder': 'client',
#   'expression': ['',
#    'CALCULATE(',
#    "    COUNTROWS('dim_client'),",
#    '    dim_client[is_whitelisted] = "yes"',
#    ')'],
#   'formatString': '0',
#   'lineageTag': 'c1bc4709-a113-4cfb-8931-aff15d9b0dfd'},
#  {'name': 'Nb of Onboarded Clients',
#   'displayFolder': 'client',
#   'expression': ['',
#    'CALCULATE(',
#    "    COUNTROWS('dim_client'),",
#    '    dim_client[is_onboarded] = TRUE()',
#    ')'],
#   'formatString': '0',
#   'lineageTag': 'a1ee563a-1839-48c4-88b8-714681361154'},
#  {'name': 'INCHANEL ACTIVE Users',
#   'displayFolder': 'client',
#   'expression': ['',
#    'CALCULATE(',
#    "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#    '    \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#    '    \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#    '    \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '488fb56e-ace9-4943-9cc6-a2c11f4ff028'},
#  {'name': 'INCHANEL Active User 6 Months (Since Start)',
#   'displayFolder': 'client',
#   'expression': ['',
#    'VAR MinDateFilter = MAX(dim_calendar[Date]) - 180  // date of 6 months ago',
#    '',
#    'RETURN',
#    'CALCULATE(',
#    "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#    "    FILTER(ALL('dim_calendar'), dim_calendar[Date] >= MinDateFilter),",
#    '    KEEPFILTERS(',
#    '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#    '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#    '        \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#    '    )',
#    ')'],
#   'lineageTag': '977dd977-2c5b-4a9e-a122-2583530dbd2d'},
#  {'name': 'Monthly Repeated Users',
#   'displayFolder': 'client',
#   'expression': ['',
#    'VAR min_date = min(dim_calendar[Date])',
#    'VAR max_date = max(dim_calendar[Date])',
#    'VAR MinDateFilter = max_date - 180  ',
#    'VAR avg_frequency = (max_date - min_date) / DISTINCTCOUNT(fact_fashion_app[dtm_fashionapp])',
#    '',
#    'RETURN',
#    'CALCULATE(',
#    "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#    '    FILTER(',
#    "        'fact_fashion_app',",
#    '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#    '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#    '        \'fact_fashion_app\'[lab_scope] = "GLOBAL" &&',
#    '         avg_frequency <= 28',
#    '    ),',
#    '    FILTER(',
#    "        ALL('dim_calendar'),",
#    '        dim_calendar[Date] >= MinDateFilter',
#    '    )',
#    ')',
#    ''],
#   'formatString': '0',
#   'lineageTag': '1b114ac1-f91c-4ce4-8d66-bf714560f7e4'},
#  {'name': 'Nb of FAs who onboarded a client',
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(dim_client[fky_faofonboarding]), // fa of attachment to be added in case of that faofonboarding is blank',
#    '    FILTER(',
#    '        dim_client,',
#    '        dim_client[is_onboarded] = "Other"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '43f7a150-f20e-4c18-97fe-8a5daa48240f'},
#  {'name': 'Avg Onboarded Clients per FA',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    'VAR onboarded_client = ',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(dim_client[pky_client]), ',
#    '    FILTER(',
#    '        dim_client,',
#    '        dim_client[is_onboarded] = "Other"',
#    '    )',
#    ')',
#    '',
#    'RETURN DIVIDE(onboarded_client, [Nb of FAs who onboarded a client])'],
#   'lineageTag': 'f1644c1f-f34d-406d-a190-3b47f06b0bd7'},
#  {'name': 'Nb of FAs who sent a SB',
#   'displayFolder': 'scope FA',
#   'expression': 'DISTINCTCOUNT(fact_suggestion_board[fky_fa])',
#   'formatString': '0',
#   'lineageTag': '23a4aaae-e5ec-495a-81fe-34dd2babad61'},
#  {'name': 'Total of SB sent',
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(fact_suggestion_board[pky_suggestion_board])',
#    '    , FILTER(',
#    '        fact_suggestion_board',
#    '        , fact_suggestion_board[lab_status] = "SENT"',
#    '    )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '028e4af9-39cc-47fe-b114-629283df51b8'},
#  {'name': 'Nb of SB sent per FA',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'scope FA',
#   'expression': '[Total of SB sent] / [Nb of FAs who sent a SB] ',
#   'lineageTag': 'e9e0c141-91e3-4f13-871a-a7fcfc23b679'},
#  {'name': 'Nb of FAs who sent a Chat',
#   'displayFolder': 'scope FA',
#   'expression': 'DISTINCTCOUNT(fact_message[fky_fa])',
#   'lineageTag': 'c84dec07-2aad-4189-a033-b7b4f78fe1b3'},
#  {'name': 'Total of Chats',
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    '',
#    'CALCULATE(',
#    '    COUNT(fact_message[pky_message])',
#    '    , FILTER(',
#    '        fact_message',
#    '        ,NOT(ISBLANK(fact_message[fky_fa]))',
#    '    )',
#    ')'],
#   'lineageTag': '4324aca1-1c81-4e8e-9ba9-0da12c791f46'},
#  {'name': 'Nb of Chats sent per FA',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    'DIVIDE(',
#    '    [Total of Chats]',
#    '    , [Nb of FAs who sent a Chat]',
#    ')'],
#   'lineageTag': 'bb7437d2-5949-4c95-a0ed-1d915599fcbc'},
#  {'name': 'Nb of FAs who did at least one Mirror Session',
#   'displayFolder': 'scope FA',
#   'expression': ['',
#    '',
#    'CALCULATE(',
#    '    DISTINCTCOUNT(fact_mirror[fky_fa]),',
#    '    FILTER(fact_mirror,',
#    '    fact_mirror[experience_Duration_valid] = True',
#    '            )',
#    ')'],
#   'formatString': '0',
#   'lineageTag': '3e8b16d6-d9ac-4928-843c-ad516432f32e'},
#  {'name': 'Nb of Mirror Sessions by FA',
#   'annotations': [{'name': 'PBI_FormatHint',
#     'value': '{"isGeneralNumber":true}'}],
#   'displayFolder': 'scope FA',
#   'expression': '[Nb of Mirror Sessions] / [Nb of FAs who did at least one Mirror Session]',
#   'lineageTag': 'c8bee7b8-2c47-4585-85d4-cf27d36824e3'}]

# %%
model_bim['model']['tables'][0].keys()
# Out:
# dict_keys(['name', 'annotations', 'columns', 'hierarchies', 'isHidden', 'isPrivate', 'lineageTag', 'partitions'])

# %%
dictionary_table = model_bim['model']['tables'][0]
dictionary_table.remove['annotations']
# Out:
# [{'name': 'PBI_ResultType', 'value': 'Table'},
#  {'name': 'PBI_NavigationStepName', 'value': 'Navigation'}]

# %%
relevant_info = extract_relevant_elements_dashboard_summary(model_bim)

# %%
relevant_info
# Out:
# {'expressions': [{'name': 'server_id',
#    'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#     {'name': 'PBI_ResultType', 'value': 'Text'}],
#    'description': 'Azure server name',
#    'expression': '"asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#    'kind': 'm',
#    'lineageTag': 'acf363bb-3a3b-4c63-8ce9-64df713220f6',
#    'queryGroup': 'parameters'},
#   {'name': 'database_id',
#    'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#     {'name': 'PBI_ResultType', 'value': 'Text'}],
#    'expression': '"dhfsh-gold" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#    'kind': 'm',
#    'lineageTag': 'a29a4a2c-53d5-46aa-a171-21ed366054bd',
#    'queryGroup': 'parameters'},
#   {'name': 'storage_id',
#    'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#     {'name': 'PBI_ResultType', 'value': 'Text'}],
#    'description': 'Azure blob storage id',
#    'expression': '"sastddthglbfsh1rawweuuat" meta [IsParameterQuery=true, Type="Any", IsParameterQueryRequired=true]',
#    'kind': 'm',
#    'lineageTag': 'cb07b717-ca14-4a97-9812-d5f687ce77b9',
#    'queryGroup': 'parameters'}],
#  'tables': [{'name': 'fact_wishlist',
#    'annotations': [{'name': 'PBI_ResultType', 'value': 'Table'},
#     {'name': 'PBI_NavigationStepName', 'value': 'Navigation'}],
#    'columns': [{'name': 'pky_wishlist',
#      'dataType': 'string',
#      'lineageTag': 'f546e353-f1c9-4624-8a07-28de975d0bad',
#      'sourceColumn': 'pky_wishlist',
#      'summarizeBy': 'none'},
#     {'name': 'fky_client',
#      'dataType': 'string',
#      'lineageTag': 'baac1fca-4c5b-4f5c-81a0-13ca08fae612',
#      'sourceColumn': 'fky_client',
#      'summarizeBy': 'none'},
#     {'name': 'lab_status',
#      'dataType': 'string',
#      'lineageTag': 'dcb040a5-cb04-45f2-b4e0-7f9252905a27',
#      'sourceColumn': 'lab_status',
#      'summarizeBy': 'none'},
#     {'name': 'lab_updatestatus',
#      'dataType': 'dateTime',
#      'formatString': 'Short Date',
#      'lineageTag': 'a71ea34b-d29e-42ca-9110-62a510ac54f5',
#      'sourceColumn': 'lab_updatestatus',
#      'summarizeBy': 'none'},
#     {'name': 'client_attached_boutique',
#      'dataType': 'string',
#      'lineageTag': 'dca989eb-b2b8-4e0b-89f0-846e5e3b0b53',
#      'sourceColumn': 'client_attached_boutique',
#      'summarizeBy': 'none'}],
#    'lineageTag': '9c1984fe-b967-4432-a514-8fc84ea3c5e4',
#    'partitions': [{'name': 'fact_wishlist',
#      'mode': 'import',
#      'queryGroup': 'fact',
#      'source': {'expression': ['let',
#        '    Source = Sql.Database(',
#        '        server_id, ',
#        '        database_id, ',
#        '        [Query = "SELECT *',
#        '                  FROM OPENROWSET(',
#        '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_wishlist/\',',
#        "                        FORMAT = 'DELTA'",
#        '                    ) AS [result]"',
#        '        ]',
#        '    ),',
#        '    #"Modify Date Column Format" = Table.TransformColumnTypes(Source,{{"lab_updatestatus", type date}}),',
#        '    #"Lignes filtrées" = Table.SelectRows(#"Modify Date Column Format", each true)',
#        'in',
#        '    #"Lignes filtrées"'],
#       'type': 'm'}}]},
#   {'name': 'dim_calendar',
#    'annotations': [{'name': 'PBI_ResultType', 'value': 'Table'},
#     {'name': 'PBI_NavigationStepName', 'value': 'Navigation'}],
#    'columns': [{'name': 'Date ID',
#      'dataType': 'string',
#      'lineageTag': '1c6cb0d4-533d-49d7-a124-b2ed3c399810',
#      'sourceColumn': 'Date ID',
#      'summarizeBy': 'none'},
#     {'name': 'Date',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': '7f153662-84ce-4170-ad03-a4cf2065f13d',
#      'sourceColumn': 'Date',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_822da7e9-510e-4037-be69-095aaa0a2010'},
#        'isDefault': True,
#        'relationship': 'f14ab861-6de1-4ee5-83f7-0d54e5b5938c'}]},
#     {'name': 'Year',
#      'dataType': 'string',
#      'lineageTag': 'cc9765fe-cde4-4e22-920a-632f8e5964ff',
#      'sourceColumn': 'Year',
#      'summarizeBy': 'none'},
#     {'name': 'Month',
#      'dataType': 'int64',
#      'formatString': '0',
#      'lineageTag': '0c67be34-3111-4f55-8218-0a0e832c946a',
#      'sourceColumn': 'Month',
#      'summarizeBy': 'sum'},
#     {'name': 'Quanter',
#      'dataType': 'int64',
#      'formatString': '0',
#      'lineageTag': '28d1cc69-027e-4895-82f7-08263740408e',
#      'sourceColumn': 'Quanter',
#      'summarizeBy': 'sum'},
#     {'name': 'Start of the Month',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': 'be89b095-5f27-4667-9e85-94e6fc7e01c6',
#      'sourceColumn': 'Start of the Month',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_4de7692d-409c-4065-9503-d0b84e2f7489'},
#        'isDefault': True,
#        'relationship': 'c9107009-412b-4574-980c-7ed8c5a62a86'}]},
#     {'name': 'End of the Month',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': '33b5e3f9-7160-4e36-b542-5160087d659f',
#      'sourceColumn': 'End of the Month',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_9a1422c1-22fb-462c-9059-dcf138aec3e7'},
#        'isDefault': True,
#        'relationship': '3b1de498-ce49-4932-8bda-832bd1565be8'}]},
#     {'name': 'Name of the month',
#      'dataType': 'string',
#      'lineageTag': '6f663d66-015a-456f-86cd-8fe22f828b61',
#      'sourceColumn': 'Name of the month',
#      'summarizeBy': 'none'},
#     {'name': 'Month_year_name',
#      'dataType': 'string',
#      'lineageTag': '051e9f12-a50b-4884-ac61-39d69c299422',
#      'sourceColumn': 'Month_year_name',
#      'summarizeBy': 'none'},
#     {'name': 'Start of the Week',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': '830d8782-88c0-4a3e-817f-2837bcb46654',
#      'sourceColumn': 'Start of the Week',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_fdf3cfa6-ac4f-4279-80cf-cd75cf0f5ed8'},
#        'isDefault': True,
#        'relationship': '24216199-4312-4a98-852f-b1a9e44c6405'}]},
#     {'name': 'PrimaryKey',
#      'dataType': 'int64',
#      'formatString': '0',
#      'lineageTag': 'ac9558c0-5506-4b66-89fe-a88e3c198a38',
#      'sourceColumn': 'PrimaryKey',
#      'summarizeBy': 'count'}],
#    'lineageTag': '25be8507-aaef-45a8-87ba-484593d9d0ea',
#    'partitions': [{'name': 'dim_calendar',
#      'mode': 'import',
#      'queryGroup': 'dimension',
#      'source': {'expression': ['let',
#        '    Source = let',
#        '    Source = let',
#        '    Source = "",',
#        '    StartDate = #date(2019, 1, 1),',
#        '    EndDate = #date(2029, 1, 1),',
#        '    Duration = Duration.Days(EndDate - StartDate),',
#        '    DefineInterval = List.Dates(StartDate, Duration, #duration(1, 0, 0, 0)),',
#        '    ConvertToTable = Table.FromList(DefineInterval, Splitter.SplitByNothing(), null, null, ExtraValues.Error),',
#        '    RenameColumns = Table.RenameColumns(ConvertToTable, {{"Column1", "Date"}}),',
#        '    ModifyType = Table.TransformColumnTypes(RenameColumns, {{"Date", type date}}),',
#        '    AddDateID = Table.AddColumn(ModifyType, "Date ID", each Date.ToText([Date], "YYYYMMDD")),',
#        '    ReorderColumns = Table.ReorderColumns(AddDateID, {"Date ID", "Date"}),',
#        '    AddYearColumn = Table.AddColumn(ReorderColumns, "Année", each Date.Year([Date]), Int64.Type),',
#        '    ModifyYearType = Table.TransformColumnTypes(AddYearColumn, {{"Année", type text}}),',
#        '    AddMonthColumn = Table.AddColumn(ModifyYearType, "Mois", each Date.Month([Date]), Int64.Type),',
#        '    AddQuarterColumn = Table.AddColumn(AddMonthColumn, "Trimestre", each Date.QuarterOfYear([Date]), Int64.Type),',
#        '    AddStartOfMonth = Table.AddColumn(AddQuarterColumn, "Début de mois", each Date.StartOfMonth([Date]), type date),',
#        '    AddEndOfMonth = Table.AddColumn(AddStartOfMonth, "Fin du mois", each Date.EndOfMonth([Date]), type date),',
#        '    AddNameOfMonth = Table.AddColumn(AddEndOfMonth, "Nom du mois", each Date.MonthName([Date]), type text),',
#        '    AddMonthYearName = Table.AddColumn(AddNameOfMonth, "Month_year_name", each [Nom du mois] & " " & [Année]),',
#        '    AddStartOfWeek = Table.AddColumn(AddMonthYearName, "Début de semaine", each Date.StartOfWeek([Date]), type date),',
#        '    AddIndexColumn = Table.AddIndexColumn(AddStartOfWeek, "PrimaryKey", 1, 1, Int64.Type),',
#        '    RenameFinalColumns = Table.RenameColumns(AddIndexColumn, {{"Année", "Year"}, {"Mois", "Month"}, {"Trimestre", "Quanter"}, {"Début de mois", "Start of the Month"}, {"Nom du mois", "Name of the month"}, {"Fin du mois", "End of the Month"}, {"Début de semaine", "Start of the Week"}})',
#        'in',
#        '    RenameFinalColumns',
#        'in',
#        '    Source',
#        'in',
#        '    Source'],
#       'type': 'm'}}]},
#   {'name': 'Mesure',
#    'annotations': [{'name': 'PBI_ResultType', 'value': 'Table'}],
#    'lineageTag': 'f6b28902-600c-4245-9ec3-14d242fe77ea',
#    'measures': [{'name': 'Nb of Clients who used the Wishlist',
#      'displayFolder': 'wishlist',
#      'expression': ['', 'DISTINCTCOUNT(fact_wishlist[fky_client])', ''],
#      'formatString': '0',
#      'lineageTag': 'b04888e0-5770-4b38-be96-d2fc9d2b53c2'},
#     {'name': 'Wishlist usage frequency per client',
#      'annotations': [{'name': 'PBI_FormatHint',
#        'value': '{"isGeneralNumber":true}'}],
#      'displayFolder': 'wishlist',
#      'expression': ['',
#       'VAR distinct_days = ',
#       "DISTINCTCOUNT( 'fact_wishlist'[lab_updatestatus] )",
#       '',
#       'VAR t =',
#       '    SUMMARIZE(',
#       '        fact_wishlist,',
#       '        fact_wishlist[fky_client],',
#       '        "val", distinct_days',
#       '    )',
#       '',
#       'RETURN',
#       '    AVERAGEX(',
#       '        t,',
#       '        [val]',
#       '    )',
#       ''],
#      'lineageTag': '1117dc79-4a80-4df0-b02f-7ffd4be90d35'},
#     {'name': 'Nb of Mirror Sessions',
#      'displayFolder': 'mirror',
#      'expression': ['',
#       'CALCULATE(',
#       '    COUNTROWS(fact_mirror),',
#       '    FILTER(',
#       '        fact_mirror,',
#       '        fact_mirror[is_session_starting_time_validated] = TRUE() ',
#       '        && fact_mirror[experience_Duration_valid] = TRUE()',
#       '        && fact_mirror[lab_sessiontype] = "external"',
#       '    )',
#       ')'],
#      'formatString': '0',
#      'lineageTag': 'b1ca63bf-2377-4040-9aca-d5053bfea38f'},
#     {'name': 'Share of Mirror Sessions attached to a client',
#      'displayFolder': 'mirror',
#      'expression': ['',
#       'DIVIDE(',
#       '    CALCULATE(',
#       '        [Nb of Mirror Sessions]',
#       '        , fact_mirror[connection_mode] = "Client"',
#       '    )',
#       '    , [Nb of Mirror Sessions]',
#       ')'],
#      'formatString': '0%;-0%;0%',
#      'lineageTag': '3c56b624-7aeb-4c41-9e99-6e684abf9012'},
#     {'name': 'Nb of clients attached to Mirror Sessions',
#      'displayFolder': 'mirror',
#      'expression': ['',
#       'CALCULATE(',
#       '    DISTINCTCOUNT(fact_mirror[fky_client]),',
#       '    FILTER(',
#       '        fact_mirror,',
#       '        fact_mirror[is_session_starting_time_validated] = TRUE()',
#       '        && fact_mirror[experience_Duration_valid] = TRUE()',
#       '        && fact_mirror[lab_sessiontype] = "external"',
#       '    )',
#       ')'],
#      'formatString': '0',
#      'lineageTag': '9b413f73-7290-479e-8e65-fa5172d88cf2'},
#     {'name': 'Nb of Clients who opened a Chat',
#      'displayFolder': 'message',
#      'expression': 'CALCULATE(DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), FILTER(\'fact_fashion_app\', \'fact_fashion_app\'[lab_UserType] = "INCHANEL" && \'fact_fashion_app\'[lab_MetricType] = "USERS" && \'fact_fashion_app\'[lab_chatFA] > 0 && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"))',
#      'formatString': '0',
#      'lineageTag': '2cd21672-72fe-46dd-9a49-6290d81bf1f2'},
#     {'name': 'Nb of Clients who replied in a Chat',
#      'displayFolder': 'message',
#      'expression': 'DISTINCTCOUNT(fact_message[fky_chanel_member]) ',
#      'formatString': '0',
#      'lineageTag': '3db09d91-80d8-469a-85c2-f9cc7f39a378'},
#     {'name': 'Chat usage frequency per client',
#      'annotations': [{'name': 'PBI_FormatHint',
#        'value': '{"isGeneralNumber":true}'}],
#      'displayFolder': 'message',
#      'expression': ['',
#       'VAR t =',
#       '    SUMMARIZE(',
#       "        'fact_message',",
#       "        'fact_message'[fky_chanel_member],",
#       '        "val", DISTINCTCOUNT(\'fact_message\'[dtm_createdat])',
#       '    )',
#       'RETURN',
#       '    AVERAGEX(',
#       '        t,',
#       '        [val]',
#       '    )',
#       ''],
#      'lineageTag': '3dcc5cdf-2504-4383-b29e-4cd3fe611614'},
#     {'name': 'Nb of Clients who received a SB',
#      'displayFolder': 'suggestion board',
#      'expression': "DISTINCTCOUNT( 'fact_suggestion_board'[fky_client])",
#      'formatString': '0',
#      'lineageTag': '490eed12-fddf-454c-9494-e57e6f4bd4ea'},
#     {'name': 'Nb of Clients who opened a SB',
#      'displayFolder': 'suggestion board',
#      'expression': ['',
#       'CALCULATE(',
#       "    DISTINCTCOUNT('fact_fashion_app'[fky_client])",
#       '    , FILTER(',
#       "        'fact_fashion_app'",
#       '        , \'fact_fashion_app\'[lab_UserType] = "INCHANEL" ',
#       '        && \'fact_fashion_app\'[lab_MetricType] = "USERS" ',
#       "        && 'fact_fashion_app'[lab_suggestionboardviews] > 0 ",
#       '        && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"',
#       '    )',
#       ')'],
#      'formatString': '0',
#      'lineageTag': 'f6ca8184-5764-4e52-af0d-4e0e11142ba6'},
#     {'name': 'Nb of SB sent per client',
#      'annotations': [{'name': 'PBI_FormatHint',
#        'value': '{"isGeneralNumber":true}'}],
#      'displayFolder': 'suggestion board',
#      'expression': ['',
#       '',
#       'VAR sbe_nb_SuggestionBoard_Sent_eu = ',
#       'calculate(',
#       '    COUNTROWS(fact_suggestion_board)',
#       '    , filter(',
#       '        fact_suggestion_board',
#       '        , fact_suggestion_board[lab_status] = "SENT" ',
#       '    )',
#       ')',
#       '',
#       'RETURN DIVIDE(',
#       '    sbe_nb_SuggestionBoard_Sent_eu',
#       '    , [Nb of Clients who received a SB]',
#       ')'],
#      'lineageTag': '331945d3-9ba7-41de-ba6a-142ed757a3bd'},
#     {'name': 'Whitelisted Clients',
#      'displayFolder': 'client',
#      'expression': ['',
#       'CALCULATE(',
#       "    COUNTROWS('dim_client'),",
#       '    dim_client[is_whitelisted] = "yes"',
#       ')'],
#      'formatString': '0',
#      'lineageTag': 'c1bc4709-a113-4cfb-8931-aff15d9b0dfd'},
#     {'name': 'Nb of Onboarded Clients',
#      'displayFolder': 'client',
#      'expression': ['',
#       'CALCULATE(',
#       "    COUNTROWS('dim_client'),",
#       '    dim_client[is_onboarded] = TRUE()',
#       ')'],
#      'formatString': '0',
#      'lineageTag': 'a1ee563a-1839-48c4-88b8-714681361154'},
#     {'name': 'INCHANEL ACTIVE Users',
#      'displayFolder': 'client',
#      'expression': ['',
#       'CALCULATE(',
#       "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#       '    \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#       '    \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#       '    \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#       ')'],
#      'formatString': '0',
#      'lineageTag': '488fb56e-ace9-4943-9cc6-a2c11f4ff028'},
#     {'name': 'INCHANEL Active User 6 Months (Since Start)',
#      'displayFolder': 'client',
#      'expression': ['',
#       'VAR MinDateFilter = MAX(dim_calendar[Date]) - 180  // date of 6 months ago',
#       '',
#       'RETURN',
#       'CALCULATE(',
#       "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#       "    FILTER(ALL('dim_calendar'), dim_calendar[Date] >= MinDateFilter),",
#       '    KEEPFILTERS(',
#       '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#       '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#       '        \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#       '    )',
#       ')'],
#      'lineageTag': '977dd977-2c5b-4a9e-a122-2583530dbd2d'},
#     {'name': 'Monthly Repeated Users',
#      'displayFolder': 'client',
#      'expression': ['',
#       'VAR min_date = min(dim_calendar[Date])',
#       'VAR max_date = max(dim_calendar[Date])',
#       'VAR MinDateFilter = max_date - 180  ',
#       'VAR avg_frequency = (max_date - min_date) / DISTINCTCOUNT(fact_fashion_app[dtm_fashionapp])',
#       '',
#       'RETURN',
#       'CALCULATE(',
#       "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#       '    FILTER(',
#       "        'fact_fashion_app',",
#       '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#       '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#       '        \'fact_fashion_app\'[lab_scope] = "GLOBAL" &&',
#       '         avg_frequency <= 28',
#       '    ),',
#       '    FILTER(',
#       "        ALL('dim_calendar'),",
#       '        dim_calendar[Date] >= MinDateFilter',
#       '    )',
#       ')',
#       ''],
#      'formatString': '0',
#      'lineageTag': '1b114ac1-f91c-4ce4-8d66-bf714560f7e4'},
#     {'name': 'Nb of FAs who onboarded a client',
#      'displayFolder': 'scope FA',
#      'expression': ['',
#       'CALCULATE(',
#       '    DISTINCTCOUNT(dim_client[fky_faofonboarding]), // fa of attachment to be added in case of that faofonboarding is blank',
#       '    FILTER(',
#       '        dim_client,',
#       '        dim_client[is_onboarded] = "Other"',
#       '    )',
#       ')'],
#      'formatString': '0',
#      'lineageTag': '43f7a150-f20e-4c18-97fe-8a5daa48240f'},
#     {'name': 'Avg Onboarded Clients per FA',
#      'annotations': [{'name': 'PBI_FormatHint',
#        'value': '{"isGeneralNumber":true}'}],
#      'displayFolder': 'scope FA',
#      'expression': ['',
#       'VAR onboarded_client = ',
#       'CALCULATE(',
#       '    DISTINCTCOUNT(dim_client[pky_client]), ',
#       '    FILTER(',
#       '        dim_client,',
#       '        dim_client[is_onboarded] = "Other"',
#       '    )',
#       ')',
#       '',
#       'RETURN DIVIDE(onboarded_client, [Nb of FAs who onboarded a client])'],
#      'lineageTag': 'f1644c1f-f34d-406d-a190-3b47f06b0bd7'},
#     {'name': 'Nb of FAs who sent a SB',
#      'displayFolder': 'scope FA',
#      'expression': 'DISTINCTCOUNT(fact_suggestion_board[fky_fa])',
#      'formatString': '0',
#      'lineageTag': '23a4aaae-e5ec-495a-81fe-34dd2babad61'},
#     {'name': 'Total of SB sent',
#      'displayFolder': 'scope FA',
#      'expression': ['',
#       'CALCULATE(',
#       '    DISTINCTCOUNT(fact_suggestion_board[pky_suggestion_board])',
#       '    , FILTER(',
#       '        fact_suggestion_board',
#       '        , fact_suggestion_board[lab_status] = "SENT"',
#       '    )',
#       ')'],
#      'formatString': '0',
#      'lineageTag': '028e4af9-39cc-47fe-b114-629283df51b8'},
#     {'name': 'Nb of SB sent per FA',
#      'annotations': [{'name': 'PBI_FormatHint',
#        'value': '{"isGeneralNumber":true}'}],
#      'displayFolder': 'scope FA',
#      'expression': '[Total of SB sent] / [Nb of FAs who sent a SB] ',
#      'lineageTag': 'e9e0c141-91e3-4f13-871a-a7fcfc23b679'},
#     {'name': 'Nb of FAs who sent a Chat',
#      'displayFolder': 'scope FA',
#      'expression': 'DISTINCTCOUNT(fact_message[fky_fa])',
#      'lineageTag': 'c84dec07-2aad-4189-a033-b7b4f78fe1b3'},
#     {'name': 'Total of Chats',
#      'displayFolder': 'scope FA',
#      'expression': ['',
#       '',
#       'CALCULATE(',
#       '    COUNT(fact_message[pky_message])',
#       '    , FILTER(',
#       '        fact_message',
#       '        ,NOT(ISBLANK(fact_message[fky_fa]))',
#       '    )',
#       ')'],
#      'lineageTag': '4324aca1-1c81-4e8e-9ba9-0da12c791f46'},
#     {'name': 'Nb of Chats sent per FA',
#      'annotations': [{'name': 'PBI_FormatHint',
#        'value': '{"isGeneralNumber":true}'}],
#      'displayFolder': 'scope FA',
#      'expression': ['',
#       'DIVIDE(',
#       '    [Total of Chats]',
#       '    , [Nb of FAs who sent a Chat]',
#       ')'],
#      'lineageTag': 'bb7437d2-5949-4c95-a0ed-1d915599fcbc'},
#     {'name': 'Nb of FAs who did at least one Mirror Session',
#      'displayFolder': 'scope FA',
#      'expression': ['',
#       '',
#       'CALCULATE(',
#       '    DISTINCTCOUNT(fact_mirror[fky_fa]),',
#       '    FILTER(fact_mirror,',
#       '    fact_mirror[experience_Duration_valid] = True',
#       '            )',
#       ')'],
#      'formatString': '0',
#      'lineageTag': '3e8b16d6-d9ac-4928-843c-ad516432f32e'},
#     {'name': 'Nb of Mirror Sessions by FA',
#      'annotations': [{'name': 'PBI_FormatHint',
#        'value': '{"isGeneralNumber":true}'}],
#      'displayFolder': 'scope FA',
#      'expression': '[Nb of Mirror Sessions] / [Nb of FAs who did at least one Mirror Session]',
#      'lineageTag': 'c8bee7b8-2c47-4585-85d4-cf27d36824e3'}],
#    'partitions': [{'name': 'Mesure',
#      'mode': 'import',
#      'source': {'expression': ['let',
#        '    Source = Table.FromRows(Json.Document(Binary.Decompress(Binary.FromText("i44FAA==", BinaryEncoding.Base64), Compression.Deflate)), let _t = ((type nullable text) meta [Serialized.Text = true]) in type table [temp = _t]),',
#        '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"temp", type text}}),',
#        '    #"Colonnes supprimées" = Table.RemoveColumns(#"Type modifié",{"temp"})',
#        'in',
#        '    #"Colonnes supprimées"'],
#       'type': 'm'}}]},
#   {'name': 'fact_mirror',
#    'annotations': [{'name': 'PBI_ResultType', 'value': 'Table'},
#     {'name': 'PBI_NavigationStepName', 'value': 'Navigation'}],
#    'columns': [{'name': 'pky_mirror_session',
#      'dataType': 'string',
#      'lineageTag': '5bc85fa2-d358-443f-ac8f-f516df6415d3',
#      'sourceColumn': 'pky_mirror_session',
#      'summarizeBy': 'none'},
#     {'name': 'fky_client',
#      'dataType': 'string',
#      'lineageTag': '4b49cd0c-1c37-4921-a938-d7c4fe1e50fd',
#      'sourceColumn': 'fky_client',
#      'summarizeBy': 'none'},
#     {'name': 'fky_fa',
#      'dataType': 'string',
#      'lineageTag': '3f8ea200-98ab-46d2-ab42-97a7f370cb36',
#      'sourceColumn': 'fky_fa',
#      'summarizeBy': 'none'},
#     {'name': 'fky_mirror',
#      'dataType': 'string',
#      'lineageTag': 'a17d1590-b9db-47d1-8cf9-c5e48633334c',
#      'sourceColumn': 'fky_mirror',
#      'summarizeBy': 'none'},
#     {'name': 'is_productdetected',
#      'dataType': 'boolean',
#      'formatString': '"TRUE";"TRUE";"FALSE"',
#      'lineageTag': 'b0de566d-2f90-4fdf-a39f-9ad35cf793d8',
#      'sourceColumn': 'is_productdetected',
#      'summarizeBy': 'none'},
#     {'name': 'is_productrecommended',
#      'dataType': 'boolean',
#      'formatString': '"TRUE";"TRUE";"FALSE"',
#      'lineageTag': '3f1329b0-7af5-405e-b3ef-df1650348b98',
#      'sourceColumn': 'is_productrecommended',
#      'summarizeBy': 'none'},
#     {'name': 'is_lookrecommended',
#      'dataType': 'boolean',
#      'formatString': '"TRUE";"TRUE";"FALSE"',
#      'lineageTag': '8bce18cc-dc4c-40fa-8fad-addfbb2cf909',
#      'sourceColumn': 'is_lookrecommended',
#      'summarizeBy': 'none'},
#     {'name': 'dtm_lastupdate',
#      'dataType': 'dateTime',
#      'formatString': 'General Date',
#      'lineageTag': '33134ccb-3fd9-449c-a285-000ee91a1cf2',
#      'sourceColumn': 'dtm_lastupdate',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_b6d04e11-7818-41c0-8252-5404c06b34b3'},
#        'isDefault': True,
#        'relationship': '1c542d6c-d576-4003-b820-2d7dc763db54'}]},
#     {'name': 'dtm_experiencestarting',
#      'dataType': 'dateTime',
#      'formatString': 'General Date',
#      'lineageTag': '6bdb39d6-ddc9-42a5-be16-69a79f0df9b5',
#      'sourceColumn': 'dtm_experiencestarting',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_b967f1b3-99af-4a56-a8c8-5115a090d2e8'},
#        'isDefault': True,
#        'relationship': '674c4005-e1ae-4490-9c9e-d75173bc9f7c'}]},
#     {'name': 'dtm_experienceending',
#      'dataType': 'dateTime',
#      'formatString': 'General Date',
#      'lineageTag': '2e37865d-5b9c-4678-a388-8d8b2577533c',
#      'sourceColumn': 'dtm_experienceending',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_abff6ddb-74f8-4e28-98b7-1cb2763daf96'},
#        'isDefault': True,
#        'relationship': '1d2a6e8d-ff99-4087-bcb3-a41a20a3404a'}]},
#     {'name': 'lab_sessiontype',
#      'dataType': 'string',
#      'lineageTag': '154c0b0e-e0d4-4577-a9b9-4a5c9c751ef1',
#      'sourceColumn': 'lab_sessiontype',
#      'summarizeBy': 'none'},
#     {'name': 'pky_mirror',
#      'dataType': 'string',
#      'lineageTag': '2e1409d6-8042-4a18-83e1-14447c985d3d',
#      'sourceColumn': 'pky_mirror',
#      'summarizeBy': 'none'},
#     {'name': 'fky_boutique',
#      'dataType': 'string',
#      'lineageTag': '21928f57-5a9d-4884-a301-c411d8ebb60f',
#      'sourceColumn': 'fky_boutique',
#      'summarizeBy': 'none'},
#     {'name': 'experience_DurationMn',
#      'dataType': 'double',
#      'lineageTag': 'fed32f5c-d479-4100-b5ad-69c4446d8714',
#      'sourceColumn': 'experience_DurationMn',
#      'summarizeBy': 'sum'},
#     {'name': 'experience_Duration_valid',
#      'dataType': 'boolean',
#      'formatString': '"TRUE";"TRUE";"FALSE"',
#      'lineageTag': '851faa13-00c7-4ca0-9199-4f765f8ab1ee',
#      'sourceColumn': 'experience_Duration_valid',
#      'summarizeBy': 'none'},
#     {'name': 'experience_starting_date',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': 'f350bb93-04dd-4d49-9dd5-d41eef86916c',
#      'sourceColumn': 'experience_starting_date',
#      'summarizeBy': 'none'},
#     {'name': 'experience_starting_time',
#      'dataType': 'dateTime',
#      'formatString': 'General Date',
#      'lineageTag': 'daeec98e-6101-4085-b026-01b078ae1de4',
#      'sourceColumn': 'experience_starting_time',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_b7b7c7a9-0a88-4ce3-8981-443a5a749dea'},
#        'isDefault': True,
#        'relationship': '5edf97e5-2dfa-4184-9346-5f07102b71fd'}]},
#     {'name': 'experience_ending_date',
#      'dataType': 'dateTime',
#      'formatString': 'General Date',
#      'lineageTag': '16993693-0975-4637-ab1a-adb9d1b6f67d',
#      'sourceColumn': 'experience_ending_date',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_77ee9777-3f8a-4f4a-91db-c0373d5b761f'},
#        'isDefault': True,
#        'relationship': '6bbf3867-3ff9-4ffc-9ed5-4d221b7defc8'}]},
#     {'name': 'experience_ending_time',
#      'dataType': 'dateTime',
#      'formatString': 'General Date',
#      'lineageTag': 'cb664ed3-ec69-4426-83ed-d7495ae6a2e8',
#      'sourceColumn': 'experience_ending_time',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_e91d7dbb-0364-4129-bd81-abaa8064afc2'},
#        'isDefault': True,
#        'relationship': 'dee10df1-8da8-47e0-99ee-2edbad3f2f19'}]},
#     {'name': 'DayOfWeekName',
#      'dataType': 'string',
#      'lineageTag': '8df4c973-a0d4-4627-aafe-f210efac8ff5',
#      'sourceColumn': 'DayOfWeekName',
#      'summarizeBy': 'none'},
#     {'name': 'connection_mode',
#      'dataType': 'string',
#      'lineageTag': '28e72515-4723-49d8-92d7-4af7e5d5a5c3',
#      'sourceColumn': 'connection_mode',
#      'summarizeBy': 'none'},
#     {'name': 'fky_mirror_session',
#      'dataType': 'string',
#      'lineageTag': 'c98b5c84-0ff1-437a-85ba-a1a07ededccf',
#      'sourceColumn': 'fky_mirror_session',
#      'summarizeBy': 'none'},
#     {'name': 'fky_product',
#      'dataType': 'string',
#      'lineageTag': '6a519675-2514-4002-81fc-dd98d70ddb94',
#      'sourceColumn': 'fky_product',
#      'summarizeBy': 'none'},
#     {'name': 'boutique_opening_hour_utc',
#      'changedProperties': [{'property': 'DataType'}],
#      'dataType': 'dateTime',
#      'expression': ['// this formula selects the utc opening hour of each boutique based on summer and winter timings',
#       'VAR StartingDate = fact_mirror[experience_starting_date]',
#       'VAR SummerStart = DATE(YEAR(StartingDate), 3, 31)  -- March 31',
#       'VAR SummerEnd = DATE(YEAR(StartingDate), 11, 27)  -- November 27',
#       'VAR WinterStart = DATE(YEAR(StartingDate), 11, 28) -- November 28',
#       'VAR WinterEnd = DATE(YEAR(StartingDate), 3, 30)  -- March 30',
#       '',
#       'RETURN ',
#       'IF(',
#       '    StartingDate >= SummerStart && StartingDate <= SummerEnd,',
#       '    RELATED(dim_boutique[UTC opening hour (summer)]),',
#       '    RELATED(dim_boutique[UTC opening hour (winter)])',
#       ')',
#       ''],
#      'formatString': 'Long Time',
#      'isDataTypeInferred': True,
#      'lineageTag': '8dfa00f0-42b3-41d3-97ca-1009352c2785',
#      'summarizeBy': 'none',
#      'type': 'calculated'},
#     {'name': 'boutique_closing_hour_utc',
#      'changedProperties': [{'property': 'DataType'}],
#      'dataType': 'dateTime',
#      'expression': ['// this formula selects the utc closing hour of each boutique based on summer and winter timings',
#       'VAR EndingDate = fact_mirror[experience_ending_date]',
#       'VAR SummerStart = DATE(YEAR(EndingDate), 3, 31)  -- March 31',
#       'VAR SummerEnd = DATE(YEAR(EndingDate), 11, 27)  -- November 27',
#       'VAR WinterStart = DATE(YEAR(EndingDate), 11, 28) -- November 28',
#       'VAR WinterEnd = DATE(YEAR(EndingDate), 3, 30)  -- March 30',
#       '',
#       'RETURN ',
#       'IF(',
#       '    EndingDate >= SummerStart && EndingDate <= SummerEnd,',
#       '    RELATED(dim_boutique[UTC closing hour (summer)]),',
#       '    RELATED(dim_boutique[UTC closing hour (winter)])',
#       ')',
#       ''],
#      'formatString': 'Long Time',
#      'isDataTypeInferred': True,
#      'lineageTag': '0bac4433-8a88-410b-b3da-e30dd703843c',
#      'summarizeBy': 'none',
#      'type': 'calculated'},
#     {'name': 'is_session_starting_time_validated',
#      'dataType': 'boolean',
#      'expression': ['',
#       'IF(',
#       '    VALUE(TIMEVALUE(fact_mirror[experience_starting_time])) >= fact_mirror[boutique_opening_hour_utc] ',
#       '    && VALUE(TIMEVALUE(fact_mirror[experience_starting_time])) <= fact_mirror[boutique_closing_hour_utc],',
#       '    TRUE(),',
#       '    FALSE()',
#       ')'],
#      'formatString': '"TRUE";"TRUE";"FALSE"',
#      'isDataTypeInferred': True,
#      'lineageTag': '916f0a61-4ec5-49b9-b1d9-916986c30568',
#      'summarizeBy': 'none',
#      'type': 'calculated'},
#     {'name': 'lab_mirror',
#      'dataType': 'string',
#      'lineageTag': '3a4579d3-a133-41eb-9e3f-c0494d52417b',
#      'sourceColumn': 'lab_mirror',
#      'summarizeBy': 'none'}],
#    'lineageTag': '16059bc1-4e99-43d8-9428-1b2796a8c5dd',
#    'partitions': [{'name': 'fact_mirror',
#      'mode': 'import',
#      'queryGroup': 'fact',
#      'source': {'expression': ['let',
#        '    Source = Sql.Database(',
#        '        "asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net", ',
#        '        database_id, ',
#        '        [Query = "SELECT *',
#        '                  FROM OPENROWSET(',
#        '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_mirror/\',',
#        "                        FORMAT = 'DELTA'",
#        '                    ) AS [result]"',
#        '        ]',
#        '    )',
#        'in',
#        '    Source'],
#       'type': 'm'}}]},
#   {'name': 'fact_suggestion_board',
#    'annotations': [{'name': 'PBI_ResultType', 'value': 'Table'},
#     {'name': 'PBI_NavigationStepName', 'value': 'Navigation'}],
#    'columns': [{'name': 'pky_suggestion_board',
#      'dataType': 'string',
#      'lineageTag': '9f6bb4f7-5bea-40dd-9828-39edd3000904',
#      'sourceColumn': 'pky_suggestion_board',
#      'summarizeBy': 'none'},
#     {'name': 'fky_client',
#      'dataType': 'string',
#      'lineageTag': '830918e2-4822-4fca-94b5-c44de45c7c33',
#      'sourceColumn': 'fky_client',
#      'summarizeBy': 'none'},
#     {'name': 'fky_fa',
#      'dataType': 'string',
#      'lineageTag': '1d45f5dd-e8c8-4051-8b39-6b26c37aec7f',
#      'sourceColumn': 'fky_fa',
#      'summarizeBy': 'none'},
#     {'name': 'lab_status',
#      'dataType': 'string',
#      'lineageTag': 'eaf32e84-42a4-43b9-bded-1bda4b1c47e2',
#      'sourceColumn': 'lab_status',
#      'summarizeBy': 'none'},
#     {'name': 'client_attached_boutique',
#      'dataType': 'string',
#      'lineageTag': 'b88f22f2-2526-4641-a56b-95a7be86aa5d',
#      'sourceColumn': 'client_attached_boutique',
#      'summarizeBy': 'none'},
#     {'name': 'dtm_publication',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': '2ccfe8e0-a4d2-419d-b0f1-502737576db4',
#      'sourceColumn': 'dtm_publication',
#      'summarizeBy': 'none'}],
#    'lineageTag': 'd37f2dd9-6846-4ae4-924e-520d498f135b',
#    'partitions': [{'name': 'fact_suggestion_board',
#      'mode': 'import',
#      'queryGroup': 'fact',
#      'source': {'expression': ['let',
#        '    Source = Sql.Database(',
#        '        server_id, ',
#        '        database_id, ',
#        '        [Query = "SELECT *',
#        '                  FROM OPENROWSET(',
#        '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_suggestion_board/\',',
#        "                        FORMAT = 'DELTA'",
#        '                    ) AS [result]"',
#        '        ]',
#        '    ),',
#        '    #"Modify Date Column Format" = Table.TransformColumnTypes(Source,{{"dtm_publication", type date}})',
#        'in',
#        '    #"Modify Date Column Format"'],
#       'type': 'm'}}]},
#   {'name': 'fact_message',
#    'annotations': [{'name': 'PBI_ResultType', 'value': 'Table'},
#     {'name': 'PBI_NavigationStepName', 'value': 'Navigation'}],
#    'columns': [{'name': 'pky_message',
#      'dataType': 'string',
#      'lineageTag': '1ec96b09-b39a-41be-9ba4-290711146b1d',
#      'sourceColumn': 'pky_message',
#      'summarizeBy': 'none'},
#     {'name': 'fky_chanel_member',
#      'dataType': 'string',
#      'lineageTag': 'e81f32ac-5796-4ff1-9ceb-dd0baf8606af',
#      'sourceColumn': 'fky_chanel_member',
#      'summarizeBy': 'none'},
#     {'name': 'lab_type',
#      'dataType': 'string',
#      'lineageTag': 'b684ed10-5554-4270-af0a-392c6fde3ccf',
#      'sourceColumn': 'lab_type',
#      'summarizeBy': 'none'},
#     {'name': 'dtm_createdat',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': '4d166d9f-2a76-46fb-b102-b46b87e846bb',
#      'sourceColumn': 'dtm_createdat',
#      'summarizeBy': 'none'},
#     {'name': 'pky_channel_member',
#      'dataType': 'string',
#      'lineageTag': 'b65725c9-7df0-4dfc-b0aa-67f9cb61b44c',
#      'sourceColumn': 'pky_channel_member',
#      'summarizeBy': 'none'},
#     {'name': 'fky_channel',
#      'dataType': 'string',
#      'lineageTag': 'c4d4fe75-3542-4125-9913-94e802fac6a3',
#      'sourceColumn': 'fky_channel',
#      'summarizeBy': 'none'},
#     {'name': 'fky_client',
#      'dataType': 'string',
#      'lineageTag': 'c26eff7c-0dd4-407d-9048-2acfc798fa08',
#      'sourceColumn': 'fky_client',
#      'summarizeBy': 'none'},
#     {'name': 'fky_fa',
#      'dataType': 'string',
#      'lineageTag': '012e502c-979f-45ff-8c76-c460f0c93022',
#      'sourceColumn': 'fky_fa',
#      'summarizeBy': 'none'},
#     {'name': 'client_attached_boutique',
#      'dataType': 'string',
#      'lineageTag': 'bc9eadcc-5b32-4993-b71c-2cda8eec1767',
#      'sourceColumn': 'client_attached_boutique',
#      'summarizeBy': 'none'},
#     {'name': 'dtm_createdat_chat',
#      'dataType': 'int64',
#      'formatString': '0',
#      'lineageTag': '53e49be2-5e7c-4395-9b59-a1420ae56c16',
#      'sourceColumn': 'dtm_createdat_chat',
#      'summarizeBy': 'sum'}],
#    'lineageTag': '2148dd52-6805-4438-9475-62ae8d389bc4',
#    'partitions': [{'name': 'fact_message',
#      'mode': 'import',
#      'queryGroup': 'fact',
#      'source': {'expression': ['let',
#        '    Source = Sql.Database(',
#        '        server_id, ',
#        '        database_id, ',
#        '        [Query = "SELECT *',
#        '                  FROM OPENROWSET(',
#        '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/fact/fact_message/\',',
#        "                        FORMAT = 'DELTA'",
#        '                    ) AS [result]"',
#        '        ]',
#        '    ),',
#        '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"dtm_createdat", type date}})',
#        'in',
#        '    #"Type modifié"'],
#       'type': 'm'}}]},
#   {'name': 'dim_client',
#    'annotations': [{'name': 'PBI_ResultType', 'value': 'Table'},
#     {'name': 'PBI_NavigationStepName', 'value': 'Navigation'}],
#    'columns': [{'name': 'fky_boutique',
#      'dataType': 'string',
#      'lineageTag': 'bea8dfd8-abf0-42f1-8b61-2688cc0d4187',
#      'sourceColumn': 'fky_boutique',
#      'summarizeBy': 'none'},
#     {'name': 'pky_client',
#      'dataType': 'string',
#      'lineageTag': 'b3856bed-d245-400c-a2b9-0202ccaae6d4',
#      'sourceColumn': 'pky_client',
#      'summarizeBy': 'none'},
#     {'name': 'fky_faofonboarding',
#      'dataType': 'string',
#      'lineageTag': 'e59151fb-f507-40dc-a866-642a93fa9f64',
#      'sourceColumn': 'fky_faofonboarding',
#      'summarizeBy': 'none'},
#     {'name': 'fky_faofattachement',
#      'dataType': 'string',
#      'lineageTag': '375494f9-7aa5-45f0-b002-885b997cf8bc',
#      'sourceColumn': 'fky_faofattachement',
#      'summarizeBy': 'none'},
#     {'name': 'id_gygia',
#      'dataType': 'string',
#      'lineageTag': 'df0171b6-149d-4595-b1d1-821a6a303c6a',
#      'sourceColumn': 'id_gygia',
#      'summarizeBy': 'none'},
#     {'name': 'id_POS',
#      'dataType': 'string',
#      'lineageTag': '453bd216-0210-41cc-a737-33e4ff2a6121',
#      'sourceColumn': 'id_POS',
#      'summarizeBy': 'none'},
#     {'name': 'id_GA',
#      'dataType': 'string',
#      'lineageTag': 'bad1120e-fd84-4bb4-86ec-b03cd7ebc988',
#      'sourceColumn': 'id_GA',
#      'summarizeBy': 'none'},
#     {'name': 'id_CRM',
#      'dataType': 'string',
#      'lineageTag': '044ebfd4-7102-4e79-be88-79dd2f048048',
#      'sourceColumn': 'id_CRM',
#      'summarizeBy': 'none'},
#     {'name': 'dtm_dateofonboarding',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': '77b1b0d3-b15c-4f6c-9c9f-7638b77d9315',
#      'sourceColumn': 'dtm_dateofonboarding',
#      'summarizeBy': 'none'},
#     {'name': 'lab_marketofonboarding',
#      'dataType': 'string',
#      'lineageTag': '032939f0-471a-4356-91eb-b21a96c95479',
#      'sourceColumn': 'lab_marketofonboarding',
#      'summarizeBy': 'none'},
#     {'name': 'lab_local',
#      'dataType': 'string',
#      'lineageTag': '8eef4774-c45f-423c-8739-88e65c8222d5',
#      'sourceColumn': 'lab_local',
#      'summarizeBy': 'none'},
#     {'name': 'lab_tourist',
#      'dataType': 'string',
#      'lineageTag': '67d86796-fd2b-45b5-8880-6545fbd4fb28',
#      'sourceColumn': 'lab_tourist',
#      'summarizeBy': 'none'},
#     {'name': 'is_chanelemployee',
#      'dataType': 'boolean',
#      'formatString': '"TRUE";"TRUE";"FALSE"',
#      'lineageTag': '576985c0-055d-45b1-952d-377a8551a811',
#      'sourceColumn': 'is_chanelemployee',
#      'summarizeBy': 'none'},
#     {'name': 'lab_segmentation',
#      'dataType': 'string',
#      'lineageTag': 'b20316fa-82b1-4ad5-9848-73c0a430c404',
#      'sourceColumn': 'lab_segmentation',
#      'summarizeBy': 'none'},
#     {'name': 'is_onboarded',
#      'dataType': 'boolean',
#      'formatString': '"TRUE";"TRUE";"FALSE"',
#      'lineageTag': '8fb1b185-9348-4d99-9fb1-6ba89cae2241',
#      'sourceColumn': 'is_onboarded',
#      'summarizeBy': 'none'},
#     {'name': 'lab_region',
#      'dataType': 'string',
#      'lineageTag': '4615e761-4973-479e-8c60-c6a600fd7727',
#      'sourceColumn': 'lab_region',
#      'summarizeBy': 'none'},
#     {'name': 'is_whitelisted',
#      'dataType': 'boolean',
#      'formatString': '"TRUE";"TRUE";"FALSE"',
#      'lineageTag': 'b5de9eda-34f7-431a-aa13-beab8296ec8f',
#      'sourceColumn': 'is_whitelisted',
#      'summarizeBy': 'none'},
#     {'name': 'cod_billingcountryiso3',
#      'dataType': 'string',
#      'lineageTag': '018b747e-a0da-434c-970a-df644aec6d01',
#      'sourceColumn': 'cod_billingcountryiso3',
#      'summarizeBy': 'none'},
#     {'name': 'lab_billingcountryen',
#      'dataType': 'string',
#      'lineageTag': '49eb8512-e14d-4245-ac5f-eec32cd818b3',
#      'sourceColumn': 'lab_billingcountryen',
#      'summarizeBy': 'none'}],
#    'lineageTag': 'd8891cbd-50af-4d89-b2ca-54b3564424b7',
#    'partitions': [{'name': 'dim_client',
#      'mode': 'import',
#      'queryGroup': 'dimension',
#      'source': {'expression': ['let',
#        '    Source = Sql.Database(',
#        '        server_id, ',
#        '        database_id, ',
#        '        [Query = "SELECT *',
#        '                  FROM OPENROWSET(',
#        '                        BULK \'https://" & storage_id & ".dfs.core.windows.net/digital-platine/dimension/dim_client/\',',
#        "                        FORMAT = 'DELTA'",
#        '                    ) AS [result]"',
#        '        ]',
#        '    ),',
#        '    #"Type modifié" = Table.TransformColumnTypes(Source,{{"dtm_dateofonboarding", type date}})',
#        'in',
#        '    #"Type modifié"'],
#       'type': 'm'}}]},
#   {'name': 'dim_boutique',
#    'annotations': [{'name': 'PBI_NavigationStepName', 'value': 'Navigation'},
#     {'name': 'PBI_ResultType', 'value': 'Table'}],
#    'columns': [{'name': 'Region',
#      'dataType': 'string',
#      'lineageTag': 'ce19aa0b-0a99-43a0-ab8c-0f81306e4bf9',
#      'sourceColumn': 'Region',
#      'summarizeBy': 'none'},
#     {'name': 'Market',
#      'dataType': 'string',
#      'lineageTag': 'db7247c7-0fa3-4092-a9e9-f5502c43e479',
#      'sourceColumn': 'Market',
#      'summarizeBy': 'none'},
#     {'name': 'Country',
#      'dataType': 'string',
#      'lineageTag': 'f6949a3a-0000-4044-a586-3e88097ccb1f',
#      'sourceColumn': 'Country',
#      'summarizeBy': 'none'},
#     {'name': 'Boutique Name',
#      'dataType': 'string',
#      'lineageTag': '3bab60b1-4bf3-4461-ba70-286082c7f409',
#      'sourceColumn': 'Boutique Name',
#      'summarizeBy': 'none'},
#     {'name': 'Boutique Group Code',
#      'changedProperties': [{'property': 'SortByColumn'}],
#      'dataType': 'string',
#      'lineageTag': '61996d31-66b7-448b-9805-93fb037030db',
#      'sourceColumn': 'Boutique Group Code',
#      'summarizeBy': 'none'},
#     {'name': 'Inchanel Launching Date',
#      'dataType': 'dateTime',
#      'formatString': 'Long Date',
#      'lineageTag': 'd57e9f13-5cb4-406b-9bde-fe5bf083d7b8',
#      'sourceColumn': 'Inchanel Launching Date',
#      'summarizeBy': 'none',
#      'variations': [{'name': 'Variation',
#        'defaultHierarchy': {'hierarchy': 'Hiérarchie de dates',
#         'table': 'LocalDateTable_de807e5e-d6db-488d-ac38-bb0d956e632e'},
#        'isDefault': True,
#        'relationship': 'cf1574a2-f761-4d82-943b-e6b91c69e89b'}]},
#     {'name': 'Boutique Status',
#      'dataType': 'string',
#      'lineageTag': '18543cc9-6a32-45f3-bc3c-a2ce2a69e69d',
#      'sourceColumn': 'Boutique Status',
#      'summarizeBy': 'none'},
#     {'name': 'Boutique Status Code',
#      'dataType': 'int64',
#      'formatString': '0',
#      'lineageTag': 'aeea477c-c1b0-4e64-a589-97bebbfde639',
#      'sourceColumn': 'Boutique Status Code',
#      'summarizeBy': 'count'},
#     {'name': 'Mirror Launch date',
#      'dataType': 'string',
#      'lineageTag': '6964463a-4457-429f-8263-b20d4313c7cd',
#      'sourceColumn': 'Mirror Launch date',
#      'summarizeBy': 'none'},
#     {'name': 'Digital Launch date',
#      'dataType': 'string',
#      'lineageTag': 'ce5572c8-31ca-49d6-a9f3-8a7655c2380d',
#      'sourceColumn': 'Digital Launch date',
#      'summarizeBy': 'none'},
#     {'name': 'Boutique Code',
#      'dataType': 'string',
#      'lineageTag': '3c0cf06b-f7a3-4068-8d3a-9f24a3781497',
#      'sourceColumn': 'Boutique Code',
#      'summarizeBy': 'none'},
#     {'name': 'Opening hour (local)',
#      'dataType': 'dateTime',
#      'formatString': 'Long Time',
#      'lineageTag': '2918a68c-213a-4773-ab5d-0411dbc84dee',
#      'sourceColumn': 'Opening hour (local)',
#      'summarizeBy': 'none'},
#     {'name': 'Closing hour (local)',
#      'dataType': 'dateTime',
#      'formatString': 'Long Time',
#      'lineageTag': '4fa0ae4c-1d97-463e-a26d-bb405ef1c95b',
#      'sourceColumn': 'Closing hour (local)',
#      'summarizeBy': 'none'},
#     {'name': 'UTC opening hour (summer)',
#      'dataType': 'dateTime',
#      'formatString': 'Long Time',
#      'lineageTag': 'ad63ab10-df52-433d-8b44-fb3b6c52a4ed',
#      'sourceColumn': 'UTC opening hour (summer)',
#      'summarizeBy': 'none'},
#     {'name': 'UTC closing hour (summer)',
#      'dataType': 'dateTime',
#      'formatString': 'Long Time',
#      'lineageTag': '6adf5446-174a-48cb-956c-8065461aae9d',
#      'sourceColumn': 'UTC closing hour (summer)',
#      'summarizeBy': 'none'},
#     {'name': 'UTC opening hour (winter)',
#      'dataType': 'dateTime',
#      'formatString': 'Long Time',
#      'lineageTag': 'c148b2cb-7068-4d83-b164-b8f9dd7543d9',
#      'sourceColumn': 'UTC opening hour (winter)',
#      'summarizeBy': 'none'},
#     {'name': 'UTC closing hour (winter)',
#      'dataType': 'dateTime',
#      'formatString': 'Long Time',
#      'lineageTag': 'a03f3a73-be56-4b20-8c13-19439f8483c8',
#      'sourceColumn': 'UTC closing hour (winter)',
#      'summarizeBy': 'none'}],
#    'lineageTag': '760a6498-4b72-41f3-bd7f-9015644d8476',
#    'partitions': [{'name': 'dim_boutique',
#      'mode': 'import',
#      'queryGroup': 'dimension',
#      'source': {'expression': ['let',
#        '    // Load files from SharePoint folder',
#        '    Source = SharePoint.Files("https://lpl.sharepoint.com/sites/PERFORMANCETEAM", [ApiVersion = 15]),',
#        '',
#        '    // Filter to the specific folder path',
#        '    FilteredRows = Table.SelectRows(Source, each [Folder Path] = "https://lpl.sharepoint.com/sites/PERFORMANCETEAM/Documents partages/Dashboard/DATA & MONITORING/INCHANEL/COUCHE GOLD/DIM BOUTIQUE/"),',
#        '',
#        '    // Select the specific file',
#        '    BoutiqueReferenceFile = FilteredRows{[Name = "Référentiel boutiques InChanel.xlsx", Folder Path = "https://lpl.sharepoint.com/sites/PERFORMANCETEAM/Documents partages/Dashboard/DATA & MONITORING/INCHANEL/COUCHE GOLD/DIM BOUTIQUE/"]}[Content],',
#        '',
#        '    // Load the Excel file',
#        '    ImportedExcel = Excel.Workbook(BoutiqueReferenceFile),',
#        '',
#        '    // Get the data from the specific sheet',
#        '    BoutiqueSheet = ImportedExcel{[Item = "REFERENTIEL BOUTIQUES INCHANEL", Kind = "Sheet"]}[Data],',
#        '',
#        '    // Filter non-null rows from the source',
#        '    FilteredSourceRows = Table.SelectRows(BoutiqueSheet, each [Column6] <> null),',
#        '',
#        '    // Promote headers',
#        '    PromotedHeaders = Table.PromoteHeaders(FilteredSourceRows, [PromoteAllScalars = true]),',
#        '',
#        '    // Change column types',
#        '    ChangedColumnTypes = Table.TransformColumnTypes(',
#        '        PromotedHeaders,',
#        '        {',
#        '            {"Region", type text}, ',
#        '            {"Market", type text}, ',
#        '            {"Country", type text}, ',
#        '            {"Boutique Name", type text}, ',
#        '            {"Boutique Group Code", type any}, ',
#        '            {"Boutique STAR Code", type text}, ',
#        '            {"Inchanel Launching Date", type date}, ',
#        '            {"Boutique Status", type text}, ',
#        '            {"Boutique Status Code", Int64.Type}, ',
#        '            {"Mirror Launch date", type any}, ',
#        '            {"Digital Launch date", type text}, ',
#        '            {"Opening hour (local)", type time}, ',
#        '            {"Closing hour (local)", type time}, ',
#        '            {"UTC opening hour (summer)", type time}, ',
#        '            {"UTC closing hour (summer)", type time}, ',
#        '            {"UTC opening hour (winter)", type time},',
#        '            {"UTC closing hour (winter)", type time},',
#        '            {"Code boutique mirror ", type text}',
#        '        }',
#        '    ),',
#        '',
#        '    // Filter rows where "Code boutique mirror" is not null',
#        '    FilteredMirrorCodeRows = Table.SelectRows(ChangedColumnTypes, each [#"Code boutique mirror "] <> null),',
#        '',
#        '    // Remove "Boutique STAR Code" column',
#        '    RemovedBoutiqueStarCode = Table.RemoveColumns(FilteredMirrorCodeRows, {"Boutique STAR Code"}),',
#        '',
#        '    // Remove duplicates based on "Code boutique mirror"',
#        '    DistinctMirrorCode = Table.Distinct(RemovedBoutiqueStarCode, {"Code boutique mirror "}),',
#        '',
#        '    // Rename "Code boutique mirror" to "Boutique STAR Code"',
#        '    RenamedColumns = Table.RenameColumns(DistinctMirrorCode, {{"Code boutique mirror ", "Boutique STAR Code"}}),',
#        '',
#        '    // Combine the original table and the updated table',
#        '    CombinedTable = Table.Combine({ChangedColumnTypes, RenamedColumns}),',
#        '',
#        '    // Remove the redundant "Code boutique mirror" column',
#        '    FinalResult = Table.RemoveColumns(CombinedTable, {"Code boutique mirror "}),',
#        '    RenameColumn = Table.RenameColumns(FinalResult,{{"Boutique STAR Code", "Boutique Code"}})',
#        'in',
#        '    RenameColumn'],
#       'type': 'm'}}]}]}

# %%
import json

def extract_relevant_parts(data):
    # Initialize a dictionary to hold extracted information
    relevant_parts = {
        "DataSources": [],
        "DAXCalculations": [],
        "Relationships": []
    }

    # Extract data sources
    if "expressions" in data.get("model", {}):
        for expression in data["model"]["expressions"]:
            relevant_parts["DataSources"].append({
                "Name": expression.get("name"),
                "Expression": expression.get("expression"),
                "QueryGroup": expression.get("queryGroup")
            })

    # Extract DAX calculations (calculated columns and measures)
    if "tables" in data.get("model", {}):
        for table in data["model"]["tables"]:
            # for column in table.get("columns", []):
            #     if column.get("type") == "calculated":
            #         relevant_parts["DAXCalculations"].append({
            #             "Table": table.get("name"),
            #             "Column": column.get("name"),
            #             "Expression": column.get("expression")
            #         })
            for measure in table.get("measures", []):
                relevant_parts["DAXCalculations"].append({
                    "Table": table.get("name"),
                    "Measure": measure.get("name"),
                    "Expression": measure.get("expression")
                })

    # Extract relationships between tables
    if "relationships" in data.get("model", {}):
        for relationship in data["model"]["relationships"]:
            relevant_parts["Relationships"].append({
                "FromTable": relationship.get("fromTable"),
                "FromColumn": relationship.get("fromColumn"),
                "ToTable": relationship.get("toTable"),
                "ToColumn": relationship.get("toColumn"),
                "JoinBehavior": relationship.get("joinOnDateBehavior", "standard")
            })

    return relevant_parts

# %%
relevant_info = extract_relevant_parts(model_bim)

# Display the results
relevant_info
# Out:
# {'DataSources': [{'Name': 'server_id',
#    'Expression': '"asa-dthglbfsh-weu-uat-ondemand.sql.azuresynapse.net" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#    'QueryGroup': 'parameters'},
#   {'Name': 'database_id',
#    'Expression': '"dhfsh-gold" meta [IsParameterQuery=true, Type="Text", IsParameterQueryRequired=true]',
#    'QueryGroup': 'parameters'},
#   {'Name': 'storage_id',
#    'Expression': '"sastddthglbfsh1rawweuuat" meta [IsParameterQuery=true, Type="Any", IsParameterQueryRequired=true]',
#    'QueryGroup': 'parameters'}],
#  'DAXCalculations': [{'Table': 'Mesure',
#    'Measure': 'Nb of Clients who used the Wishlist',
#    'Expression': ['', 'DISTINCTCOUNT(fact_wishlist[fky_client])', '']},
#   {'Table': 'Mesure',
#    'Measure': 'Wishlist usage frequency per client',
#    'Expression': ['',
#     'VAR distinct_days = ',
#     "DISTINCTCOUNT( 'fact_wishlist'[lab_updatestatus] )",
#     '',
#     'VAR t =',
#     '    SUMMARIZE(',
#     '        fact_wishlist,',
#     '        fact_wishlist[fky_client],',
#     '        "val", distinct_days',
#     '    )',
#     '',
#     'RETURN',
#     '    AVERAGEX(',
#     '        t,',
#     '        [val]',
#     '    )',
#     '']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of Mirror Sessions',
#    'Expression': ['',
#     'CALCULATE(',
#     '    COUNTROWS(fact_mirror),',
#     '    FILTER(',
#     '        fact_mirror,',
#     '        fact_mirror[is_session_starting_time_validated] = TRUE() ',
#     '        && fact_mirror[experience_Duration_valid] = TRUE()',
#     '        && fact_mirror[lab_sessiontype] = "external"',
#     '    )',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Share of Mirror Sessions attached to a client',
#    'Expression': ['',
#     'DIVIDE(',
#     '    CALCULATE(',
#     '        [Nb of Mirror Sessions]',
#     '        , fact_mirror[connection_mode] = "Client"',
#     '    )',
#     '    , [Nb of Mirror Sessions]',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of clients attached to Mirror Sessions',
#    'Expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_mirror[fky_client]),',
#     '    FILTER(',
#     '        fact_mirror,',
#     '        fact_mirror[is_session_starting_time_validated] = TRUE()',
#     '        && fact_mirror[experience_Duration_valid] = TRUE()',
#     '        && fact_mirror[lab_sessiontype] = "external"',
#     '    )',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of Clients who opened a Chat',
#    'Expression': 'CALCULATE(DISTINCTCOUNT(\'fact_fashion_app\'[fky_client]), FILTER(\'fact_fashion_app\', \'fact_fashion_app\'[lab_UserType] = "INCHANEL" && \'fact_fashion_app\'[lab_MetricType] = "USERS" && \'fact_fashion_app\'[lab_chatFA] > 0 && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"))'},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of Clients who replied in a Chat',
#    'Expression': 'DISTINCTCOUNT(fact_message[fky_chanel_member]) '},
#   {'Table': 'Mesure',
#    'Measure': 'Chat usage frequency per client',
#    'Expression': ['',
#     'VAR t =',
#     '    SUMMARIZE(',
#     "        'fact_message',",
#     "        'fact_message'[fky_chanel_member],",
#     '        "val", DISTINCTCOUNT(\'fact_message\'[dtm_createdat])',
#     '    )',
#     'RETURN',
#     '    AVERAGEX(',
#     '        t,',
#     '        [val]',
#     '    )',
#     '']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of Clients who received a SB',
#    'Expression': "DISTINCTCOUNT( 'fact_suggestion_board'[fky_client])"},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of Clients who opened a SB',
#    'Expression': ['',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client])",
#     '    , FILTER(',
#     "        'fact_fashion_app'",
#     '        , \'fact_fashion_app\'[lab_UserType] = "INCHANEL" ',
#     '        && \'fact_fashion_app\'[lab_MetricType] = "USERS" ',
#     "        && 'fact_fashion_app'[lab_suggestionboardviews] > 0 ",
#     '        && \'fact_fashion_app\'[lab_Scope] = "GLOBAL"',
#     '    )',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of SB sent per client',
#    'Expression': ['',
#     '',
#     'VAR sbe_nb_SuggestionBoard_Sent_eu = ',
#     'calculate(',
#     '    COUNTROWS(fact_suggestion_board)',
#     '    , filter(',
#     '        fact_suggestion_board',
#     '        , fact_suggestion_board[lab_status] = "SENT" ',
#     '    )',
#     ')',
#     '',
#     'RETURN DIVIDE(',
#     '    sbe_nb_SuggestionBoard_Sent_eu',
#     '    , [Nb of Clients who received a SB]',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Whitelisted Clients',
#    'Expression': ['',
#     'CALCULATE(',
#     "    COUNTROWS('dim_client'),",
#     '    dim_client[is_whitelisted] = "yes"',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of Onboarded Clients',
#    'Expression': ['',
#     'CALCULATE(',
#     "    COUNTROWS('dim_client'),",
#     '    dim_client[is_onboarded] = TRUE()',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'INCHANEL ACTIVE Users',
#    'Expression': ['',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     '    \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '    \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '    \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'INCHANEL Active User 6 Months (Since Start)',
#    'Expression': ['',
#     'VAR MinDateFilter = MAX(dim_calendar[Date]) - 180  // date of 6 months ago',
#     '',
#     'RETURN',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     "    FILTER(ALL('dim_calendar'), dim_calendar[Date] >= MinDateFilter),",
#     '    KEEPFILTERS(',
#     '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '        \'fact_fashion_app\'[lab_scope] = "GLOBAL"',
#     '    )',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Monthly Repeated Users',
#    'Expression': ['',
#     'VAR min_date = min(dim_calendar[Date])',
#     'VAR max_date = max(dim_calendar[Date])',
#     'VAR MinDateFilter = max_date - 180  ',
#     'VAR avg_frequency = (max_date - min_date) / DISTINCTCOUNT(fact_fashion_app[dtm_fashionapp])',
#     '',
#     'RETURN',
#     'CALCULATE(',
#     "    DISTINCTCOUNT('fact_fashion_app'[fky_client]),",
#     '    FILTER(',
#     "        'fact_fashion_app',",
#     '        \'fact_fashion_app\'[lab_usertype] = "INCHANEL" &&',
#     '        \'fact_fashion_app\'[lab_metrictype] = "USERS" &&',
#     '        \'fact_fashion_app\'[lab_scope] = "GLOBAL" &&',
#     '         avg_frequency <= 28',
#     '    ),',
#     '    FILTER(',
#     "        ALL('dim_calendar'),",
#     '        dim_calendar[Date] >= MinDateFilter',
#     '    )',
#     ')',
#     '']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of FAs who onboarded a client',
#    'Expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(dim_client[fky_faofonboarding]), // fa of attachment to be added in case of that faofonboarding is blank',
#     '    FILTER(',
#     '        dim_client,',
#     '        dim_client[is_onboarded] = "Other"',
#     '    )',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Avg Onboarded Clients per FA',
#    'Expression': ['',
#     'VAR onboarded_client = ',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(dim_client[pky_client]), ',
#     '    FILTER(',
#     '        dim_client,',
#     '        dim_client[is_onboarded] = "Other"',
#     '    )',
#     ')',
#     '',
#     'RETURN DIVIDE(onboarded_client, [Nb of FAs who onboarded a client])']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of FAs who sent a SB',
#    'Expression': 'DISTINCTCOUNT(fact_suggestion_board[fky_fa])'},
#   {'Table': 'Mesure',
#    'Measure': 'Total of SB sent',
#    'Expression': ['',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_suggestion_board[pky_suggestion_board])',
#     '    , FILTER(',
#     '        fact_suggestion_board',
#     '        , fact_suggestion_board[lab_status] = "SENT"',
#     '    )',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of SB sent per FA',
#    'Expression': '[Total of SB sent] / [Nb of FAs who sent a SB] '},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of FAs who sent a Chat',
#    'Expression': 'DISTINCTCOUNT(fact_message[fky_fa])'},
#   {'Table': 'Mesure',
#    'Measure': 'Total of Chats',
#    'Expression': ['',
#     '',
#     'CALCULATE(',
#     '    COUNT(fact_message[pky_message])',
#     '    , FILTER(',
#     '        fact_message',
#     '        ,NOT(ISBLANK(fact_message[fky_fa]))',
#     '    )',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of Chats sent per FA',
#    'Expression': ['',
#     'DIVIDE(',
#     '    [Total of Chats]',
#     '    , [Nb of FAs who sent a Chat]',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of FAs who did at least one Mirror Session',
#    'Expression': ['',
#     '',
#     'CALCULATE(',
#     '    DISTINCTCOUNT(fact_mirror[fky_fa]),',
#     '    FILTER(fact_mirror,',
#     '    fact_mirror[experience_Duration_valid] = True',
#     '            )',
#     ')']},
#   {'Table': 'Mesure',
#    'Measure': 'Nb of Mirror Sessions by FA',
#    'Expression': '[Nb of Mirror Sessions] / [Nb of FAs who did at least one Mirror Session]'}],
#  'Relationships': [{'FromTable': 'dim_calendar',
#    'FromColumn': 'Date',
#    'ToTable': 'LocalDateTable_822da7e9-510e-4037-be69-095aaa0a2010',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'dim_calendar',
#    'FromColumn': 'Start of the Month',
#    'ToTable': 'LocalDateTable_4de7692d-409c-4065-9503-d0b84e2f7489',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'dim_calendar',
#    'FromColumn': 'End of the Month',
#    'ToTable': 'LocalDateTable_9a1422c1-22fb-462c-9059-dcf138aec3e7',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'dim_calendar',
#    'FromColumn': 'Start of the Week',
#    'ToTable': 'LocalDateTable_fdf3cfa6-ac4f-4279-80cf-cd75cf0f5ed8',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'fact_mirror',
#    'FromColumn': 'dtm_experiencestarting',
#    'ToTable': 'LocalDateTable_b967f1b3-99af-4a56-a8c8-5115a090d2e8',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'fact_mirror',
#    'FromColumn': 'dtm_experienceending',
#    'ToTable': 'LocalDateTable_abff6ddb-74f8-4e28-98b7-1cb2763daf96',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'dim_boutique',
#    'FromColumn': 'Inchanel Launching Date',
#    'ToTable': 'LocalDateTable_de807e5e-d6db-488d-ac38-bb0d956e632e',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'fact_wishlist',
#    'FromColumn': 'lab_updatestatus',
#    'ToTable': 'dim_calendar',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'standard'},
#   {'FromTable': 'fact_message',
#    'FromColumn': 'dtm_createdat',
#    'ToTable': 'dim_calendar',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'standard'},
#   {'FromTable': 'dim_client',
#    'FromColumn': 'dtm_dateofonboarding',
#    'ToTable': 'dim_calendar',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'standard'},
#   {'FromTable': 'fact_mirror',
#    'FromColumn': 'dtm_lastupdate',
#    'ToTable': 'LocalDateTable_b6d04e11-7818-41c0-8252-5404c06b34b3',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'fact_mirror',
#    'FromColumn': 'experience_starting_date',
#    'ToTable': 'dim_calendar',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'standard'},
#   {'FromTable': 'fact_mirror',
#    'FromColumn': 'experience_starting_time',
#    'ToTable': 'LocalDateTable_b7b7c7a9-0a88-4ce3-8981-443a5a749dea',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'fact_mirror',
#    'FromColumn': 'experience_ending_date',
#    'ToTable': 'LocalDateTable_77ee9777-3f8a-4f4a-91db-c0373d5b761f',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'fact_mirror',
#    'FromColumn': 'experience_ending_time',
#    'ToTable': 'LocalDateTable_e91d7dbb-0364-4129-bd81-abaa8064afc2',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'datePartOnly'},
#   {'FromTable': 'fact_suggestion_board',
#    'FromColumn': 'dtm_publication',
#    'ToTable': 'dim_calendar',
#    'ToColumn': 'Date',
#    'JoinBehavior': 'standard'},
#   {'FromTable': 'fact_mirror',
#    'FromColumn': 'fky_boutique',
#    'ToTable': 'dim_boutique',
#    'ToColumn': 'Boutique Code',
#    'JoinBehavior': 'standard'},
#   {'FromTable': 'dim_client',
#    'FromColumn': 'fky_boutique',
#    'ToTable': 'dim_boutique',
#    'ToColumn': 'Boutique Code',
#    'JoinBehavior': 'standard'}]}
